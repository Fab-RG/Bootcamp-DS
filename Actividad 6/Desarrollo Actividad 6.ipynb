# %% [markdown]
# ## Actividad VI- Obtención datos desde API
#
# **Consigna**
#
# 1. Buscar información en APIs públicas (i.e Twitter, NewsAPI, Spotify, Google Apis, etc).
#
# 2. Extraer datos e importarlos a un dataframe realizando una exploración simple (i.e filas, columnas, tipos de datos). Se sugiere que estos datos complementen el dataset elegido en el Elección de potenciales Datasets e importe con la librería Pandas.

# %% [markdown]
# **Desarrollo**
#
# Me interesa conocer el comportamiento de la popularidad de ventas de vehículos eléctricos, en éste caso se evalúan datos del Estado de Washington en Estados Unidos.
#
# Seleccioné el siguiente Dataset para el proyecto desde las actividades anteriores.
# Este Dataset muestra los Vehículos de Batería Eléctrica (BEVs) y Vehículos Eléctricos Híbridos (PHEVs), registrados actualmente en el Departamento de Licencias del Estado de Washington (DOL). Metadata Actualizada: March 16, 2024 URL: https://catalog.data.gov/dataset/electric-vehicle-population-data

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Cargamos el Dataset original del proyecto, mediante la librería pandas, para compararlo con el nuevo obtenido para ésta activiad mediante API Pública.**

# %%
Dataset = pd.read_csv("https://raw.githubusercontent.com/Fab-RG/Bootcamp-DS/main/Actividad%202/Electric_Vehicle_Population_Data.csv", sep=",")
Dataset.head()
# Out:
#    VIN (1-10)     County       City State  Postal Code  Model Year   Make  \
# 0  5YJYGDEE1L       King    Seattle    WA      98122.0        2020  TESLA
# 1  7SAYGDEE9P  Snohomish    Bothell    WA      98021.0        2023  TESLA
# 2  5YJSA1E4XK       King    Seattle    WA      98109.0        2019  TESLA
# 3  5YJSA1E27G       King   Issaquah    WA      98027.0        2016  TESLA
# 4  5YJYGDEE5M     Kitsap  Suquamish    WA      98392.0        2021  TESLA
#
#      Model           Electric Vehicle Type  \
# 0  MODEL Y  Battery Electric Vehicle (BEV)
# 1  MODEL Y  Battery Electric Vehicle (BEV)
# 2  MODEL S  Battery Electric Vehicle (BEV)
# 3  MODEL S  Battery Electric Vehicle (BEV)
# 4  MODEL Y  Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible             291
# 1  Eligibility unknown as battery range has not b...               0
# 2            Clean Alternative Fuel Vehicle Eligible             270
# 3            Clean Alternative Fuel Vehicle Eligible             210
# 4  Eligibility unknown as battery range has not b...               0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                  37.0       125701579
# 1          0                   1.0       244285107
# 2          0                  36.0       156773144
# 3          0                   5.0       165103011
# 4          0                  23.0       205138552
#
#                 Vehicle Location  \
# 0   POINT (-122.30839 47.610365)
# 1  POINT (-122.179458 47.802589)
# 2   POINT (-122.34848 47.632405)
# 3   POINT (-122.03646 47.534065)
# 4   POINT (-122.55717 47.733415)
#
#                                 Electric Utility  2020 Census Tract
# 0   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 1                         PUGET SOUND ENERGY INC       5.306105e+10
# 2   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 3  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 4                         PUGET SOUND ENERGY INC       5.303594e+10

# %% [markdown]
# **El nuevo Dataset que descargamos para ésta actividad es el siguiente.**

# %%
NewData = pd.read_csv("Electric_Vehicle_Population_Size_History_By_County.csv", sep=",")
NewData.head()
# Out:
#                Date        County State Vehicle Primary Use  \
# 0     April 30 2022     Wahkiakum    WA               Truck
# 1       May 31 2017         Adams    WA               Truck
# 2   October 31 2019        Collin    TX           Passenger
# 3   January 31 2024      Franklin    WA               Truck
# 4  February 28 2018  Grays Harbor    WA               Truck
#
#    Battery Electric Vehicles (BEVs)  Plug-In Hybrid Electric Vehicles (PHEVs)  \
# 0                                 0                                         0
# 1                                 0                                         0
# 2                                 2                                         1
# 3                                10                                         0
# 4                                 0                                         0
#
#    Electric Vehicle (EV) Total  Non-Electric Vehicle Total  Total Vehicles  \
# 0                            0                        1815            1815
# 1                            0                        5079            5079
# 2                            3                         142             145
# 3                           10                       20616           20626
# 4                            0                       20109           20109
#
#    Percent Electric Vehicles
# 0                       0.00
# 1                       0.00
# 2                       2.07
# 3                       0.05
# 4                       0.00

# %% [markdown]
# **1. Se importa nuevo Dataset, medianta API Pública, con información de vehículos eléctricos registrados en Estado de Washington en Estados Unidos, discriminados por Condados.**

# %%
import requests                                    
url = "https://data.wa.gov/api/views/3d5d-sdqb/rows.json?accessType=DOWNLOAD"       
headers = {"Accept-Encoding": "gzip, deflate"}     
response = requests.get(url, headers=headers)      
newdata = response.json()                            
newdata
# Out:
# {'meta': {'view': {'id': '3d5d-sdqb',
#    'name': 'Electric Vehicle Population Size History By County',
#    'assetType': 'dataset',
#    'attribution': 'Washington State Department of Licensing',
#    'averageRating': 0,
#    'category': 'Transportation',
#    'createdAt': 1591046256,
#    'description': 'This shows the number of vehicles that were registered by Washington State Department of Licensing (DOL) each month. The data is separated by county for passenger vehicles and trucks. \n\nDOL integrates National Highway Traffic Safety Administration (NHTSA) data and the Environmental Protection Agency (EPA) fuel efficiency ratings with DOL titling and registration data to create this information.',
#    'displayType': 'table',
#    'downloadCount': 9921,
#    'hideFromCatalog': False,
#    'hideFromDataJson': False,
#    'licenseId': 'ODBL',
#    'locked': False,
#    'newBackend': True,
#    'numberOfComments': 0,
#    'oid': 34339220,
#    'provenance': 'official',
#    'publicationAppendEnabled': False,
#    'publicationDate': 1591379619,
#    'publicationGroup': 17186729,
#    'publicationStage': 'published',
#    'rowsUpdatedAt': 1713474423,
#    'rowsUpdatedBy': 'kgaq-6gwr',
#    'tableId': 17199524,
#    'totalTimesRated': 0,
#    'viewCount': 3777,
#    'viewLastModified': 1713474418,
#    'viewType': 'tabular',
#    'approvals': [{'reviewedAt': 1591380915,
#      'reviewedAutomatically': True,
#      'state': 'approved',
#      'submissionId': 2285192,
#      'submissionObject': 'public_audience_request',
#      'submissionOutcome': 'change_audience',
#      'submittedAt': 1591380915,
#      'targetAudience': 'public',
#      'workflowId': 2106,
#      'submissionDetails': {'permissionType': 'READ'},
#      'submissionOutcomeApplication': {'endedAt': 1591380916,
#       'failureCount': 0,
#       'startedAt': 1591380915,
#       'status': 'success'},
#      'submitter': {'id': 'dphz-szpx', 'displayName': 'Faith'}}],
#    'clientContext': {'clientContextVariables': [], 'inheritedVariables': {}},
#    'columns': [{'id': -1,
#      'name': 'sid',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':sid',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'id',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':id',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'position',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':position',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'created_at',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':created_at',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'created_meta',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':created_meta',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'updated_at',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':updated_at',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'updated_meta',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':updated_meta',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'meta',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':meta',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': 472621118,
#      'name': 'Date',
#      'dataTypeName': 'calendar_date',
#      'description': 'Counts of registered vehicles are taken on this day (the end of this month).',
#      'fieldName': 'date',
#      'position': 1,
#      'renderTypeName': 'calendar_date',
#      'tableColumnId': 103990567,
#      'cachedContents': {'non_null': '21207',
#       'largest': '2024-03-31T00:00:00.000',
#       'null': '0',
#       'top': [{'item': '2022-04-30T00:00:00.000', 'count': '285'},
#        {'item': '2022-11-30T00:00:00.000', 'count': '285'},
#        {'item': '2022-10-31T00:00:00.000', 'count': '284'},
#        {'item': '2022-03-31T00:00:00.000', 'count': '284'},
#        {'item': '2022-12-31T00:00:00.000', 'count': '283'},
#        {'item': '2023-02-28T00:00:00.000', 'count': '283'},
#        {'item': '2022-09-30T00:00:00.000', 'count': '283'},
#        {'item': '2022-02-28T00:00:00.000', 'count': '282'},
#        {'item': '2022-05-31T00:00:00.000', 'count': '282'},
#        {'item': '2023-01-31T00:00:00.000', 'count': '282'},
#        {'item': '2021-10-31T00:00:00.000', 'count': '281'},
#        {'item': '2023-03-31T00:00:00.000', 'count': '281'},
#        {'item': '2022-06-30T00:00:00.000', 'count': '281'},
#        {'item': '2023-04-30T00:00:00.000', 'count': '281'},
#        {'item': '2021-11-30T00:00:00.000', 'count': '280'},
#        {'item': '2022-01-31T00:00:00.000', 'count': '280'},
#        {'item': '2022-08-31T00:00:00.000', 'count': '279'},
#        {'item': '2023-05-31T00:00:00.000', 'count': '277'},
#        {'item': '2022-07-31T00:00:00.000', 'count': '277'},
#        {'item': '2021-12-31T00:00:00.000', 'count': '277'}],
#       'smallest': '2017-01-31T00:00:00.000',
#       'count': '21207',
#       'cardinality': '87'},
#      'format': {'view': 'date_monthdy'}},
#     {'id': 472621119,
#      'name': 'County',
#      'dataTypeName': 'text',
#      'description': "This is the geographic region of a state that a vehicle's owner is listed to reside within. Vehicles registered in Washington state may be located in other states.",
#      'fieldName': 'county',
#      'position': 2,
#      'renderTypeName': 'text',
#      'tableColumnId': 103990568,
#      'cachedContents': {'non_null': '21120',
#       'largest': 'Yuba',
#       'null': '87',
#       'top': [{'item': 'Douglas', 'count': '291'},
#        {'item': 'Montgomery', 'count': '288'},
#        {'item': 'Jefferson', 'count': '265'},
#        {'item': 'Clark', 'count': '261'},
#        {'item': 'Franklin', 'count': '221'},
#        {'item': 'Columbia', 'count': '221'},
#        {'item': 'Orange', 'count': '203'},
#        {'item': 'Adams', 'count': '199'},
#        {'item': 'Lincoln', 'count': '197'},
#        {'item': 'Garfield', 'count': '193'},
#        {'item': 'San Juan', 'count': '185'},
#        {'item': 'Lewis', 'count': '178'},
#        {'item': 'Whatcom', 'count': '174'},
#        {'item': 'Pierce', 'count': '174'},
#        {'item': 'Grays Harbor', 'count': '174'},
#        {'item': 'Klickitat', 'count': '174'},
#        {'item': 'Asotin', 'count': '174'},
#        {'item': 'Grant', 'count': '174'},
#        {'item': 'Stevens', 'count': '174'},
#        {'item': 'Skagit', 'count': '174'}],
#       'smallest': 'Ada',
#       'count': '21207',
#       'cardinality': '313'},
#      'format': {}},
#     {'id': 472621120,
#      'name': 'State',
#      'dataTypeName': 'text',
#      'description': 'This is the geographic region of the country associated with the record. These addresses may be located in other states.',
#      'fieldName': 'state',
#      'position': 3,
#      'renderTypeName': 'text',
#      'tableColumnId': 103990558,
#      'cachedContents': {'non_null': '21120',
#       'largest': 'WY',
#       'null': '87',
#       'top': [{'item': 'WA', 'count': '6786'},
#        {'item': 'CA', 'count': '1685'},
#        {'item': 'VA', 'count': '1309'},
#        {'item': 'FL', 'count': '1109'},
#        {'item': 'TX', 'count': '1083'},
#        {'item': 'MD', 'count': '772'},
#        {'item': 'OR', 'count': '540'},
#        {'item': 'CO', 'count': '511'},
#        {'item': 'GA', 'count': '488'},
#        {'item': 'NC', 'count': '460'},
#        {'item': 'NY', 'count': '414'},
#        {'item': 'NJ', 'count': '378'},
#        {'item': 'IL', 'count': '377'},
#        {'item': 'ID', 'count': '317'},
#        {'item': 'HI', 'count': '305'},
#        {'item': 'AZ', 'count': '304'},
#        {'item': 'SC', 'count': '295'},
#        {'item': 'MA', 'count': '286'},
#        {'item': 'PA', 'count': '276'},
#        {'item': 'MO', 'count': '265'}],
#       'smallest': 'AK',
#       'count': '21207',
#       'cardinality': '50'},
#      'format': {}},
#     {'id': 472621121,
#      'name': 'Vehicle Primary Use',
#      'dataTypeName': 'text',
#      'description': 'This describes the primary intended use of the vehicle.',
#      'fieldName': 'vehicle_primary_use',
#      'position': 4,
#      'renderTypeName': 'text',
#      'tableColumnId': 104001400,
#      'cachedContents': {'non_null': '21207',
#       'largest': 'Truck',
#       'null': '0',
#       'top': [{'item': 'Passenger', 'count': '17721'},
#        {'item': 'Truck', 'count': '3486'}],
#       'smallest': 'Passenger',
#       'count': '21207',
#       'cardinality': '2'},
#      'format': {}},
#     {'id': 472621122,
#      'name': 'Battery Electric Vehicles (BEVs)',
#      'dataTypeName': 'number',
#      'description': 'The count of vehicles that are known to be propelled solely by an energy derived from an onboard electric battery.',
#      'fieldName': 'battery_electric_vehicles_bevs_',
#      'position': 5,
#      'renderTypeName': 'number',
#      'tableColumnId': 104001399,
#      'cachedContents': {'non_null': '21207',
#       'largest': '73550',
#       'null': '0',
#       'top': [{'item': '1', 'count': '7054'},
#        {'item': '0', 'count': '6870'},
#        {'item': '2', 'count': '1769'},
#        {'item': '3', 'count': '810'},
#        {'item': '4', 'count': '425'},
#        {'item': '5', 'count': '316'},
#        {'item': '6', 'count': '210'},
#        {'item': '7', 'count': '167'},
#        {'item': '8', 'count': '140'},
#        {'item': '9', 'count': '81'},
#        {'item': '10', 'count': '68'},
#        {'item': '12', 'count': '68'},
#        {'item': '17', 'count': '49'},
#        {'item': '11', 'count': '48'},
#        {'item': '19', 'count': '42'},
#        {'item': '16', 'count': '40'},
#        {'item': '18', 'count': '38'},
#        {'item': '21', 'count': '35'},
#        {'item': '20', 'count': '35'},
#        {'item': '23', 'count': '34'}],
#       'smallest': '0',
#       'count': '21207',
#       'cardinality': '1221'},
#      'format': {}},
#     {'id': 472621123,
#      'name': 'Plug-In Hybrid Electric Vehicles (PHEVs)',
#      'dataTypeName': 'number',
#      'description': 'The count of vehicles that are known to be propelled from energy partially sourced from an onboard electric battery that is capable of being recharged from an external source.',
#      'fieldName': 'plug_in_hybrid_electric_vehicles_phevs_',
#      'position': 6,
#      'renderTypeName': 'number',
#      'tableColumnId': 104001398,
#      'cachedContents': {'non_null': '21207',
#       'largest': '17935',
#       'null': '0',
#       'top': [{'item': '0', 'count': '10010'},
#        {'item': '1', 'count': '5735'},
#        {'item': '2', 'count': '1461'},
#        {'item': '3', 'count': '507'},
#        {'item': '4', 'count': '229'},
#        {'item': '5', 'count': '145'},
#        {'item': '6', 'count': '85'},
#        {'item': '7', 'count': '76'},
#        {'item': '12', 'count': '39'},
#        {'item': '8', 'count': '37'},
#        {'item': '9', 'count': '35'},
#        {'item': '11', 'count': '32'},
#        {'item': '19', 'count': '29'},
#        {'item': '17', 'count': '29'},
#        {'item': '21', 'count': '28'},
#        {'item': '33', 'count': '28'},
#        {'item': '22', 'count': '26'},
#        {'item': '10', 'count': '25'},
#        {'item': '26', 'count': '24'},
#        {'item': '20', 'count': '23'}],
#       'smallest': '0',
#       'count': '21207',
#       'cardinality': '944'},
#      'format': {}},
#     {'id': 472621124,
#      'name': 'Electric Vehicle (EV) Total',
#      'dataTypeName': 'number',
#      'description': 'The sum of Battery Electric Vehicles (BEVs) and Plug-in Hybrid Electric Vehicles (PHEVs).',
#      'fieldName': 'electric_vehicle_ev_total',
#      'position': 7,
#      'renderTypeName': 'number',
#      'tableColumnId': 103990566,
#      'cachedContents': {'non_null': '21207',
#       'largest': '91485',
#       'null': '0',
#       'top': [{'item': '1', 'count': '9510'},
#        {'item': '2', 'count': '2616'},
#        {'item': '0', 'count': '2270'},
#        {'item': '3', 'count': '1133'},
#        {'item': '4', 'count': '701'},
#        {'item': '5', 'count': '362'},
#        {'item': '6', 'count': '284'},
#        {'item': '7', 'count': '264'},
#        {'item': '8', 'count': '180'},
#        {'item': '9', 'count': '141'},
#        {'item': '10', 'count': '122'},
#        {'item': '12', 'count': '81'},
#        {'item': '11', 'count': '77'},
#        {'item': '13', 'count': '69'},
#        {'item': '14', 'count': '48'},
#        {'item': '15', 'count': '45'},
#        {'item': '19', 'count': '37'},
#        {'item': '16', 'count': '35'},
#        {'item': '17', 'count': '32'},
#        {'item': '18', 'count': '31'}],
#       'smallest': '0',
#       'count': '21207',
#       'cardinality': '1421'},
#      'format': {}},
#     {'id': 472621125,
#      'name': 'Non-Electric Vehicle Total',
#      'dataTypeName': 'number',
#      'description': 'The count of vehicles that are not electric vehicles.',
#      'fieldName': 'non_electric_vehicles',
#      'position': 8,
#      'renderTypeName': 'number',
#      'tableColumnId': 104098606,
#      'cachedContents': {'non_null': '21207',
#       'largest': '1399746',
#       'null': '0',
#       'top': [{'item': '1', 'count': '298'},
#        {'item': '4', 'count': '200'},
#        {'item': '5', 'count': '196'},
#        {'item': '6', 'count': '177'},
#        {'item': '3', 'count': '173'},
#        {'item': '0', 'count': '161'},
#        {'item': '11', 'count': '145'},
#        {'item': '13', 'count': '141'},
#        {'item': '20', 'count': '140'},
#        {'item': '12', 'count': '140'},
#        {'item': '7', 'count': '139'},
#        {'item': '18', 'count': '133'},
#        {'item': '8', 'count': '130'},
#        {'item': '21', 'count': '128'},
#        {'item': '39', 'count': '126'},
#        {'item': '9', 'count': '125'},
#        {'item': '14', 'count': '125'},
#        {'item': '10', 'count': '125'},
#        {'item': '23', 'count': '124'},
#        {'item': '32', 'count': '122'}],
#       'smallest': '0',
#       'count': '21207',
#       'cardinality': '7150'},
#      'format': {}},
#     {'id': 472621126,
#      'name': 'Total Vehicles',
#      'dataTypeName': 'number',
#      'description': 'All powered vehicles registered in the county. This includes electric vehicles.',
#      'fieldName': 'total_vehicles',
#      'position': 9,
#      'renderTypeName': 'number',
#      'tableColumnId': 104001397,
#      'cachedContents': {'non_null': '21207',
#       'largest': '1430861',
#       'null': '0',
#       'top': [{'item': '2', 'count': '298'},
#        {'item': '5', 'count': '200'},
#        {'item': '6', 'count': '196'},
#        {'item': '7', 'count': '177'},
#        {'item': '4', 'count': '173'},
#        {'item': '1', 'count': '161'},
#        {'item': '14', 'count': '146'},
#        {'item': '12', 'count': '136'},
#        {'item': '19', 'count': '136'},
#        {'item': '8', 'count': '135'},
#        {'item': '13', 'count': '134'},
#        {'item': '22', 'count': '133'},
#        {'item': '9', 'count': '130'},
#        {'item': '11', 'count': '130'},
#        {'item': '21', 'count': '126'},
#        {'item': '38', 'count': '124'},
#        {'item': '15', 'count': '123'},
#        {'item': '41', 'count': '119'},
#        {'item': '37', 'count': '119'},
#        {'item': '24', 'count': '117'}],
#       'smallest': '1',
#       'count': '21207',
#       'cardinality': '7155'},
#      'format': {}},
#     {'id': 472621127,
#      'name': 'Percent Electric Vehicles',
#      'dataTypeName': 'number',
#      'description': 'Comparison of electric vehicles versus their non-electric counterparts.',
#      'fieldName': 'percent_electric_vehicles',
#      'position': 10,
#      'renderTypeName': 'number',
#      'tableColumnId': 104099062,
#      'cachedContents': {'non_null': '21207',
#       'largest': '100',
#       'null': '0',
#       'top': [{'item': '0', 'count': '2270'},
#        {'item': '50.0', 'count': '298'},
#        {'item': '16.66666666666666666666666667', 'count': '203'},
#        {'item': '20.0', 'count': '202'},
#        {'item': '14.28571428571428571428571429', 'count': '201'},
#        {'item': '25.00', 'count': '175'},
#        {'item': '100', 'count': '161'},
#        {'item': '12.500', 'count': '158'},
#        {'item': '5.263157894736842105263157895', 'count': '151'},
#        {'item': '11.11111111111111111111111111', 'count': '146'},
#        {'item': '4.761904761904761904761904762', 'count': '142'},
#        {'item': '8.333333333333333333333333333', 'count': '141'},
#        {'item': '9.090909090909090909090909091', 'count': '138'},
#        {'item': '7.692307692307692307692307692', 'count': '135'},
#        {'item': '7.142857142857142857142857143', 'count': '134'},
#        {'item': '10.0', 'count': '134'},
#        {'item': '4.545454545454545454545454545', 'count': '128'},
#        {'item': '4.00', 'count': '125'},
#        {'item': '4.166666666666666666666666667', 'count': '123'},
#        {'item': '6.666666666666666666666666667', 'count': '123'}],
#       'smallest': '0',
#       'count': '21207',
#       'cardinality': '6343'},
#      'format': {'precision': '2'}}],
#    'grants': [{'inherited': False, 'type': 'viewer', 'flags': ['public']}],
#    'license': {'name': 'Open Data Commons Open Database License',
#     'termsLink': 'http://opendatacommons.org/licenses/odbl/1.0/'},
#    'metadata': {'custom_fields': {'Temporal': {'Posting Frequency': 'Monthly',
#       'Period of Time': 'Data includes historical Electric Vehicle population counts from January 2017 through March 2024.'},
#      'Identification': {'Originator': 'Research and Analysis Office, Department of Licensing',
#       'Metadata Language': 'English'},
#      'Notes': {'1. ': 'A Battery Electric Vehicle (BEV) is an all-electric vehicle using one or more batteries to store the electrical energy that powers the motor and is charged by plugging the vehicle in to an electric power source. A Plug-in Hybrid Electric Vehicle (PHEV) is a vehicle that uses one or more batteries to power an electric motor; uses another fuel, such as gasoline or diesel, to power an internal combustion engine or other propulsion source; and is charged by plugging the vehicle in to an electric power source.',
#       '2. ': 'Vehicles registered with a military installation address may not have an assigned county. These vehicles are not included in the final counts.',
#       '3. ': 'Monthly count of vehicles for a county may change from this report and prior reports. Processes were implemented to more accurately assign county at the time of registration.'}},
#     'rowLabel': 'Monthly count of vehicles for a county',
#     'availableDisplayTypes': ['table', 'fatrow', 'page']},
#    'owner': {'id': 'eagg-6py7',
#     'displayName': 'Department of Licensing',
#     'profileImageUrlLarge': '/api/users/eagg-6py7/profile_images/LARGE',
#     'profileImageUrlMedium': '/api/users/eagg-6py7/profile_images/THUMB',
#     'profileImageUrlSmall': '/api/users/eagg-6py7/profile_images/TINY',
#     'screenName': 'Department of Licensing',
#     'type': 'interactive',
#     'flags': ['acceptedEula', 'mayBeStoriesCoOwner']},
#    'query': {},
#    'rights': ['read'],
#    'tableAuthor': {'id': 'eagg-6py7',
#     'displayName': 'Department of Licensing',
#     'profileImageUrlLarge': '/api/users/eagg-6py7/profile_images/LARGE',
#     'profileImageUrlMedium': '/api/users/eagg-6py7/profile_images/THUMB',
#     'profileImageUrlSmall': '/api/users/eagg-6py7/profile_images/TINY',
#     'screenName': 'Department of Licensing',
#     'type': 'interactive',
#     'flags': ['acceptedEula', 'mayBeStoriesCoOwner']},
#    'tags': ['battery electric',
#     'bev',
#     'plug-in',
#     'hybrid',
#     'phev',
#     'electric',
#     'vehicle',
#     'clean energy',
#     'population growth',
#     'rao_open_data',
#     'dol_open_data',
#     'department of licensing',
#     'dol',
#     'rao_ev',
#     'rao_veh'],
#    'flags': ['default',
#     'ownerMayBeContacted',
#     'restorable',
#     'restorePossibleForType']}},
#  'data': [['row-txmj.9xki-teqc',
#    '00000000-0000-0000-3BEB-D46C134BD6D7',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2022-04-30T00:00:00',
#    'Wahkiakum',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '1815',
#    '1815',
#    '0'],
#   ['row-2h8w.5k3c~aukx',
#    '00000000-0000-0000-423F-847EA1E0E72A',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2017-05-31T00:00:00',
#    'Adams',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '5079',
#    '5079',
#    '0'],
#   ['row-3snj~v22r~5cky',
#    '00000000-0000-0000-8FE3-66BD5DC299BD',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2019-10-31T00:00:00',
#    'Collin',
#    'TX',
#    'Passenger',
#    '2',
#    '1',
#    '3',
#    '142',
#    '145',
#    '2.068965517241379310344827586'],
#   ['row-im3h-cypn_ycer',
#    '00000000-0000-0000-94D4-27279BD8C159',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2024-01-31T00:00:00',
#    'Franklin',
#    'WA',
#    'Truck',
#    '10',
#    '0',
#    '10',
#    '20616',
#    '20626',
#    '0.04848249781828759817705808203'],
#   ['row-756x_sycu_v9c6',
#    '00000000-0000-0000-B273-329343B58BB6',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2018-02-28T00:00:00',
#    'Grays Harbor',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '20109',
#    '20109',
#    '0'],
#   ['row-yedf~kh84-mf9e',
#    '00000000-0000-0000-56D5-5917329E6154',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2022-11-30T00:00:00',
#    'Chesterfield',
#    'VA',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '37',
#    '38',
#    '2.631578947368421052631578947'],
#   ['row-2a7r_eheh~2y5u',
#    '00000000-0000-0000-AE6E-306DEC1D1AEE',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-05-31T00:00:00',
#    'Missoula',
#    'MT',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '64',
#    '65',
#    '1.538461538461538461538461538'],
#   ['row-zvrg-ix2n~npea',
#    '00000000-0000-0000-F9A7-7AB1A5832645',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2017-03-31T00:00:00',
#    'Harnett',
#    'NC',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '262',
#    '263',
#    '0.3802281368821292775665399240'],
#   ['row-ds88~i7fb.77d7',
#    '00000000-0000-0000-68B2-2D6D0D92CA12',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-12-31T00:00:00',
#    'Providence',
#    'RI',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '21',
#    '22',
#    '4.545454545454545454545454545'],
#   ['row-kfhg-9pzu~xqsc',
#    '00000000-0000-0000-C6E5-0977D930A0D2',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-12-31T00:00:00',
#    'Randolph',
#    'NC',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '6',
#    '7',
#    '14.28571428571428571428571429'],
#   ['row-f7tx_6det_5bet',
#    '00000000-0000-0000-185C-60FA95830FEF',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2017-04-30T00:00:00',
#    'Eagle',
#    'CO',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '8',
#    '9',
#    '11.11111111111111111111111111'],
#   ['row-ya7y-ntja.s2m7',
#    '00000000-0000-0000-2A19-BEFB1174511F',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2018-06-30T00:00:00',
#    'Cowlitz',
#    'WA',
#    'Passenger',
#    '55',
#    '74',
#    '129',
#    '71728',
#    '71857',
#    '0.1795232197280710299622862073'],
#   ['row-u5am_xr8h_kv8i',
#    '00000000-0000-0000-613C-2EEB1AFFF653',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2022-01-31T00:00:00',
#    'King',
#    'WA',
#    'Truck',
#    '14',
#    '1',
#    '15',
#    '182576',
#    '182591',
#    '0.008215081794831070534692290420'],
#   ['row-bidv~kvzb_v9cx',
#    '00000000-0000-0000-9BB7-795C1FFF0CF3',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2017-12-31T00:00:00',
#    'Pacific',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '7543',
#    '7543',
#    '0'],
#   ['row-mswt_8ttc-qzr3',
#    '00000000-0000-0000-5071-CE8BD824348C',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-12-31T00:00:00',
#    'Klickitat',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '8325',
#    '8325',
#    '0'],
#   ['row-wrbn.4f6b~bcuq',
#    '00000000-0000-0000-E796-2FDDCDEA0674',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2018-02-28T00:00:00',
#    'Fairfax',
#    'VA',
#    'Passenger',
#    '3',
#    '2',
#    '5',
#    '827',
#    '832',
#    '0.6009615384615384615384615385'],
#   ['row-wwik~nmux.xqc3',
#    '00000000-0000-0000-AE48-EB85C2C79A2F',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2018-08-31T00:00:00',
#    'Franklin',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '18790',
#    '18790',
#    '0'],
#   ['row-6j7y_jw8j-54yt',
#    '00000000-0000-0000-BE0F-202451102938',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-02-28T00:00:00',
#    'Sacramento',
#    'CA',
#    'Passenger',
#    '2',
#    '1',
#    '3',
#    '257',
#    '260',
#    '1.153846153846153846153846154'],
#   ['row-5sjt-i9dr-eyi5',
#    '00000000-0000-0000-2AB4-9388C78B0EE2',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2019-12-31T00:00:00',
#    'Calvert',
#    'MD',
#    'Passenger',
#    '0',
#    '2',
#    '2',
#    '90',
#    '92',
#    '2.173913043478260869565217391'],
#   ['row-8uuw.gkbq_isgs',
#    '00000000-0000-0000-8E30-9D7EC4A081A2',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2020-01-31T00:00:00',
#    'Fort Bend',
#    'TX',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '50',
#    '51',
#    '1.960784313725490196078431373'],
#   ['row-9h4h-gr92~rzyc',
#    '00000000-0000-0000-83FD-6FA3D1F9F10D',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-11-30T00:00:00',
#    'Placer',
#    'CA',
#    'Passenger',
#    '2',
#    '0',
#    '2',
#    '77',
#    '79',
#    '2.531645569620253164556962025'],
#   ['row-i98c-h8fy.jehm',
#    '00000000-0000-0000-74CC-93EF6F752865',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2020-04-30T00:00:00',
#    'Cascade',
#    'MT',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '61',
#    '62',
#    '1.612903225806451612903225806'],
#   ['row-p2h5-gemu.ww7j',
#    '00000000-0000-0000-5090-93AC82D7AF88',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2022-05-31T00:00:00',
#    'San Luis Obispo',
#    'CA',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '61',
#    '62',
#    '1.612903225806451612903225806'],
#   ['row-nrjc_z94y~nsmi',
#    '00000000-0000-0000-D927-9ED5A7BC9D45',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2017-11-30T00:00:00',
#    'Montgomery',
#    'PA',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '39',
#    '40',
#    '2.500'],
#   ['row-m7pi.bhjj_ebpn',
#    '00000000-0000-0000-7388-8508CCC658EF',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2018-01-31T00:00:00',
#    'Juneau',
#    'AK',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '43',
#    '44',
#    '2.272727272727272727272727273'],
#   ['row-fkig-4v5r-rruu',
#    '00000000-0000-0000-006F-EF016DE29069',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-09-30T00:00:00',
#    'Columbia',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '1536',
#    '1536',
#    '0'],
#   ['row-6ktq.d5ak_a6am',
#    '00000000-0000-0000-8D2F-962F74699A5A',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2017-04-30T00:00:00',
#    'Spokane',
#    'WA',
#    'Passenger',
#    '236',
#    '208',
#    '444',
#    '295711',
#    '296155',
#    '0.1499214938123617700190778477'],
#   ['row-bn27~4mie_hj45',
#    '00000000-0000-0000-596C-E44C644F7207',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-12-31T00:00:00',
#    'Benton',
#    'WA',
#    'Passenger',
#    '637',
#    '444',
#    '1081',
#    '136015',
#    '137096',
#    '0.7884985703448678298418626364'],
#   ['row-7tfa-szz4_mrth',
#    '00000000-0000-0000-7688-A3FD1D7CFDB9',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2020-01-31T00:00:00',
#    'Whitman',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '8569',
#    '8569',
#    '0'],
#   ['row-dqpf.byt7.684c',
#    '00000000-0000-0000-073E-11DEFD031A15',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2017-07-31T00:00:00',
#    'Clark',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '77725',
#    '77725',
#    '0'],
#   ['row-xxab~bnxr.5zrc',
#    '00000000-0000-0000-4B11-16FE2650115E',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2022-08-31T00:00:00',
#    'Williamson',
#    'TX',
#    'Passenger',
#    '0',
#    '2',
#    '2',
#    '82',
#    '84',
#    '2.380952380952380952380952381'],
#   ['row-u75k~nkbd.sefp',
#    '00000000-0000-0000-F7E2-FDACDB6DD328',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2024-01-31T00:00:00',
#    'Rockingham',
#    'NH',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '7',
#    '8',
#    '12.500'],
#   ['row-3ejr~949m.vt54',
#    '00000000-0000-0000-4CB5-A3BA6934526A',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2018-11-30T00:00:00',
#    'King',
#    'WA',
#    'Truck',
#    '6',
#    '1',
#    '7',
#    '182721',
#    '182728',
#    '0.003830830524057615691081826540'],
#   ['row-rjbn.sy83.pxmy',
#    '00000000-0000-0000-CC1B-8754850B8D19',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-02-28T00:00:00',
#    'San Francisco',
#    'CA',
#    'Passenger',
#    '1',
#    '1',
#    '2',
#    '102',
#    '104',
#    '1.923076923076923076923076923'],
#   ['row-s4j2.7y5i_ebtz',
#    '00000000-0000-0000-EB0C-24ABDFA8DBE2',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2020-09-30T00:00:00',
#    'Skagit',
#    'WA',
#    'Truck',
#    '1',
#    '0',
#    '1',
#    '32639',
#    '32640',
#    '0.003063725490196078431372549020'],
#   ['row-5ass~fuz9~nhnt',
#    '00000000-0000-0000-24AE-20DF420C25B5',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2024-01-31T00:00:00',
#    'King',
#    'WA',
#    'Truck',
#    '1110',
#    '2',
#    '1112',
#    '170380',
#    '171492',
#    '0.6484267487696219065612390082'],
#   ['row-vb4v.4yqc~bnrc',
#    '00000000-0000-0000-ED93-BDBF40530FB5',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2017-02-28T00:00:00',
#    'Salt Lake',
#    'UT',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '333',
#    '334',
#    '0.2994011976047904191616766467'],
#   ['row-qy6r.fezy_zdjy',
#    '00000000-0000-0000-997C-6A058B9D7E38',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2020-11-30T00:00:00',
#    'Missoula',
#    'MT',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '66',
#    '67',
#    '1.492537313432835820895522388'],
#   ['row-gwaw_tp27~e59d',
#    '00000000-0000-0000-B62D-195B4CA301C9',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2020-08-31T00:00:00',
#    'Columbia',
#    'OR',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '26',
#    '27',
#    '3.703703703703703703703703704'],
#   ['row-2cyh~6m3f~x98a',
#    '00000000-0000-0000-ACFE-3C94E8F41D82',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2023-09-30T00:00:00',
#    'Solano',
#    'CA',
#    'Passenger',
#    '5',
#    '0',
#    '5',
#    '131',
#    '136',
#    '3.676470588235294117647058824'],
#   ['row-38fw-cweu-ixg9',
#    '00000000-0000-0000-FE92-F86D9A4CB608',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2018-09-30T00:00:00',
#    'Norfolk',
#    'MA',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '37',
#    '38',
#    '2.631578947368421052631578947'],
#   ['row-2qyd~37ae~s2fx',
#    '00000000-0000-0000-4187-5D35D5F296BC',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2020-01-31T00:00:00',
#    'Moore',
#    'NC',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '169',
#    '170',
#    '0.5882352941176470588235294118'],
#   ['row-zegz_94s5~eswi',
#    '00000000-0000-0000-8774-CEB4F874FD2B',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2023-01-31T00:00:00',
#    'Hillsborough',
#    'FL',
#    'Passenger',
#    '1',
#    '2',
#    '3',
#    '118',
#    '121',
#    '2.479338842975206611570247934'],
#   ['row-5t28_xrcc.hjsy',
#    '00000000-0000-0000-EA17-7C230978B3CA',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2019-03-31T00:00:00',
#    'Dale',
#    'AL',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '52',
#    '53',
#    '1.886792452830188679245283019'],
#   ['row-j8en-r2kg_uv9h',
#    '00000000-0000-0000-0055-47F537DEA347',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-05-31T00:00:00',
#    'Spartanburg',
#    'SC',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '56',
#    '57',
#    '1.754385964912280701754385965'],
#   ['row-xnwn~stff_ngfs',
#    '00000000-0000-0000-F0DF-1E203CAB1D2D',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2020-11-30T00:00:00',
#    'Mason',
#    'WA',
#    'Passenger',
#    '169',
#    '133',
#    '302',
#    '47483',
#    '47785',
#    '0.6319974887517003243695720414'],
#   ['row-at4b~b3vd_p4ge',
#    '00000000-0000-0000-FE7F-F58C492A938E',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2024-01-31T00:00:00',
#    'Orange',
#    'CA',
#    'Passenger',
#    '7',
#    '2',
#    '9',
#    '256',
#    '265',
#    '3.396226415094339622641509434'],
#   ['row-uunn~6fri-i9x8',
#    '00000000-0000-0000-3C30-CBAA48DF6775',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2018-03-31T00:00:00',
#    'Pinal',
#    'AZ',
#    'Passenger',
#    '2',
#    '0',
#    '2',
#    '214',
#    '216',
#    '0.9259259259259259259259259259'],
#   ['row-432e_fne3~wtiz',
#    '00000000-0000-0000-20CB-05B7581ABCDE',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2019-01-31T00:00:00',
#    "Prince George's",
#    'MD',
#    'Passenger',
#    '1',
#    '1',
#    '2',
#    '188',
#    '190',
#    '1.052631578947368421052631579'],
#   ['row-pefa-sf79_zkyy',
#    '00000000-0000-0000-1F43-69DC0A9D2ADE',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2022-06-30T00:00:00',
#    'Yakima',
#    'WA',
#    'Truck',
#    '1',
#    '0',
#    '1',
#    '61388',
#    '61389',
#    '0.001628956327680854876280766913'],
#   ['row-wkwj_fmj2~inzs',
#    '00000000-0000-0000-7231-5FF2B4997109',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2022-01-31T00:00:00',
#    'Franklin',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '20879',
#    '20879',
#    '0'],
#   ['row-gzxc.m88h~gu7r',
#    '00000000-0000-0000-B8E8-3917A5D1FE4D',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2022-05-31T00:00:00',
#    'Grays Harbor',
#    'WA',
#    'Passenger',
#    '205',
#    '158',
#    '363',
#    '49057',
#    '49420',
#    '0.7345204370700121408336705787'],
#   ['row-k7e4_9c3a_sxcd',
#    '00000000-0000-0000-CEDD-63DD4BCEC6A3',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2023-10-31T00:00:00',
#    'Fairfax',
#    'VA',
#    'Passenger',
#    '6',
#    '3',
#    '9',
#    '542',
#    '551',
#    '1.633393829401088929219600726'],
#   ['row-v5vr.7imq_4suj',
#    '00000000-0000-0000-A211-827D1CFFBC76',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-06-30T00:00:00',
#    'Montgomery',
#    'PA',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '26',
#    '27',
#    '3.703703703703703703703703704'],
#   ['row-23cr-4sgi-gjn9',
#    '00000000-0000-0000-7646-94A5556776BE',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2023-11-30T00:00:00',
#    'Kings',
#    'CA',
#    'Passenger',
#    '2',
#    '2',
#    '4',
#    '262',
#    '266',
#    '1.503759398496240601503759398'],
#   ['row-isfk~zcct-yjkq',
#    '00000000-0000-0000-46FA-3B3B661FB277',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2022-12-31T00:00:00',
#    'Nueces',
#    'TX',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '52',
#    '53',
#    '1.886792452830188679245283019'],
#   ['row-8vca~ebdf~av7j',
#    '00000000-0000-0000-BFAB-660C727374EB',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2023-05-31T00:00:00',
#    'Charleston',
#    'SC',
#    'Passenger',
#    '1',
#    '2',
#    '3',
#    '55',
#    '58',
#    '5.172413793103448275862068966'],
#   ['row-sy9m-yc5b_8y6b',
#    '00000000-0000-0000-D15F-3E55AA7E8E69',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2019-03-31T00:00:00',
#    'Franklin',
#    'MA',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '1',
#    '2',
#    '50.0'],
#   ['row-w79z_qnkx_xidb',
#    '00000000-0000-0000-AEEC-05F2355A735C',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2017-01-31T00:00:00',
#    'San Diego',
#    'CA',
#    'Passenger',
#    '4',
#    '2',
#    '6',
#    '2894',
#    '2900',
#    '0.2068965517241379310344827586'],
#   ['row-sqfm.iine_mrqt',
#    '00000000-0000-0000-BD6C-96DC5E6470D8',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-04-30T00:00:00',
#    'Chesapeake',
#    'VA',
#    'Passenger',
#    '0',
#    '2',
#    '2',
#    '408',
#    '410',
#    '0.4878048780487804878048780488'],
#   ['row-87rn-426k~7xhp',
#    '00000000-0000-0000-C92F-58F344458EFC',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2023-02-28T00:00:00',
#    'Douglas',
#    'WA',
#    'Truck',
#    '6',
#    '0',
#    '6',
#    '12881',
#    '12887',
#    '0.04655854737332195235508652130'],
#   ['row-k7gy-i55t~i96x',
#    '00000000-0000-0000-03CD-47307BC9416F',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2019-01-31T00:00:00',
#    'Franklin',
#    'WA',
#    'Passenger',
#    '49',
#    '68',
#    '117',
#    '59313',
#    '59430',
#    '0.1968702675416456335184250379'],
#   ['row-9kcm~8rte.7jgd',
#    '00000000-0000-0000-E980-0F6F176A5B32',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2023-02-28T00:00:00',
#    'Klickitat',
#    'WA',
#    'Truck',
#    '4',
#    '0',
#    '4',
#    '8272',
#    '8276',
#    '0.04833252779120347994200096665'],
#   ['row-imjn-qy9g-mv7s',
#    '00000000-0000-0000-D87B-976F06EC5E33',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2023-07-31T00:00:00',
#    'Clallam',
#    'WA',
#    'Passenger',
#    '569',
#    '293',
#    '862',
#    '49023',
#    '49885',
#    '1.727974340984263806755537737'],
#   ['row-4fn6-5ptw.vqng',
#    '00000000-0000-0000-698D-42D93CE676A9',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-09-30T00:00:00',
#    'Pacific',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '7994',
#    '7994',
#    '0'],
#   ['row-hse4~rgmc_d3nd',
#    '00000000-0000-0000-5B04-45532D3BE64B',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2018-04-30T00:00:00',
#    'Lincoln',
#    'WA',
#    'Passenger',
#    '2',
#    '6',
#    '8',
#    '7613',
#    '7621',
#    '0.1049731006429602414381314788'],
#   ['row-s3yg-yx25.dnv2',
#    '00000000-0000-0000-13E7-931E51E649CD',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2019-11-30T00:00:00',
#    'Cochise',
#    'AZ',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '102',
#    '103',
#    '0.9708737864077669902912621359'],
#   ['row-ddnn-psrx_kpni',
#    '00000000-0000-0000-A97A-7E183C1A4CAF',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2017-01-31T00:00:00',
#    'Monterey',
#    'CA',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '234',
#    '235',
#    '0.4255319148936170212765957447'],
#   ['row-dud5_3eee~24y4',
#    '00000000-0000-0000-F937-B997E8495443',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2020-08-31T00:00:00',
#    'DuPage',
#    'IL',
#    'Passenger',
#    '4',
#    '0',
#    '4',
#    '60',
#    '64',
#    '6.2500'],
#   ['row-dnwa.peqv~87yc',
#    '00000000-0000-0000-3FF1-B1B49B27D77F',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2018-06-30T00:00:00',
#    'Utah',
#    'UT',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '140',
#    '141',
#    '0.7092198581560283687943262411'],
#   ['row-svrf.89qk_me7z',
#    '00000000-0000-0000-8567-4BA08279D5FE',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-11-30T00:00:00',
#    'Anchorage',
#    'AK',
#    'Passenger',
#    '2',
#    '0',
#    '2',
#    '138',
#    '140',
#    '1.428571428571428571428571429'],
#   ['row-gbaw-4b2x-hzpm',
#    '00000000-0000-0000-6465-9C518166657D',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2022-07-31T00:00:00',
#    'Ulster',
#    'NY',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '12',
#    '13',
#    '7.692307692307692307692307692'],
#   ['row-2g6q.rygn.4rhi',
#    '00000000-0000-0000-4484-48B11A90F943',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2022-12-31T00:00:00',
#    'Ray',
#    'MO',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '1',
#    '2',
#    '50.0'],
#   ['row-395b-27ue-e3t5',
#    '00000000-0000-0000-16D5-E86DEF399F32',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-08-31T00:00:00',
#    'Bartow',
#    'GA',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '5',
#    '6',
#    '16.66666666666666666666666667'],
#   ['row-5smx_43a6-crkm',
#    '00000000-0000-0000-F71F-1F1E5E19097A',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2020-12-31T00:00:00',
#    'Prince William',
#    'VA',
#    'Passenger',
#    '1',
#    '3',
#    '4',
#    '221',
#    '225',
#    '1.777777777777777777777777778'],
#   ['row-6qpf~s9k7~cet4',
#    '00000000-0000-0000-D776-AC7A90C2140D',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2018-03-31T00:00:00',
#    'Orange',
#    'FL',
#    'Passenger',
#    '2',
#    '1',
#    '3',
#    '170',
#    '173',
#    '1.734104046242774566473988439'],
#   ['row-n3ue.3cjn_g4j5',
#    '00000000-0000-0000-7DFE-6A95D1559700',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2022-06-30T00:00:00',
#    'Kitsap',
#    'WA',
#    'Passenger',
#    '2390',
#    '1053',
#    '3443',
#    '178314',
#    '181757',
#    '1.894287427719427587383154431'],
#   ['row-5fq9~mrhc.gz6e',
#    '00000000-0000-0000-4151-5F29A4199D5F',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2019-01-31T00:00:00',
#    'King',
#    'WA',
#    'Passenger',
#    '17166',
#    '6678',
#    '23844',
#    '1380645',
#    '1404489',
#    '1.697699305583738996887836074'],
#   ['row-upzp.i4r7~89j9',
#    '00000000-0000-0000-5726-3D401EADA21F',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2017-12-31T00:00:00',
#    'Columbia',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '1541',
#    '1541',
#    '0'],
#   ['row-86bc-yaqm~3vmc',
#    '00000000-0000-0000-0B53-96389CAEC437',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2024-01-31T00:00:00',
#    'Clark',
#    'WA',
#    'Passenger',
#    '7318',
#    '2683',
#    '10001',
#    '310003',
#    '320004',
#    '3.125273434082073974075324058'],
#   ['row-qfwf.p4b3-pde5',
#    '00000000-0000-0000-1220-BF0F2C48055C',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2024-03-31T00:00:00',
#    None,
#    None,
#    'Passenger',
#    '3',
#    '0',
#    '3',
#    '212',
#    '215',
#    '1.395348837209302325581395349'],
#   ['row-5xw9.p9wc~ryj5',
#    '00000000-0000-0000-A072-16E71DA612FC',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2020-03-31T00:00:00',
#    'Vigo',
#    'IN',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '5',
#    '6',
#    '16.66666666666666666666666667'],
#   ['row-b2zz-vjmj~w5ip',
#    '00000000-0000-0000-DF46-1D1D8FE21299',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-03-31T00:00:00',
#    'Suffolk',
#    'MA',
#    'Passenger',
#    '0',
#    '2',
#    '2',
#    '34',
#    '36',
#    '5.555555555555555555555555556'],
#   ['row-fq7c~yxk2-k5vj',
#    '00000000-0000-0000-A866-BA6B453EE55B',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2022-11-30T00:00:00',
#    'Travis',
#    'TX',
#    'Passenger',
#    '3',
#    '0',
#    '3',
#    '104',
#    '107',
#    '2.803738317757009345794392523'],
#   ['row-cmt2-wjgk~2sxv',
#    '00000000-0000-0000-43A8-E2A2B184EDDA',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-03-31T00:00:00',
#    'Bexar',
#    'TX',
#    'Passenger',
#    '3',
#    '5',
#    '8',
#    '581',
#    '589',
#    '1.358234295415959252971137521'],
#   ['row-ar2x_67jp~mkkc',
#    '00000000-0000-0000-F71C-07F501F3412C',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2022-11-30T00:00:00',
#    'Allen',
#    'IN',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '18',
#    '19',
#    '5.263157894736842105263157895'],
#   ['row-bxgf~f3cd-7kdg',
#    '00000000-0000-0000-B8DC-5623591E6E53',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-12-31T00:00:00',
#    'Lake',
#    'IN',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '9',
#    '10',
#    '10.0'],
#   ['row-993f-f5a6_2zua',
#    '00000000-0000-0000-8C68-CA7F48366A7E',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2020-01-31T00:00:00',
#    'Lake',
#    'FL',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '24',
#    '25',
#    '4.00'],
#   ['row-itiz_as4v_iisu',
#    '00000000-0000-0000-3611-8B0B7F25C01E',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2018-06-30T00:00:00',
#    'Clark',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '79112',
#    '79112',
#    '0'],
#   ['row-pcv3~nehj-k8te',
#    '00000000-0000-0000-8FCC-7A8D5B50514A',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-08-31T00:00:00',
#    'Stevens',
#    'WA',
#    'Passenger',
#    '49',
#    '44',
#    '93',
#    '30262',
#    '30355',
#    '0.3063745676165376379509141822'],
#   ['row-drti-nxq3_se4r',
#    '00000000-0000-0000-EE54-C0819DEDF80F',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2019-12-31T00:00:00',
#    'King',
#    'WA',
#    'Truck',
#    '6',
#    '1',
#    '7',
#    '182180',
#    '182187',
#    '0.003842206084956665404227524467'],
#   ['row-mxzf.jtx4~czek',
#    '00000000-0000-0000-08F6-0859252768C5',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2023-06-30T00:00:00',
#    'Mason',
#    'WA',
#    'Truck',
#    '11',
#    '0',
#    '11',
#    '20726',
#    '20737',
#    '0.05304528138110623523171143367'],
#   ['row-fmt8-rvqq-rit7',
#    '00000000-0000-0000-5C38-B958DBC2D7FA',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-11-30T00:00:00',
#    'Santa Cruz',
#    'CA',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '28',
#    '29',
#    '3.448275862068965517241379310'],
#   ['row-iyby-b8f6~hzgp',
#    '00000000-0000-0000-E74B-DE1F0E663386',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-11-30T00:00:00',
#    'Charleston',
#    'SC',
#    'Passenger',
#    '2',
#    '1',
#    '3',
#    '83',
#    '86',
#    '3.488372093023255813953488372'],
#   ['row-jq8k~656a_4aui',
#    '00000000-0000-0000-F962-D5E062DD79E8',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2017-07-31T00:00:00',
#    'Hardin',
#    'KY',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '116',
#    '117',
#    '0.8547008547008547008547008547'],
#   ['row-ke29-gfmg.zh5d',
#    '00000000-0000-0000-A664-AB319C889D6A',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2022-08-31T00:00:00',
#    'Providence',
#    'RI',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '21',
#    '22',
#    '4.545454545454545454545454545'],
#   ['row-kxer_euki_5a4b',
#    '00000000-0000-0000-8F0F-97DCB71814A6',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2020-06-30T00:00:00',
#    'Hamilton',
#    'IN',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '42',
#    '43',
#    '2.325581395348837209302325581'],
#   ['row-wei2~xwb6_kmts',
#    '00000000-0000-0000-4ABD-803D20B2E321',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-04-30T00:00:00',
#    'Hawaii',
#    'HI',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '55',
#    '56',
#    '1.785714285714285714285714286'],
#   ['row-dr72.8bis-ip2w',
#    '00000000-0000-0000-2D22-0369054E54E0',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2022-09-30T00:00:00',
#    'Kootenai',
#    'ID',
#    'Truck',
#    '1',
#    '0',
#    '1',
#    '36',
#    '37',
#    '2.702702702702702702702702703'],
#   ['row-etqk.piau_s7im',
#    '00000000-0000-0000-1C98-477CD991B094',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-05-31T00:00:00',
#    'Sumter',
#    'FL',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '10',
#    '11',
#    '9.090909090909090909090909091'],
#   ['row-87qe-nne2-fk2z',
#    '00000000-0000-0000-B976-07AD95984F2F',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2020-10-31T00:00:00',
#    'Dallas',
#    'IA',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '10',
#    '11',
#    '9.090909090909090909090909091'],
#   ['row-y9ui-sy83_mfc9',
#    '00000000-0000-0000-E849-4D83104AA550',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2018-04-30T00:00:00',
#    'Lake',
#    'CA',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '8',
#    '9',
#    '11.11111111111111111111111111'],
#   ['row-nkis_6dp9.6maz',
#    '00000000-0000-0000-8205-24559E62B45A',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2017-05-31T00:00:00',
#    'DeKalb',
#    'IN',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '1',
#    '2',
#    '50.0'],
#   ['row-y3zh.8kpi~y3f6',
# ...
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2024-03-31T00:00:00',
#    'York',
#    'VA',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '59',
#    '60',
#    '1.666666666666666666666666667'],
#   ['row-4axx.f5q4-6j2t',
#    '00000000-0000-0000-6C40-E82B473DD7EF',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2022-03-31T00:00:00',
#    'Fairbanks North Star',
#    'AK',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '80',
#    '81',
#    '1.234567901234567901234567901'],
#   ['row-rvid~drya~twy8',
#    '00000000-0000-0000-C21C-355BF8AB69EC',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2022-02-28T00:00:00',
#    'Rock Island',
#    'IL',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '15',
#    '16',
#    '6.2500'],
#   ['row-zttt.sd9m.3qmr',
#    '00000000-0000-0000-36B6-7D5646AB56F1',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-11-30T00:00:00',
#    'Skagit',
#    'WA',
#    'Passenger',
#    '666',
#    '299',
#    '965',
#    '91247',
#    '92212',
#    '1.046501539929727150479330239'],
#   ['row-jpy5~ft5f.ms6h',
#    '00000000-0000-0000-D1A2-766FEDD1520E',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2019-05-31T00:00:00',
#    'Fulton',
#    'GA',
#    'Passenger',
#    '1',
#    '3',
#    '4',
#    '110',
#    '114',
#    '3.508771929824561403508771930'],
#   ['row-ty4g_crxr-fy4f',
#    '00000000-0000-0000-D7D6-CCB8C939BFCA',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2022-11-30T00:00:00',
#    'Walla Walla',
#    'WA',
#    'Truck',
#    '3',
#    '0',
#    '3',
#    '13909',
#    '13912',
#    '0.02156411730879815986198964922'],
#   ['row-ui3y-zuyr_5sud',
#    '00000000-0000-0000-D832-E629442D3B0B',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2022-10-31T00:00:00',
#    'Providence',
#    'RI',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '20',
#    '21',
#    '4.761904761904761904761904762'],
#   ['row-p8uy~h4fd.f7pc',
#    '00000000-0000-0000-0439-0F4AC4088230',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2018-07-31T00:00:00',
#    'Pierce',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '138039',
#    '138039',
#    '0'],
#   ['row-9a9a-akne~q3h5',
#    '00000000-0000-0000-EF15-2E4BD2784F5B',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2019-08-31T00:00:00',
#    'Riverside',
#    'CA',
#    'Passenger',
#    '3',
#    '2',
#    '5',
#    '654',
#    '659',
#    '0.7587253414264036418816388467'],
#   ['row-hq2s~tsvf-3yv4',
#    '00000000-0000-0000-F8FE-AFD66C0590DA',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-12-31T00:00:00',
#    'Honolulu',
#    'HI',
#    'Passenger',
#    '4',
#    '4',
#    '8',
#    '394',
#    '402',
#    '1.990049751243781094527363184'],
#   ['row-w5cy-7kk5.fzwr',
#    '00000000-0000-0000-940A-663B93E49E49',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-12-31T00:00:00',
#    'Alameda',
#    'CA',
#    'Passenger',
#    '5',
#    '0',
#    '5',
#    '228',
#    '233',
#    '2.145922746781115879828326180'],
#   ['row-pwzx_w4r6_nr52',
#    '00000000-0000-0000-4EC7-ADC5E089C207',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2022-04-30T00:00:00',
#    'Nassau',
#    'NY',
#    'Passenger',
#    '3',
#    '0',
#    '3',
#    '35',
#    '38',
#    '7.894736842105263157894736842'],
#   ['row-ayka~5q9r-d9bu',
#    '00000000-0000-0000-6AE8-870135064906',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2017-02-28T00:00:00',
#    'Jackson',
#    'MO',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '73',
#    '74',
#    '1.351351351351351351351351351'],
#   ['row-svam.uyue-zj2k',
#    '00000000-0000-0000-4E19-72D36F1CE19A',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2020-12-31T00:00:00',
#    'Stevens',
#    'WA',
#    'Passenger',
#    '37',
#    '40',
#    '77',
#    '30216',
#    '30293',
#    '0.2541841349486680091110157462'],
#   ['row-ebsi_8mzy~msrj',
#    '00000000-0000-0000-EC6F-8C0AB44AC625',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-05-31T00:00:00',
#    'Virginia Beach',
#    'VA',
#    'Passenger',
#    '2',
#    '0',
#    '2',
#    '621',
#    '623',
#    '0.3210272873194221508828250401'],
#   ['row-49h6.rdss-idwy',
#    '00000000-0000-0000-1D3C-7CBC3CC5F03B',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2020-01-31T00:00:00',
#    'Columbia',
#    'WA',
#    'Passenger',
#    '3',
#    '3',
#    '6',
#    '2448',
#    '2454',
#    '0.2444987775061124694376528117'],
#   ['row-af2g.ysur.yr54',
#    '00000000-0000-0000-48CC-5207CBDC08D9',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2020-11-30T00:00:00',
#    'Douglas',
#    'NE',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '52',
#    '53',
#    '1.886792452830188679245283019'],
#   ['row-waen_7xna~9fn4',
#    '00000000-0000-0000-A30A-0CB46F9C6703',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2020-04-30T00:00:00',
#    'Randolph',
#    'NC',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '8',
#    '9',
#    '11.11111111111111111111111111'],
#   ['row-k66g_53hh-gdgk',
#    '00000000-0000-0000-3061-7D80988BF7AE',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-06-30T00:00:00',
#    'Benton',
#    'WA',
#    'Passenger',
#    '516',
#    '393',
#    '909',
#    '136335',
#    '137244',
#    '0.6623240360234327183702019760'],
#   ['row-23ik_zxx7_ff9a',
#    '00000000-0000-0000-D541-F7CBFDF314CE',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-12-31T00:00:00',
#    'Kittitas',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '14796',
#    '14796',
#    '0'],
#   ['row-p8qq~zjvz-9dvg',
#    '00000000-0000-0000-C5D7-9A45C928073E',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2023-01-31T00:00:00',
#    'Galveston',
#    'TX',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '18',
#    '19',
#    '5.263157894736842105263157895'],
#   ['row-pn7r.vuk2.zwg5',
#    '00000000-0000-0000-C42D-9DC3F4542DC5',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2018-07-31T00:00:00',
#    'Queens',
#    'NY',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '62',
#    '63',
#    '1.587301587301587301587301587'],
#   ['row-stpk-68si.sxqs',
#    '00000000-0000-0000-C24B-49BA56B86BFF',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2023-01-31T00:00:00',
#    'St. Louis',
#    'MO',
#    'Passenger',
#    '2',
#    '0',
#    '2',
#    '59',
#    '61',
#    '3.278688524590163934426229508'],
#   ['row-mkfg~gvi4-pjdi',
#    '00000000-0000-0000-98C9-598066C5D524',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2024-01-31T00:00:00',
#    'Santa Cruz',
#    'CA',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '20',
#    '21',
#    '4.761904761904761904761904762'],
#   ['row-rb6g_wbhj-uqq4',
#    '00000000-0000-0000-A3D2-1DE1106390B6',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2023-11-30T00:00:00',
#    'Santa Clara',
#    'CA',
#    'Passenger',
#    '12',
#    '2',
#    '14',
#    '147',
#    '161',
#    '8.695652173913043478260869565'],
#   ['row-m4yc_dbdg~8ywe',
#    '00000000-0000-0000-E79A-657AD31C9B29',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2024-02-29T00:00:00',
#    'Sarasota',
#    'FL',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '20',
#    '21',
#    '4.761904761904761904761904762'],
#   ['row-pqw5~e8ym.84vy',
#    '00000000-0000-0000-0B69-A70C82DF1E63',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2019-12-31T00:00:00',
#    'Bucks',
#    'PA',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '23',
#    '24',
#    '4.166666666666666666666666667'],
#   ['row-uwsw.kn3x_gwm7',
#    '00000000-0000-0000-8161-8AADF34B2018',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-07-31T00:00:00',
#    'Hanover',
#    'VA',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '1',
#    '2',
#    '50.0'],
#   ['row-c9qc~dz4z~gfhb',
#    '00000000-0000-0000-060F-DBB492C0AF2D',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-11-30T00:00:00',
#    'Virginia Beach',
#    'VA',
#    'Passenger',
#    '2',
#    '0',
#    '2',
#    '575',
#    '577',
#    '0.3466204506065857885615251300'],
#   ['row-q6x8.gcit.3qqx',
#    '00000000-0000-0000-E4C2-CFA71F7BBC5D',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2023-05-31T00:00:00',
#    'Muscogee',
#    'GA',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '98',
#    '99',
#    '1.010101010101010101010101010'],
#   ['row-ivcx_zv4a_mrdy',
#    '00000000-0000-0000-499E-2E4BD1CD0FA0',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2023-03-31T00:00:00',
#    'Hudson',
#    'NJ',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '23',
#    '24',
#    '4.166666666666666666666666667'],
#   ['row-ux68_svaq_a5wx',
#    '00000000-0000-0000-6D46-3517AFEFE810',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2019-09-30T00:00:00',
#    'Nassau',
#    'NY',
#    'Passenger',
#    '4',
#    '0',
#    '4',
#    '41',
#    '45',
#    '8.888888888888888888888888889'],
#   ['row-979e-r3ru.nyiy',
#    '00000000-0000-0000-A3B3-97DE19C31E87',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2018-05-31T00:00:00',
#    'Beaufort',
#    'SC',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '40',
#    '41',
#    '2.439024390243902439024390244'],
#   ['row-7x5d~x38b-gad5',
#    '00000000-0000-0000-9FA8-C42A19D735AB',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-12-31T00:00:00',
#    'Carroll',
#    'NH',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '5',
#    '6',
#    '16.66666666666666666666666667'],
#   ['row-7459~pnjr~p992',
#    '00000000-0000-0000-31F7-442227F2D9E9',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2017-06-30T00:00:00',
#    'Anne Arundel',
#    'MD',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '498',
#    '499',
#    '0.2004008016032064128256513026'],
#   ['row-u8ni~68p8.p6ya',
#    '00000000-0000-0000-4652-F52E0602BA09',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2019-01-31T00:00:00',
#    'Travis',
#    'TX',
#    'Passenger',
#    '3',
#    '1',
#    '4',
#    '213',
#    '217',
#    '1.843317972350230414746543779'],
#   ['row-g7ri-jhix~suyk',
#    '00000000-0000-0000-2CDF-FD79D8270BDB',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-04-30T00:00:00',
#    'Harris',
#    'TX',
#    'Passenger',
#    '1',
#    '1',
#    '2',
#    '234',
#    '236',
#    '0.8474576271186440677966101695'],
#   ['row-s4yf~2423-cysh',
#    '00000000-0000-0000-2005-905348DD0E23',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2019-09-30T00:00:00',
#    'Houston',
#    'GA',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '58',
#    '59',
#    '1.694915254237288135593220339'],
#   ['row-hcu8_2ssr_6nfq',
#    '00000000-0000-0000-35B0-1BE12F2C8DE3',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2017-05-31T00:00:00',
#    'Albemarle',
#    'VA',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '31',
#    '32',
#    '3.12500'],
#   ['row-uhy2-je4i_risj',
#    '00000000-0000-0000-4BFA-C0DBA080DB38',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2017-10-31T00:00:00',
#    'Monterey',
#    'CA',
#    'Passenger',
#    '0',
#    '2',
#    '2',
#    '194',
#    '196',
#    '1.020408163265306122448979592'],
#   ['row-ws9i-at96-jjim',
#    '00000000-0000-0000-1BEA-6E51CBCFA6AD',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2017-05-31T00:00:00',
#    'Alameda',
#    'CA',
#    'Passenger',
#    '1',
#    '1',
#    '2',
#    '376',
#    '378',
#    '0.5291005291005291005291005291'],
#   ['row-wqen_e52h.diwk',
#    '00000000-0000-0000-D5AE-CBA40EE5F73A',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2022-01-31T00:00:00',
#    'Duval',
#    'FL',
#    'Passenger',
#    '0',
#    '2',
#    '2',
#    '321',
#    '323',
#    '0.6191950464396284829721362229'],
#   ['row-jcrw.5mtm~mfhc',
#    '00000000-0000-0000-C191-C33CC2BB7269',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-09-30T00:00:00',
#    'Nueces',
#    'TX',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '67',
#    '68',
#    '1.470588235294117647058823529'],
#   ['row-zvs5~3378.yesc',
#    '00000000-0000-0000-3A5D-7025275F1E2A',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2023-12-31T00:00:00',
#    'Stafford',
#    'VA',
#    'Passenger',
#    '3',
#    '0',
#    '3',
#    '72',
#    '75',
#    '4.00'],
#   ['row-uhhn.jg3n-gcew',
#    '00000000-0000-0000-67B1-8F175802FE2E',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2022-06-30T00:00:00',
#    'Riverside',
#    'CA',
#    'Passenger',
#    '8',
#    '1',
#    '9',
#    '480',
#    '489',
#    '1.840490797546012269938650307'],
#   ['row-kikm.c4cv~rr2g',
#    '00000000-0000-0000-DCC8-2814EA9B913C',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-10-31T00:00:00',
#    'Clark',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '83992',
#    '83992',
#    '0'],
#   ['row-4pxv.w7vq_gvgx',
#    '00000000-0000-0000-A060-103D598389D3',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2022-06-30T00:00:00',
#    'Benton',
#    'WA',
#    'Truck',
#    '3',
#    '0',
#    '3',
#    '43557',
#    '43560',
#    '0.006887052341597796143250688705'],
#   ['row-b46j_s7xq-uwih',
#    '00000000-0000-0000-F076-6AB308A78396',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2023-06-30T00:00:00',
#    'Mason',
#    'WA',
#    'Passenger',
#    '445',
#    '206',
#    '651',
#    '46320',
#    '46971',
#    '1.385961550744076132081497094'],
#   ['row-r8ge_75qb_khhh',
#    '00000000-0000-0000-3E70-A62978D25CCD',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2017-09-30T00:00:00',
#    'District of Columbia',
#    'DC',
#    'Passenger',
#    '0',
#    '2',
#    '2',
#    '202',
#    '204',
#    '0.9803921568627450980392156863'],
#   ['row-r8dy~b8ee-rzvp',
#    '00000000-0000-0000-EAB8-AF2C49B1EC81',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2019-05-31T00:00:00',
#    'Ventura',
#    'CA',
#    'Passenger',
#    '0',
#    '2',
#    '2',
#    '321',
#    '323',
#    '0.6191950464396284829721362229'],
#   ['row-s48u-wkqs_5eut',
#    '00000000-0000-0000-C44B-A6854047720E',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2023-06-30T00:00:00',
#    'Jefferson',
#    'WA',
#    'Truck',
#    '12',
#    '0',
#    '12',
#    '9332',
#    '9344',
#    '0.1284246575342465753424657534'],
#   ['row-vxqe~47jp-vjsy',
#    '00000000-0000-0000-3E67-165BEBBACFAB',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2023-03-31T00:00:00',
#    'Wichita',
#    'TX',
#    'Passenger',
#    '2',
#    '0',
#    '2',
#    '39',
#    '41',
#    '4.878048780487804878048780488'],
#   ['row-kb8v.3erg.9kr8',
#    '00000000-0000-0000-97C5-EA771E7415E9',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2022-05-31T00:00:00',
#    'Hawaii',
#    'HI',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '42',
#    '43',
#    '2.325581395348837209302325581'],
#   ['row-r84x.pi6i.tvbr',
#    '00000000-0000-0000-15C6-86609149672A',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2019-10-31T00:00:00',
#    'Whitman',
#    'WA',
#    'Passenger',
#    '38',
#    '45',
#    '83',
#    '22706',
#    '22789',
#    '0.3642108034578085918644960288'],
#   ['row-wbui.g3wv_43hy',
#    '00000000-0000-0000-1EA3-CAAF05C150D5',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2023-07-31T00:00:00',
#    'Hennepin',
#    'MN',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '36',
#    '37',
#    '2.702702702702702702702702703'],
#   ['row-rc5z_2gvd-fz2c',
#    '00000000-0000-0000-8D71-AAC74D646345',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2023-05-31T00:00:00',
#    'Kittitas',
#    'WA',
#    'Passenger',
#    '344',
#    '104',
#    '448',
#    '29417',
#    '29865',
#    '1.500083710028461409676879290'],
#   ['row-xz4e.wn69_rrxb',
#    '00000000-0000-0000-9145-3A7E2CBDE629',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2021-04-30T00:00:00',
#    'Lincoln',
#    'WA',
#    'Passenger',
#    '5',
#    '13',
#    '18',
#    '7749',
#    '7767',
#    '0.2317497103128621089223638470'],
#   ['row-r525-hxgn~6rdq',
#    '00000000-0000-0000-0376-466D3CC6F405',
#    0,
#    1713474420,
#    None,
#    1713474420,
#    None,
#    '{ }',
#    '2022-10-31T00:00:00',
#    'Cumberland',
#    'NC',
#    'Passenger',
#    '1',
#    '4',
#    '5',
#    '360',
#    '365',
#    '1.369863013698630136986301370'],
#   ...]}

# %% [markdown]
# **2. Se realiza exploración de datos simple y se lee Dataset mediante librería pandas, después de ordenarlo.**

# %%
newdata.keys()
# Out:
# dict_keys(['meta', 'data'])

# %%
newdata['meta']
# Out:
# {'view': {'id': '3d5d-sdqb',
#   'name': 'Electric Vehicle Population Size History By County',
#   'assetType': 'dataset',
#   'attribution': 'Washington State Department of Licensing',
#   'averageRating': 0,
#   'category': 'Transportation',
#   'createdAt': 1591046256,
#   'description': 'This shows the number of vehicles that were registered by Washington State Department of Licensing (DOL) each month. The data is separated by county for passenger vehicles and trucks. \n\nDOL integrates National Highway Traffic Safety Administration (NHTSA) data and the Environmental Protection Agency (EPA) fuel efficiency ratings with DOL titling and registration data to create this information.',
#   'displayType': 'table',
#   'downloadCount': 9921,
#   'hideFromCatalog': False,
#   'hideFromDataJson': False,
#   'licenseId': 'ODBL',
#   'locked': False,
#   'newBackend': True,
#   'numberOfComments': 0,
#   'oid': 34339220,
#   'provenance': 'official',
#   'publicationAppendEnabled': False,
#   'publicationDate': 1591379619,
#   'publicationGroup': 17186729,
#   'publicationStage': 'published',
#   'rowsUpdatedAt': 1713474423,
#   'rowsUpdatedBy': 'kgaq-6gwr',
#   'tableId': 17199524,
#   'totalTimesRated': 0,
#   'viewCount': 3777,
#   'viewLastModified': 1713474418,
#   'viewType': 'tabular',
#   'approvals': [{'reviewedAt': 1591380915,
#     'reviewedAutomatically': True,
#     'state': 'approved',
#     'submissionId': 2285192,
#     'submissionObject': 'public_audience_request',
#     'submissionOutcome': 'change_audience',
#     'submittedAt': 1591380915,
#     'targetAudience': 'public',
#     'workflowId': 2106,
#     'submissionDetails': {'permissionType': 'READ'},
#     'submissionOutcomeApplication': {'endedAt': 1591380916,
#      'failureCount': 0,
#      'startedAt': 1591380915,
#      'status': 'success'},
#     'submitter': {'id': 'dphz-szpx', 'displayName': 'Faith'}}],
#   'clientContext': {'clientContextVariables': [], 'inheritedVariables': {}},
#   'columns': [{'id': -1,
#     'name': 'sid',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':sid',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'id',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':id',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'position',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':position',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'created_at',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':created_at',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'created_meta',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':created_meta',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'updated_at',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':updated_at',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'updated_meta',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':updated_meta',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'meta',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':meta',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': 472621118,
#     'name': 'Date',
#     'dataTypeName': 'calendar_date',
#     'description': 'Counts of registered vehicles are taken on this day (the end of this month).',
#     'fieldName': 'date',
#     'position': 1,
#     'renderTypeName': 'calendar_date',
#     'tableColumnId': 103990567,
#     'cachedContents': {'non_null': '21207',
#      'largest': '2024-03-31T00:00:00.000',
#      'null': '0',
#      'top': [{'item': '2022-04-30T00:00:00.000', 'count': '285'},
#       {'item': '2022-11-30T00:00:00.000', 'count': '285'},
#       {'item': '2022-10-31T00:00:00.000', 'count': '284'},
#       {'item': '2022-03-31T00:00:00.000', 'count': '284'},
#       {'item': '2022-12-31T00:00:00.000', 'count': '283'},
#       {'item': '2023-02-28T00:00:00.000', 'count': '283'},
#       {'item': '2022-09-30T00:00:00.000', 'count': '283'},
#       {'item': '2022-02-28T00:00:00.000', 'count': '282'},
#       {'item': '2022-05-31T00:00:00.000', 'count': '282'},
#       {'item': '2023-01-31T00:00:00.000', 'count': '282'},
#       {'item': '2021-10-31T00:00:00.000', 'count': '281'},
#       {'item': '2023-03-31T00:00:00.000', 'count': '281'},
#       {'item': '2022-06-30T00:00:00.000', 'count': '281'},
#       {'item': '2023-04-30T00:00:00.000', 'count': '281'},
#       {'item': '2021-11-30T00:00:00.000', 'count': '280'},
#       {'item': '2022-01-31T00:00:00.000', 'count': '280'},
#       {'item': '2022-08-31T00:00:00.000', 'count': '279'},
#       {'item': '2023-05-31T00:00:00.000', 'count': '277'},
#       {'item': '2022-07-31T00:00:00.000', 'count': '277'},
#       {'item': '2021-12-31T00:00:00.000', 'count': '277'}],
#      'smallest': '2017-01-31T00:00:00.000',
#      'count': '21207',
#      'cardinality': '87'},
#     'format': {'view': 'date_monthdy'}},
#    {'id': 472621119,
#     'name': 'County',
#     'dataTypeName': 'text',
#     'description': "This is the geographic region of a state that a vehicle's owner is listed to reside within. Vehicles registered in Washington state may be located in other states.",
#     'fieldName': 'county',
#     'position': 2,
#     'renderTypeName': 'text',
#     'tableColumnId': 103990568,
#     'cachedContents': {'non_null': '21120',
#      'largest': 'Yuba',
#      'null': '87',
#      'top': [{'item': 'Douglas', 'count': '291'},
#       {'item': 'Montgomery', 'count': '288'},
#       {'item': 'Jefferson', 'count': '265'},
#       {'item': 'Clark', 'count': '261'},
#       {'item': 'Franklin', 'count': '221'},
#       {'item': 'Columbia', 'count': '221'},
#       {'item': 'Orange', 'count': '203'},
#       {'item': 'Adams', 'count': '199'},
#       {'item': 'Lincoln', 'count': '197'},
#       {'item': 'Garfield', 'count': '193'},
#       {'item': 'San Juan', 'count': '185'},
#       {'item': 'Lewis', 'count': '178'},
#       {'item': 'Whatcom', 'count': '174'},
#       {'item': 'Pierce', 'count': '174'},
#       {'item': 'Grays Harbor', 'count': '174'},
#       {'item': 'Klickitat', 'count': '174'},
#       {'item': 'Asotin', 'count': '174'},
#       {'item': 'Grant', 'count': '174'},
#       {'item': 'Stevens', 'count': '174'},
#       {'item': 'Skagit', 'count': '174'}],
#      'smallest': 'Ada',
#      'count': '21207',
#      'cardinality': '313'},
#     'format': {}},
#    {'id': 472621120,
#     'name': 'State',
#     'dataTypeName': 'text',
#     'description': 'This is the geographic region of the country associated with the record. These addresses may be located in other states.',
#     'fieldName': 'state',
#     'position': 3,
#     'renderTypeName': 'text',
#     'tableColumnId': 103990558,
#     'cachedContents': {'non_null': '21120',
#      'largest': 'WY',
#      'null': '87',
#      'top': [{'item': 'WA', 'count': '6786'},
#       {'item': 'CA', 'count': '1685'},
#       {'item': 'VA', 'count': '1309'},
#       {'item': 'FL', 'count': '1109'},
#       {'item': 'TX', 'count': '1083'},
#       {'item': 'MD', 'count': '772'},
#       {'item': 'OR', 'count': '540'},
#       {'item': 'CO', 'count': '511'},
#       {'item': 'GA', 'count': '488'},
#       {'item': 'NC', 'count': '460'},
#       {'item': 'NY', 'count': '414'},
#       {'item': 'NJ', 'count': '378'},
#       {'item': 'IL', 'count': '377'},
#       {'item': 'ID', 'count': '317'},
#       {'item': 'HI', 'count': '305'},
#       {'item': 'AZ', 'count': '304'},
#       {'item': 'SC', 'count': '295'},
#       {'item': 'MA', 'count': '286'},
#       {'item': 'PA', 'count': '276'},
#       {'item': 'MO', 'count': '265'}],
#      'smallest': 'AK',
#      'count': '21207',
#      'cardinality': '50'},
#     'format': {}},
#    {'id': 472621121,
#     'name': 'Vehicle Primary Use',
#     'dataTypeName': 'text',
#     'description': 'This describes the primary intended use of the vehicle.',
#     'fieldName': 'vehicle_primary_use',
#     'position': 4,
#     'renderTypeName': 'text',
#     'tableColumnId': 104001400,
#     'cachedContents': {'non_null': '21207',
#      'largest': 'Truck',
#      'null': '0',
#      'top': [{'item': 'Passenger', 'count': '17721'},
#       {'item': 'Truck', 'count': '3486'}],
#      'smallest': 'Passenger',
#      'count': '21207',
#      'cardinality': '2'},
#     'format': {}},
#    {'id': 472621122,
#     'name': 'Battery Electric Vehicles (BEVs)',
#     'dataTypeName': 'number',
#     'description': 'The count of vehicles that are known to be propelled solely by an energy derived from an onboard electric battery.',
#     'fieldName': 'battery_electric_vehicles_bevs_',
#     'position': 5,
#     'renderTypeName': 'number',
#     'tableColumnId': 104001399,
#     'cachedContents': {'non_null': '21207',
#      'largest': '73550',
#      'null': '0',
#      'top': [{'item': '1', 'count': '7054'},
#       {'item': '0', 'count': '6870'},
#       {'item': '2', 'count': '1769'},
#       {'item': '3', 'count': '810'},
#       {'item': '4', 'count': '425'},
#       {'item': '5', 'count': '316'},
#       {'item': '6', 'count': '210'},
#       {'item': '7', 'count': '167'},
#       {'item': '8', 'count': '140'},
#       {'item': '9', 'count': '81'},
#       {'item': '10', 'count': '68'},
#       {'item': '12', 'count': '68'},
#       {'item': '17', 'count': '49'},
#       {'item': '11', 'count': '48'},
#       {'item': '19', 'count': '42'},
#       {'item': '16', 'count': '40'},
#       {'item': '18', 'count': '38'},
#       {'item': '21', 'count': '35'},
#       {'item': '20', 'count': '35'},
#       {'item': '23', 'count': '34'}],
#      'smallest': '0',
#      'count': '21207',
#      'cardinality': '1221'},
#     'format': {}},
#    {'id': 472621123,
#     'name': 'Plug-In Hybrid Electric Vehicles (PHEVs)',
#     'dataTypeName': 'number',
#     'description': 'The count of vehicles that are known to be propelled from energy partially sourced from an onboard electric battery that is capable of being recharged from an external source.',
#     'fieldName': 'plug_in_hybrid_electric_vehicles_phevs_',
#     'position': 6,
#     'renderTypeName': 'number',
#     'tableColumnId': 104001398,
#     'cachedContents': {'non_null': '21207',
#      'largest': '17935',
#      'null': '0',
#      'top': [{'item': '0', 'count': '10010'},
#       {'item': '1', 'count': '5735'},
#       {'item': '2', 'count': '1461'},
#       {'item': '3', 'count': '507'},
#       {'item': '4', 'count': '229'},
#       {'item': '5', 'count': '145'},
#       {'item': '6', 'count': '85'},
#       {'item': '7', 'count': '76'},
#       {'item': '12', 'count': '39'},
#       {'item': '8', 'count': '37'},
#       {'item': '9', 'count': '35'},
#       {'item': '11', 'count': '32'},
#       {'item': '19', 'count': '29'},
#       {'item': '17', 'count': '29'},
#       {'item': '21', 'count': '28'},
#       {'item': '33', 'count': '28'},
#       {'item': '22', 'count': '26'},
#       {'item': '10', 'count': '25'},
#       {'item': '26', 'count': '24'},
#       {'item': '20', 'count': '23'}],
#      'smallest': '0',
#      'count': '21207',
#      'cardinality': '944'},
#     'format': {}},
#    {'id': 472621124,
#     'name': 'Electric Vehicle (EV) Total',
#     'dataTypeName': 'number',
#     'description': 'The sum of Battery Electric Vehicles (BEVs) and Plug-in Hybrid Electric Vehicles (PHEVs).',
#     'fieldName': 'electric_vehicle_ev_total',
#     'position': 7,
#     'renderTypeName': 'number',
#     'tableColumnId': 103990566,
#     'cachedContents': {'non_null': '21207',
#      'largest': '91485',
#      'null': '0',
#      'top': [{'item': '1', 'count': '9510'},
#       {'item': '2', 'count': '2616'},
#       {'item': '0', 'count': '2270'},
#       {'item': '3', 'count': '1133'},
#       {'item': '4', 'count': '701'},
#       {'item': '5', 'count': '362'},
#       {'item': '6', 'count': '284'},
#       {'item': '7', 'count': '264'},
#       {'item': '8', 'count': '180'},
#       {'item': '9', 'count': '141'},
#       {'item': '10', 'count': '122'},
#       {'item': '12', 'count': '81'},
#       {'item': '11', 'count': '77'},
#       {'item': '13', 'count': '69'},
#       {'item': '14', 'count': '48'},
#       {'item': '15', 'count': '45'},
#       {'item': '19', 'count': '37'},
#       {'item': '16', 'count': '35'},
#       {'item': '17', 'count': '32'},
#       {'item': '18', 'count': '31'}],
#      'smallest': '0',
#      'count': '21207',
#      'cardinality': '1421'},
#     'format': {}},
#    {'id': 472621125,
#     'name': 'Non-Electric Vehicle Total',
#     'dataTypeName': 'number',
#     'description': 'The count of vehicles that are not electric vehicles.',
#     'fieldName': 'non_electric_vehicles',
#     'position': 8,
#     'renderTypeName': 'number',
#     'tableColumnId': 104098606,
#     'cachedContents': {'non_null': '21207',
#      'largest': '1399746',
#      'null': '0',
#      'top': [{'item': '1', 'count': '298'},
#       {'item': '4', 'count': '200'},
#       {'item': '5', 'count': '196'},
#       {'item': '6', 'count': '177'},
#       {'item': '3', 'count': '173'},
#       {'item': '0', 'count': '161'},
#       {'item': '11', 'count': '145'},
#       {'item': '13', 'count': '141'},
#       {'item': '20', 'count': '140'},
#       {'item': '12', 'count': '140'},
#       {'item': '7', 'count': '139'},
#       {'item': '18', 'count': '133'},
#       {'item': '8', 'count': '130'},
#       {'item': '21', 'count': '128'},
#       {'item': '39', 'count': '126'},
#       {'item': '9', 'count': '125'},
#       {'item': '14', 'count': '125'},
#       {'item': '10', 'count': '125'},
#       {'item': '23', 'count': '124'},
#       {'item': '32', 'count': '122'}],
#      'smallest': '0',
#      'count': '21207',
#      'cardinality': '7150'},
#     'format': {}},
#    {'id': 472621126,
#     'name': 'Total Vehicles',
#     'dataTypeName': 'number',
#     'description': 'All powered vehicles registered in the county. This includes electric vehicles.',
#     'fieldName': 'total_vehicles',
#     'position': 9,
#     'renderTypeName': 'number',
#     'tableColumnId': 104001397,
#     'cachedContents': {'non_null': '21207',
#      'largest': '1430861',
#      'null': '0',
#      'top': [{'item': '2', 'count': '298'},
#       {'item': '5', 'count': '200'},
#       {'item': '6', 'count': '196'},
#       {'item': '7', 'count': '177'},
#       {'item': '4', 'count': '173'},
#       {'item': '1', 'count': '161'},
#       {'item': '14', 'count': '146'},
#       {'item': '12', 'count': '136'},
#       {'item': '19', 'count': '136'},
#       {'item': '8', 'count': '135'},
#       {'item': '13', 'count': '134'},
#       {'item': '22', 'count': '133'},
#       {'item': '9', 'count': '130'},
#       {'item': '11', 'count': '130'},
#       {'item': '21', 'count': '126'},
#       {'item': '38', 'count': '124'},
#       {'item': '15', 'count': '123'},
#       {'item': '41', 'count': '119'},
#       {'item': '37', 'count': '119'},
#       {'item': '24', 'count': '117'}],
#      'smallest': '1',
#      'count': '21207',
#      'cardinality': '7155'},
#     'format': {}},
#    {'id': 472621127,
#     'name': 'Percent Electric Vehicles',
#     'dataTypeName': 'number',
#     'description': 'Comparison of electric vehicles versus their non-electric counterparts.',
#     'fieldName': 'percent_electric_vehicles',
#     'position': 10,
#     'renderTypeName': 'number',
#     'tableColumnId': 104099062,
#     'cachedContents': {'non_null': '21207',
#      'largest': '100',
#      'null': '0',
#      'top': [{'item': '0', 'count': '2270'},
#       {'item': '50.0', 'count': '298'},
#       {'item': '16.66666666666666666666666667', 'count': '203'},
#       {'item': '20.0', 'count': '202'},
#       {'item': '14.28571428571428571428571429', 'count': '201'},
#       {'item': '25.00', 'count': '175'},
#       {'item': '100', 'count': '161'},
#       {'item': '12.500', 'count': '158'},
#       {'item': '5.263157894736842105263157895', 'count': '151'},
#       {'item': '11.11111111111111111111111111', 'count': '146'},
#       {'item': '4.761904761904761904761904762', 'count': '142'},
#       {'item': '8.333333333333333333333333333', 'count': '141'},
#       {'item': '9.090909090909090909090909091', 'count': '138'},
#       {'item': '7.692307692307692307692307692', 'count': '135'},
#       {'item': '7.142857142857142857142857143', 'count': '134'},
#       {'item': '10.0', 'count': '134'},
#       {'item': '4.545454545454545454545454545', 'count': '128'},
#       {'item': '4.00', 'count': '125'},
#       {'item': '4.166666666666666666666666667', 'count': '123'},
#       {'item': '6.666666666666666666666666667', 'count': '123'}],
#      'smallest': '0',
#      'count': '21207',
#      'cardinality': '6343'},
#     'format': {'precision': '2'}}],
#   'grants': [{'inherited': False, 'type': 'viewer', 'flags': ['public']}],
#   'license': {'name': 'Open Data Commons Open Database License',
#    'termsLink': 'http://opendatacommons.org/licenses/odbl/1.0/'},
#   'metadata': {'custom_fields': {'Temporal': {'Posting Frequency': 'Monthly',
#      'Period of Time': 'Data includes historical Electric Vehicle population counts from January 2017 through March 2024.'},
#     'Identification': {'Originator': 'Research and Analysis Office, Department of Licensing',
#      'Metadata Language': 'English'},
#     'Notes': {'1. ': 'A Battery Electric Vehicle (BEV) is an all-electric vehicle using one or more batteries to store the electrical energy that powers the motor and is charged by plugging the vehicle in to an electric power source. A Plug-in Hybrid Electric Vehicle (PHEV) is a vehicle that uses one or more batteries to power an electric motor; uses another fuel, such as gasoline or diesel, to power an internal combustion engine or other propulsion source; and is charged by plugging the vehicle in to an electric power source.',
#      '2. ': 'Vehicles registered with a military installation address may not have an assigned county. These vehicles are not included in the final counts.',
#      '3. ': 'Monthly count of vehicles for a county may change from this report and prior reports. Processes were implemented to more accurately assign county at the time of registration.'}},
#    'rowLabel': 'Monthly count of vehicles for a county',
#    'availableDisplayTypes': ['table', 'fatrow', 'page']},
#   'owner': {'id': 'eagg-6py7',
#    'displayName': 'Department of Licensing',
#    'profileImageUrlLarge': '/api/users/eagg-6py7/profile_images/LARGE',
#    'profileImageUrlMedium': '/api/users/eagg-6py7/profile_images/THUMB',
#    'profileImageUrlSmall': '/api/users/eagg-6py7/profile_images/TINY',
#    'screenName': 'Department of Licensing',
#    'type': 'interactive',
#    'flags': ['acceptedEula', 'mayBeStoriesCoOwner']},
#   'query': {},
#   'rights': ['read'],
#   'tableAuthor': {'id': 'eagg-6py7',
#    'displayName': 'Department of Licensing',
#    'profileImageUrlLarge': '/api/users/eagg-6py7/profile_images/LARGE',
#    'profileImageUrlMedium': '/api/users/eagg-6py7/profile_images/THUMB',
#    'profileImageUrlSmall': '/api/users/eagg-6py7/profile_images/TINY',
#    'screenName': 'Department of Licensing',
#    'type': 'interactive',
#    'flags': ['acceptedEula', 'mayBeStoriesCoOwner']},
#   'tags': ['battery electric',
#    'bev',
#    'plug-in',
#    'hybrid',
#    'phev',
#    'electric',
#    'vehicle',
#    'clean energy',
#    'population growth',
#    'rao_open_data',
#    'dol_open_data',
#    'department of licensing',
#    'dol',
#    'rao_ev',
#    'rao_veh'],
#   'flags': ['default',
#    'ownerMayBeContacted',
#    'restorable',
#    'restorePossibleForType']}}

# %%
column = newdata['meta']['view']['columns'][8:][0]['name']
column
# Out:
# 'Date'

# %%
newdata['data']
# Out:
# [['row-txmj.9xki-teqc',
#   '00000000-0000-0000-3BEB-D46C134BD6D7',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-04-30T00:00:00',
#   'Wahkiakum',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '1815',
#   '1815',
#   '0'],
#  ['row-2h8w.5k3c~aukx',
#   '00000000-0000-0000-423F-847EA1E0E72A',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-05-31T00:00:00',
#   'Adams',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '5079',
#   '5079',
#   '0'],
#  ['row-3snj~v22r~5cky',
#   '00000000-0000-0000-8FE3-66BD5DC299BD',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-10-31T00:00:00',
#   'Collin',
#   'TX',
#   'Passenger',
#   '2',
#   '1',
#   '3',
#   '142',
#   '145',
#   '2.068965517241379310344827586'],
#  ['row-im3h-cypn_ycer',
#   '00000000-0000-0000-94D4-27279BD8C159',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2024-01-31T00:00:00',
#   'Franklin',
#   'WA',
#   'Truck',
#   '10',
#   '0',
#   '10',
#   '20616',
#   '20626',
#   '0.04848249781828759817705808203'],
#  ['row-756x_sycu_v9c6',
#   '00000000-0000-0000-B273-329343B58BB6',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2018-02-28T00:00:00',
#   'Grays Harbor',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '20109',
#   '20109',
#   '0'],
#  ['row-yedf~kh84-mf9e',
#   '00000000-0000-0000-56D5-5917329E6154',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-11-30T00:00:00',
#   'Chesterfield',
#   'VA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '37',
#   '38',
#   '2.631578947368421052631578947'],
#  ['row-2a7r_eheh~2y5u',
#   '00000000-0000-0000-AE6E-306DEC1D1AEE',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-05-31T00:00:00',
#   'Missoula',
#   'MT',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '64',
#   '65',
#   '1.538461538461538461538461538'],
#  ['row-zvrg-ix2n~npea',
#   '00000000-0000-0000-F9A7-7AB1A5832645',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-03-31T00:00:00',
#   'Harnett',
#   'NC',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '262',
#   '263',
#   '0.3802281368821292775665399240'],
#  ['row-ds88~i7fb.77d7',
#   '00000000-0000-0000-68B2-2D6D0D92CA12',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-12-31T00:00:00',
#   'Providence',
#   'RI',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '21',
#   '22',
#   '4.545454545454545454545454545'],
#  ['row-kfhg-9pzu~xqsc',
#   '00000000-0000-0000-C6E5-0977D930A0D2',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-12-31T00:00:00',
#   'Randolph',
#   'NC',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '6',
#   '7',
#   '14.28571428571428571428571429'],
#  ['row-f7tx_6det_5bet',
#   '00000000-0000-0000-185C-60FA95830FEF',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-04-30T00:00:00',
#   'Eagle',
#   'CO',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '8',
#   '9',
#   '11.11111111111111111111111111'],
#  ['row-ya7y-ntja.s2m7',
#   '00000000-0000-0000-2A19-BEFB1174511F',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2018-06-30T00:00:00',
#   'Cowlitz',
#   'WA',
#   'Passenger',
#   '55',
#   '74',
#   '129',
#   '71728',
#   '71857',
#   '0.1795232197280710299622862073'],
#  ['row-u5am_xr8h_kv8i',
#   '00000000-0000-0000-613C-2EEB1AFFF653',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-01-31T00:00:00',
#   'King',
#   'WA',
#   'Truck',
#   '14',
#   '1',
#   '15',
#   '182576',
#   '182591',
#   '0.008215081794831070534692290420'],
#  ['row-bidv~kvzb_v9cx',
#   '00000000-0000-0000-9BB7-795C1FFF0CF3',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-12-31T00:00:00',
#   'Pacific',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '7543',
#   '7543',
#   '0'],
#  ['row-mswt_8ttc-qzr3',
#   '00000000-0000-0000-5071-CE8BD824348C',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-12-31T00:00:00',
#   'Klickitat',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '8325',
#   '8325',
#   '0'],
#  ['row-wrbn.4f6b~bcuq',
#   '00000000-0000-0000-E796-2FDDCDEA0674',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2018-02-28T00:00:00',
#   'Fairfax',
#   'VA',
#   'Passenger',
#   '3',
#   '2',
#   '5',
#   '827',
#   '832',
#   '0.6009615384615384615384615385'],
#  ['row-wwik~nmux.xqc3',
#   '00000000-0000-0000-AE48-EB85C2C79A2F',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2018-08-31T00:00:00',
#   'Franklin',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '18790',
#   '18790',
#   '0'],
#  ['row-6j7y_jw8j-54yt',
#   '00000000-0000-0000-BE0F-202451102938',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-02-28T00:00:00',
#   'Sacramento',
#   'CA',
#   'Passenger',
#   '2',
#   '1',
#   '3',
#   '257',
#   '260',
#   '1.153846153846153846153846154'],
#  ['row-5sjt-i9dr-eyi5',
#   '00000000-0000-0000-2AB4-9388C78B0EE2',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-12-31T00:00:00',
#   'Calvert',
#   'MD',
#   'Passenger',
#   '0',
#   '2',
#   '2',
#   '90',
#   '92',
#   '2.173913043478260869565217391'],
#  ['row-8uuw.gkbq_isgs',
#   '00000000-0000-0000-8E30-9D7EC4A081A2',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-01-31T00:00:00',
#   'Fort Bend',
#   'TX',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '50',
#   '51',
#   '1.960784313725490196078431373'],
#  ['row-9h4h-gr92~rzyc',
#   '00000000-0000-0000-83FD-6FA3D1F9F10D',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-11-30T00:00:00',
#   'Placer',
#   'CA',
#   'Passenger',
#   '2',
#   '0',
#   '2',
#   '77',
#   '79',
#   '2.531645569620253164556962025'],
#  ['row-i98c-h8fy.jehm',
#   '00000000-0000-0000-74CC-93EF6F752865',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-04-30T00:00:00',
#   'Cascade',
#   'MT',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '61',
#   '62',
#   '1.612903225806451612903225806'],
#  ['row-p2h5-gemu.ww7j',
#   '00000000-0000-0000-5090-93AC82D7AF88',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-05-31T00:00:00',
#   'San Luis Obispo',
#   'CA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '61',
#   '62',
#   '1.612903225806451612903225806'],
#  ['row-nrjc_z94y~nsmi',
#   '00000000-0000-0000-D927-9ED5A7BC9D45',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-11-30T00:00:00',
#   'Montgomery',
#   'PA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '39',
#   '40',
#   '2.500'],
#  ['row-m7pi.bhjj_ebpn',
#   '00000000-0000-0000-7388-8508CCC658EF',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2018-01-31T00:00:00',
#   'Juneau',
#   'AK',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '43',
#   '44',
#   '2.272727272727272727272727273'],
#  ['row-fkig-4v5r-rruu',
#   '00000000-0000-0000-006F-EF016DE29069',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-09-30T00:00:00',
#   'Columbia',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '1536',
#   '1536',
#   '0'],
#  ['row-6ktq.d5ak_a6am',
#   '00000000-0000-0000-8D2F-962F74699A5A',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-04-30T00:00:00',
#   'Spokane',
#   'WA',
#   'Passenger',
#   '236',
#   '208',
#   '444',
#   '295711',
#   '296155',
#   '0.1499214938123617700190778477'],
#  ['row-bn27~4mie_hj45',
#   '00000000-0000-0000-596C-E44C644F7207',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-12-31T00:00:00',
#   'Benton',
#   'WA',
#   'Passenger',
#   '637',
#   '444',
#   '1081',
#   '136015',
#   '137096',
#   '0.7884985703448678298418626364'],
#  ['row-7tfa-szz4_mrth',
#   '00000000-0000-0000-7688-A3FD1D7CFDB9',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-01-31T00:00:00',
#   'Whitman',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '8569',
#   '8569',
#   '0'],
#  ['row-dqpf.byt7.684c',
#   '00000000-0000-0000-073E-11DEFD031A15',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-07-31T00:00:00',
#   'Clark',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '77725',
#   '77725',
#   '0'],
#  ['row-xxab~bnxr.5zrc',
#   '00000000-0000-0000-4B11-16FE2650115E',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-08-31T00:00:00',
#   'Williamson',
#   'TX',
#   'Passenger',
#   '0',
#   '2',
#   '2',
#   '82',
#   '84',
#   '2.380952380952380952380952381'],
#  ['row-u75k~nkbd.sefp',
#   '00000000-0000-0000-F7E2-FDACDB6DD328',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2024-01-31T00:00:00',
#   'Rockingham',
#   'NH',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '7',
#   '8',
#   '12.500'],
#  ['row-3ejr~949m.vt54',
#   '00000000-0000-0000-4CB5-A3BA6934526A',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2018-11-30T00:00:00',
#   'King',
#   'WA',
#   'Truck',
#   '6',
#   '1',
#   '7',
#   '182721',
#   '182728',
#   '0.003830830524057615691081826540'],
#  ['row-rjbn.sy83.pxmy',
#   '00000000-0000-0000-CC1B-8754850B8D19',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-02-28T00:00:00',
#   'San Francisco',
#   'CA',
#   'Passenger',
#   '1',
#   '1',
#   '2',
#   '102',
#   '104',
#   '1.923076923076923076923076923'],
#  ['row-s4j2.7y5i_ebtz',
#   '00000000-0000-0000-EB0C-24ABDFA8DBE2',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-09-30T00:00:00',
#   'Skagit',
#   'WA',
#   'Truck',
#   '1',
#   '0',
#   '1',
#   '32639',
#   '32640',
#   '0.003063725490196078431372549020'],
#  ['row-5ass~fuz9~nhnt',
#   '00000000-0000-0000-24AE-20DF420C25B5',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2024-01-31T00:00:00',
#   'King',
#   'WA',
#   'Truck',
#   '1110',
#   '2',
#   '1112',
#   '170380',
#   '171492',
#   '0.6484267487696219065612390082'],
#  ['row-vb4v.4yqc~bnrc',
#   '00000000-0000-0000-ED93-BDBF40530FB5',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-02-28T00:00:00',
#   'Salt Lake',
#   'UT',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '333',
#   '334',
#   '0.2994011976047904191616766467'],
#  ['row-qy6r.fezy_zdjy',
#   '00000000-0000-0000-997C-6A058B9D7E38',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-11-30T00:00:00',
#   'Missoula',
#   'MT',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '66',
#   '67',
#   '1.492537313432835820895522388'],
#  ['row-gwaw_tp27~e59d',
#   '00000000-0000-0000-B62D-195B4CA301C9',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-08-31T00:00:00',
#   'Columbia',
#   'OR',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '26',
#   '27',
#   '3.703703703703703703703703704'],
#  ['row-2cyh~6m3f~x98a',
#   '00000000-0000-0000-ACFE-3C94E8F41D82',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-09-30T00:00:00',
#   'Solano',
#   'CA',
#   'Passenger',
#   '5',
#   '0',
#   '5',
#   '131',
#   '136',
#   '3.676470588235294117647058824'],
#  ['row-38fw-cweu-ixg9',
#   '00000000-0000-0000-FE92-F86D9A4CB608',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2018-09-30T00:00:00',
#   'Norfolk',
#   'MA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '37',
#   '38',
#   '2.631578947368421052631578947'],
#  ['row-2qyd~37ae~s2fx',
#   '00000000-0000-0000-4187-5D35D5F296BC',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-01-31T00:00:00',
#   'Moore',
#   'NC',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '169',
#   '170',
#   '0.5882352941176470588235294118'],
#  ['row-zegz_94s5~eswi',
#   '00000000-0000-0000-8774-CEB4F874FD2B',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-01-31T00:00:00',
#   'Hillsborough',
#   'FL',
#   'Passenger',
#   '1',
#   '2',
#   '3',
#   '118',
#   '121',
#   '2.479338842975206611570247934'],
#  ['row-5t28_xrcc.hjsy',
#   '00000000-0000-0000-EA17-7C230978B3CA',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-03-31T00:00:00',
#   'Dale',
#   'AL',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '52',
#   '53',
#   '1.886792452830188679245283019'],
#  ['row-j8en-r2kg_uv9h',
#   '00000000-0000-0000-0055-47F537DEA347',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-05-31T00:00:00',
#   'Spartanburg',
#   'SC',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '56',
#   '57',
#   '1.754385964912280701754385965'],
#  ['row-xnwn~stff_ngfs',
#   '00000000-0000-0000-F0DF-1E203CAB1D2D',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-11-30T00:00:00',
#   'Mason',
#   'WA',
#   'Passenger',
#   '169',
#   '133',
#   '302',
#   '47483',
#   '47785',
#   '0.6319974887517003243695720414'],
#  ['row-at4b~b3vd_p4ge',
#   '00000000-0000-0000-FE7F-F58C492A938E',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2024-01-31T00:00:00',
#   'Orange',
#   'CA',
#   'Passenger',
#   '7',
#   '2',
#   '9',
#   '256',
#   '265',
#   '3.396226415094339622641509434'],
#  ['row-uunn~6fri-i9x8',
#   '00000000-0000-0000-3C30-CBAA48DF6775',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2018-03-31T00:00:00',
#   'Pinal',
#   'AZ',
#   'Passenger',
#   '2',
#   '0',
#   '2',
#   '214',
#   '216',
#   '0.9259259259259259259259259259'],
#  ['row-432e_fne3~wtiz',
#   '00000000-0000-0000-20CB-05B7581ABCDE',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-01-31T00:00:00',
#   "Prince George's",
#   'MD',
#   'Passenger',
#   '1',
#   '1',
#   '2',
#   '188',
#   '190',
#   '1.052631578947368421052631579'],
#  ['row-pefa-sf79_zkyy',
#   '00000000-0000-0000-1F43-69DC0A9D2ADE',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-06-30T00:00:00',
#   'Yakima',
#   'WA',
#   'Truck',
#   '1',
#   '0',
#   '1',
#   '61388',
#   '61389',
#   '0.001628956327680854876280766913'],
#  ['row-wkwj_fmj2~inzs',
#   '00000000-0000-0000-7231-5FF2B4997109',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-01-31T00:00:00',
#   'Franklin',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '20879',
#   '20879',
#   '0'],
#  ['row-gzxc.m88h~gu7r',
#   '00000000-0000-0000-B8E8-3917A5D1FE4D',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-05-31T00:00:00',
#   'Grays Harbor',
#   'WA',
#   'Passenger',
#   '205',
#   '158',
#   '363',
#   '49057',
#   '49420',
#   '0.7345204370700121408336705787'],
#  ['row-k7e4_9c3a_sxcd',
#   '00000000-0000-0000-CEDD-63DD4BCEC6A3',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-10-31T00:00:00',
#   'Fairfax',
#   'VA',
#   'Passenger',
#   '6',
#   '3',
#   '9',
#   '542',
#   '551',
#   '1.633393829401088929219600726'],
#  ['row-v5vr.7imq_4suj',
#   '00000000-0000-0000-A211-827D1CFFBC76',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-06-30T00:00:00',
#   'Montgomery',
#   'PA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '26',
#   '27',
#   '3.703703703703703703703703704'],
#  ['row-23cr-4sgi-gjn9',
#   '00000000-0000-0000-7646-94A5556776BE',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-11-30T00:00:00',
#   'Kings',
#   'CA',
#   'Passenger',
#   '2',
#   '2',
#   '4',
#   '262',
#   '266',
#   '1.503759398496240601503759398'],
#  ['row-isfk~zcct-yjkq',
#   '00000000-0000-0000-46FA-3B3B661FB277',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-12-31T00:00:00',
#   'Nueces',
#   'TX',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '52',
#   '53',
#   '1.886792452830188679245283019'],
#  ['row-8vca~ebdf~av7j',
#   '00000000-0000-0000-BFAB-660C727374EB',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-05-31T00:00:00',
#   'Charleston',
#   'SC',
#   'Passenger',
#   '1',
#   '2',
#   '3',
#   '55',
#   '58',
#   '5.172413793103448275862068966'],
#  ['row-sy9m-yc5b_8y6b',
#   '00000000-0000-0000-D15F-3E55AA7E8E69',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-03-31T00:00:00',
#   'Franklin',
#   'MA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '1',
#   '2',
#   '50.0'],
#  ['row-w79z_qnkx_xidb',
#   '00000000-0000-0000-AEEC-05F2355A735C',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-01-31T00:00:00',
#   'San Diego',
#   'CA',
#   'Passenger',
#   '4',
#   '2',
#   '6',
#   '2894',
#   '2900',
#   '0.2068965517241379310344827586'],
#  ['row-sqfm.iine_mrqt',
#   '00000000-0000-0000-BD6C-96DC5E6470D8',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-04-30T00:00:00',
#   'Chesapeake',
#   'VA',
#   'Passenger',
#   '0',
#   '2',
#   '2',
#   '408',
#   '410',
#   '0.4878048780487804878048780488'],
#  ['row-87rn-426k~7xhp',
#   '00000000-0000-0000-C92F-58F344458EFC',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-02-28T00:00:00',
#   'Douglas',
#   'WA',
#   'Truck',
#   '6',
#   '0',
#   '6',
#   '12881',
#   '12887',
#   '0.04655854737332195235508652130'],
#  ['row-k7gy-i55t~i96x',
#   '00000000-0000-0000-03CD-47307BC9416F',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-01-31T00:00:00',
#   'Franklin',
#   'WA',
#   'Passenger',
#   '49',
#   '68',
#   '117',
#   '59313',
#   '59430',
#   '0.1968702675416456335184250379'],
#  ['row-9kcm~8rte.7jgd',
#   '00000000-0000-0000-E980-0F6F176A5B32',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-02-28T00:00:00',
#   'Klickitat',
#   'WA',
#   'Truck',
#   '4',
#   '0',
#   '4',
#   '8272',
#   '8276',
#   '0.04833252779120347994200096665'],
#  ['row-imjn-qy9g-mv7s',
#   '00000000-0000-0000-D87B-976F06EC5E33',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-07-31T00:00:00',
#   'Clallam',
#   'WA',
#   'Passenger',
#   '569',
#   '293',
#   '862',
#   '49023',
#   '49885',
#   '1.727974340984263806755537737'],
#  ['row-4fn6-5ptw.vqng',
#   '00000000-0000-0000-698D-42D93CE676A9',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-09-30T00:00:00',
#   'Pacific',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '7994',
#   '7994',
#   '0'],
#  ['row-hse4~rgmc_d3nd',
#   '00000000-0000-0000-5B04-45532D3BE64B',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2018-04-30T00:00:00',
#   'Lincoln',
#   'WA',
#   'Passenger',
#   '2',
#   '6',
#   '8',
#   '7613',
#   '7621',
#   '0.1049731006429602414381314788'],
#  ['row-s3yg-yx25.dnv2',
#   '00000000-0000-0000-13E7-931E51E649CD',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-11-30T00:00:00',
#   'Cochise',
#   'AZ',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '102',
#   '103',
#   '0.9708737864077669902912621359'],
#  ['row-ddnn-psrx_kpni',
#   '00000000-0000-0000-A97A-7E183C1A4CAF',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-01-31T00:00:00',
#   'Monterey',
#   'CA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '234',
#   '235',
#   '0.4255319148936170212765957447'],
#  ['row-dud5_3eee~24y4',
#   '00000000-0000-0000-F937-B997E8495443',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-08-31T00:00:00',
#   'DuPage',
#   'IL',
#   'Passenger',
#   '4',
#   '0',
#   '4',
#   '60',
#   '64',
#   '6.2500'],
#  ['row-dnwa.peqv~87yc',
#   '00000000-0000-0000-3FF1-B1B49B27D77F',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2018-06-30T00:00:00',
#   'Utah',
#   'UT',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '140',
#   '141',
#   '0.7092198581560283687943262411'],
#  ['row-svrf.89qk_me7z',
#   '00000000-0000-0000-8567-4BA08279D5FE',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-11-30T00:00:00',
#   'Anchorage',
#   'AK',
#   'Passenger',
#   '2',
#   '0',
#   '2',
#   '138',
#   '140',
#   '1.428571428571428571428571429'],
#  ['row-gbaw-4b2x-hzpm',
#   '00000000-0000-0000-6465-9C518166657D',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-07-31T00:00:00',
#   'Ulster',
#   'NY',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '12',
#   '13',
#   '7.692307692307692307692307692'],
#  ['row-2g6q.rygn.4rhi',
#   '00000000-0000-0000-4484-48B11A90F943',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-12-31T00:00:00',
#   'Ray',
#   'MO',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '1',
#   '2',
#   '50.0'],
#  ['row-395b-27ue-e3t5',
#   '00000000-0000-0000-16D5-E86DEF399F32',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-08-31T00:00:00',
#   'Bartow',
#   'GA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '5',
#   '6',
#   '16.66666666666666666666666667'],
#  ['row-5smx_43a6-crkm',
#   '00000000-0000-0000-F71F-1F1E5E19097A',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-12-31T00:00:00',
#   'Prince William',
#   'VA',
#   'Passenger',
#   '1',
#   '3',
#   '4',
#   '221',
#   '225',
#   '1.777777777777777777777777778'],
#  ['row-6qpf~s9k7~cet4',
#   '00000000-0000-0000-D776-AC7A90C2140D',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2018-03-31T00:00:00',
#   'Orange',
#   'FL',
#   'Passenger',
#   '2',
#   '1',
#   '3',
#   '170',
#   '173',
#   '1.734104046242774566473988439'],
#  ['row-n3ue.3cjn_g4j5',
#   '00000000-0000-0000-7DFE-6A95D1559700',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-06-30T00:00:00',
#   'Kitsap',
#   'WA',
#   'Passenger',
#   '2390',
#   '1053',
#   '3443',
#   '178314',
#   '181757',
#   '1.894287427719427587383154431'],
#  ['row-5fq9~mrhc.gz6e',
#   '00000000-0000-0000-4151-5F29A4199D5F',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-01-31T00:00:00',
#   'King',
#   'WA',
#   'Passenger',
#   '17166',
#   '6678',
#   '23844',
#   '1380645',
#   '1404489',
#   '1.697699305583738996887836074'],
#  ['row-upzp.i4r7~89j9',
#   '00000000-0000-0000-5726-3D401EADA21F',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-12-31T00:00:00',
#   'Columbia',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '1541',
#   '1541',
#   '0'],
#  ['row-86bc-yaqm~3vmc',
#   '00000000-0000-0000-0B53-96389CAEC437',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2024-01-31T00:00:00',
#   'Clark',
#   'WA',
#   'Passenger',
#   '7318',
#   '2683',
#   '10001',
#   '310003',
#   '320004',
#   '3.125273434082073974075324058'],
#  ['row-qfwf.p4b3-pde5',
#   '00000000-0000-0000-1220-BF0F2C48055C',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2024-03-31T00:00:00',
#   None,
#   None,
#   'Passenger',
#   '3',
#   '0',
#   '3',
#   '212',
#   '215',
#   '1.395348837209302325581395349'],
#  ['row-5xw9.p9wc~ryj5',
#   '00000000-0000-0000-A072-16E71DA612FC',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-03-31T00:00:00',
#   'Vigo',
#   'IN',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '5',
#   '6',
#   '16.66666666666666666666666667'],
#  ['row-b2zz-vjmj~w5ip',
#   '00000000-0000-0000-DF46-1D1D8FE21299',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-03-31T00:00:00',
#   'Suffolk',
#   'MA',
#   'Passenger',
#   '0',
#   '2',
#   '2',
#   '34',
#   '36',
#   '5.555555555555555555555555556'],
#  ['row-fq7c~yxk2-k5vj',
#   '00000000-0000-0000-A866-BA6B453EE55B',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-11-30T00:00:00',
#   'Travis',
#   'TX',
#   'Passenger',
#   '3',
#   '0',
#   '3',
#   '104',
#   '107',
#   '2.803738317757009345794392523'],
#  ['row-cmt2-wjgk~2sxv',
#   '00000000-0000-0000-43A8-E2A2B184EDDA',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-03-31T00:00:00',
#   'Bexar',
#   'TX',
#   'Passenger',
#   '3',
#   '5',
#   '8',
#   '581',
#   '589',
#   '1.358234295415959252971137521'],
#  ['row-ar2x_67jp~mkkc',
#   '00000000-0000-0000-F71C-07F501F3412C',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-11-30T00:00:00',
#   'Allen',
#   'IN',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '18',
#   '19',
#   '5.263157894736842105263157895'],
#  ['row-bxgf~f3cd-7kdg',
#   '00000000-0000-0000-B8DC-5623591E6E53',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-12-31T00:00:00',
#   'Lake',
#   'IN',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '9',
#   '10',
#   '10.0'],
#  ['row-993f-f5a6_2zua',
#   '00000000-0000-0000-8C68-CA7F48366A7E',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-01-31T00:00:00',
#   'Lake',
#   'FL',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '24',
#   '25',
#   '4.00'],
#  ['row-itiz_as4v_iisu',
#   '00000000-0000-0000-3611-8B0B7F25C01E',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2018-06-30T00:00:00',
#   'Clark',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '79112',
#   '79112',
#   '0'],
#  ['row-pcv3~nehj-k8te',
#   '00000000-0000-0000-8FCC-7A8D5B50514A',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-08-31T00:00:00',
#   'Stevens',
#   'WA',
#   'Passenger',
#   '49',
#   '44',
#   '93',
#   '30262',
#   '30355',
#   '0.3063745676165376379509141822'],
#  ['row-drti-nxq3_se4r',
#   '00000000-0000-0000-EE54-C0819DEDF80F',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-12-31T00:00:00',
#   'King',
#   'WA',
#   'Truck',
#   '6',
#   '1',
#   '7',
#   '182180',
#   '182187',
#   '0.003842206084956665404227524467'],
#  ['row-mxzf.jtx4~czek',
#   '00000000-0000-0000-08F6-0859252768C5',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-06-30T00:00:00',
#   'Mason',
#   'WA',
#   'Truck',
#   '11',
#   '0',
#   '11',
#   '20726',
#   '20737',
#   '0.05304528138110623523171143367'],
#  ['row-fmt8-rvqq-rit7',
#   '00000000-0000-0000-5C38-B958DBC2D7FA',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-11-30T00:00:00',
#   'Santa Cruz',
#   'CA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '28',
#   '29',
#   '3.448275862068965517241379310'],
#  ['row-iyby-b8f6~hzgp',
#   '00000000-0000-0000-E74B-DE1F0E663386',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-11-30T00:00:00',
#   'Charleston',
#   'SC',
#   'Passenger',
#   '2',
#   '1',
#   '3',
#   '83',
#   '86',
#   '3.488372093023255813953488372'],
#  ['row-jq8k~656a_4aui',
#   '00000000-0000-0000-F962-D5E062DD79E8',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-07-31T00:00:00',
#   'Hardin',
#   'KY',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '116',
#   '117',
#   '0.8547008547008547008547008547'],
#  ['row-ke29-gfmg.zh5d',
#   '00000000-0000-0000-A664-AB319C889D6A',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-08-31T00:00:00',
#   'Providence',
#   'RI',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '21',
#   '22',
#   '4.545454545454545454545454545'],
#  ['row-kxer_euki_5a4b',
#   '00000000-0000-0000-8F0F-97DCB71814A6',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-06-30T00:00:00',
#   'Hamilton',
#   'IN',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '42',
#   '43',
#   '2.325581395348837209302325581'],
#  ['row-wei2~xwb6_kmts',
#   '00000000-0000-0000-4ABD-803D20B2E321',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-04-30T00:00:00',
#   'Hawaii',
#   'HI',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '55',
#   '56',
#   '1.785714285714285714285714286'],
#  ['row-dr72.8bis-ip2w',
#   '00000000-0000-0000-2D22-0369054E54E0',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-09-30T00:00:00',
#   'Kootenai',
#   'ID',
#   'Truck',
#   '1',
#   '0',
#   '1',
#   '36',
#   '37',
#   '2.702702702702702702702702703'],
#  ['row-etqk.piau_s7im',
#   '00000000-0000-0000-1C98-477CD991B094',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-05-31T00:00:00',
#   'Sumter',
#   'FL',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '10',
#   '11',
#   '9.090909090909090909090909091'],
#  ['row-87qe-nne2-fk2z',
#   '00000000-0000-0000-B976-07AD95984F2F',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-10-31T00:00:00',
#   'Dallas',
#   'IA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '10',
#   '11',
#   '9.090909090909090909090909091'],
#  ['row-y9ui-sy83_mfc9',
#   '00000000-0000-0000-E849-4D83104AA550',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2018-04-30T00:00:00',
#   'Lake',
#   'CA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '8',
#   '9',
#   '11.11111111111111111111111111'],
#  ['row-nkis_6dp9.6maz',
#   '00000000-0000-0000-8205-24559E62B45A',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-05-31T00:00:00',
#   'DeKalb',
#   'IN',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '1',
#   '2',
#   '50.0'],
#  ['row-y3zh.8kpi~y3f6',
#   '00000000-0000-0000-1583-D39305DCE93F',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-11-30T00:00:00',
#   'Burlington',
#   'NJ',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '119',
#   '120',
#   '0.8333333333333333333333333333'],
#  ['row-3h6g~jv9i~d7kn',
#   '00000000-0000-0000-17C1-4C02E99A8832',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-11-30T00:00:00',
#   'Maricopa',
#   'AZ',
#   'Passenger',
#   '5',
#   '9',
#   '14',
#   '1428',
#   '1442',
#   '0.9708737864077669902912621359'],
#  ['row-8v9j_sg4u-eh2v',
#   '00000000-0000-0000-0DC4-1978459590C0',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-12-31T00:00:00',
#   'Los Angeles',
#   'CA',
#   'Passenger',
#   '4',
#   '6',
#   '10',
#   '753',
#   '763',
#   '1.310615989515072083879423329'],
#  ['row-ygft~yt39.ezgg',
#   '00000000-0000-0000-88CF-255B5C9A68BA',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-10-31T00:00:00',
#   'Spokane',
#   'WA',
#   'Passenger',
#   '615',
#   '463',
#   '1078',
#   '314253',
#   '315331',
#   '0.3418629947578893289908064859'],
#  ['row-ivk9.57zj.ycgd',
#   '00000000-0000-0000-BA80-37CFB949D44C',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-10-31T00:00:00',
#   'Yakima',
#   'WA',
#   'Passenger',
#   '157',
#   '122',
#   '279',
#   '166847',
#   '167126',
#   '0.1669399135981235714371192992'],
#  ['row-px5y_u8z6.bez9',
#   '00000000-0000-0000-E391-19E11AC3A7DE',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-10-31T00:00:00',
#   'Gwinnett',
#   'GA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '88',
#   '89',
#   '1.123595505617977528089887640'],
#  ['row-t4a3~fydb.tyfv',
#   '00000000-0000-0000-E9B6-C0CD0A3A9745',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-10-31T00:00:00',
#   'Solano',
#   'CA',
#   'Passenger',
#   '2',
#   '0',
#   '2',
#   '162',
#   '164',
#   '1.219512195121951219512195122'],
#  ['row-ucxn~rfjn_ahg3',
#   '00000000-0000-0000-6E84-9F6964252BEB',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-10-31T00:00:00',
#   'Montgomery',
#   'PA',
#   'Passenger',
#   '2',
#   '0',
#   '2',
#   '24',
#   '26',
#   '7.692307692307692307692307692'],
#  ['row-syby.eytn-4z6b',
#   '00000000-0000-0000-88C4-1BB8321F8AD2',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-02-28T00:00:00',
#   'Madison',
#   'ID',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '44',
#   '45',
#   '2.222222222222222222222222222'],
#  ['row-rjmf-6chx_hzhf',
#   '00000000-0000-0000-B1BD-36BCAAC33A5B',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-07-31T00:00:00',
#   'Columbia',
#   'OR',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '16',
#   '17',
#   '5.882352941176470588235294118'],
#  ['row-2m34~5hzn_kss2',
#   '00000000-0000-0000-B5CC-D7D4223E08F9',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-08-31T00:00:00',
#   'Skamania',
#   'WA',
#   'Passenger',
#   '31',
#   '22',
#   '53',
#   '8369',
#   '8422',
#   '0.6293042032771313227261933033'],
#  ['row-wra3-wht6~pxma',
#   '00000000-0000-0000-7A28-F7CCE3933D3D',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-09-30T00:00:00',
#   'Lewis',
#   'WA',
#   'Passenger',
#   '53',
#   '40',
#   '93',
#   '56023',
#   '56116',
#   '0.1657281345783733694489985031'],
#  ['row-4wgi_ngj9~pvam',
#   '00000000-0000-0000-7012-A5D5D88FA1BC',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-12-31T00:00:00',
#   'Bexar',
#   'TX',
#   'Passenger',
#   '0',
#   '5',
#   '5',
#   '672',
#   '677',
#   '0.7385524372230428360413589365'],
#  ['row-97pt-vg94~zyvc',
#   '00000000-0000-0000-2FD0-60BD699E26BE',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-08-31T00:00:00',
#   'Snohomish',
#   'WA',
#   'Truck',
#   '1',
#   '0',
#   '1',
#   '125975',
#   '125976',
#   '0.0007938019940306090048898202832'],
#  ['row-p4u2~fjg6-6w7d',
#   '00000000-0000-0000-CDB1-4CFC5A2458E2',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-06-30T00:00:00',
#   None,
#   None,
#   'Passenger',
#   '6',
#   '1',
#   '7',
#   '388',
#   '395',
#   '1.772151898734177215189873418'],
#  ['row-6zas-afu7~y9fa',
#   '00000000-0000-0000-F34A-FB90D71DE350',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-06-30T00:00:00',
#   'Garfield',
#   'WA',
#   'Passenger',
#   '1',
#   '3',
#   '4',
#   '1302',
#   '1306',
#   '0.3062787136294027565084226646'],
#  ['row-qwkf.vimq.kbtr',
#   '00000000-0000-0000-17F6-FA11897C54E4',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2018-05-31T00:00:00',
#   'St. Clair',
#   'IL',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '156',
#   '157',
#   '0.6369426751592356687898089172'],
#  ['row-mids~88dq_57cd',
#   '00000000-0000-0000-C8D6-4B8AA37A1A8A',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-09-30T00:00:00',
#   'Allen',
#   'IN',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '19',
#   '20',
#   '5.00'],
#  ['row-t9xc.9n83.z8f7',
#   '00000000-0000-0000-DB01-1AF21B95B835',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-07-31T00:00:00',
#   'Walla Walla',
#   'WA',
#   'Passenger',
#   '52',
#   '61',
#   '113',
#   '36201',
#   '36314',
#   '0.3111747535385801619210221953'],
#  ['row-6esv-acfe-g8f5',
#   '00000000-0000-0000-25D7-377D27E133FF',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-03-31T00:00:00',
#   'Sarpy',
#   'NE',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '64',
#   '65',
#   '1.538461538461538461538461538'],
#  ['row-cc4i~gmrv~bbtw',
#   '00000000-0000-0000-860F-4D5203215393',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-01-31T00:00:00',
#   'Bryan',
#   'GA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '33',
#   '34',
#   '2.941176470588235294117647059'],
#  ['row-4k6g~mtj2-z6wx',
#   '00000000-0000-0000-6575-3726B202C228',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-01-31T00:00:00',
#   'Clark',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '79955',
#   '79955',
#   '0'],
#  ['row-dzxn.j22x_nb69',
#   '00000000-0000-0000-DEE4-950904EFB8E4',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-04-30T00:00:00',
#   'Kittitas',
#   'WA',
#   'Truck',
#   '8',
#   '0',
#   '8',
#   '14536',
#   '14544',
#   '0.05500550055005500550055005501'],
#  ['row-j878-ndq7.7rsk',
#   '00000000-0000-0000-5AF7-EB13CB85AF61',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-03-31T00:00:00',
#   'Skagit',
#   'WA',
#   'Passenger',
#   '730',
#   '326',
#   '1056',
#   '90422',
#   '91478',
#   '1.154375915520671636896302936'],
#  ['row-gv64-5m3u_pfk2',
#   '00000000-0000-0000-028B-C8CC234F678C',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-09-30T00:00:00',
#   'Walla Walla',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '13788',
#   '13788',
#   '0'],
#  ['row-eihm-yad7_zwb6',
#   '00000000-0000-0000-4242-DE276A9014C9',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-05-31T00:00:00',
#   'Jefferson',
#   'WA',
#   'Passenger',
#   '103',
#   '59',
#   '162',
#   '23820',
#   '23982',
#   '0.6755066299724793595196397298'],
#  ['row-ffei.wxuj_263s',
#   '00000000-0000-0000-DE18-0BA102A73F97',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-09-30T00:00:00',
#   'Alameda',
#   'CA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '356',
#   '357',
#   '0.2801120448179271708683473389'],
#  ['row-p46s-wg6x-uinv',
#   '00000000-0000-0000-0582-E2C90FA91A61',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2018-06-30T00:00:00',
#   'Adams',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '5163',
#   '5163',
#   '0'],
#  ['row-hqp5.x8r5_7vfv',
#   '00000000-0000-0000-A999-8A767C10BF72',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-06-30T00:00:00',
#   'Escambia',
#   'FL',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '141',
#   '142',
#   '0.7042253521126760563380281690'],
#  ['row-rku6~qz5f.zne8',
#   '00000000-0000-0000-1EF2-35B9C27CE288',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-05-31T00:00:00',
#   'Cook',
#   'IL',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '249',
#   '250',
#   '0.400'],
#  ['row-rjia~226d~a54x',
#   '00000000-0000-0000-A50F-B67EBDE98D3A',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-01-31T00:00:00',
#   'Columbia',
#   'OR',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '23',
#   '24',
#   '4.166666666666666666666666667'],
#  ['row-94yb~kdj6~32t2',
#   '00000000-0000-0000-AA17-46A944CBE264',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-12-31T00:00:00',
#   'Montgomery',
#   'PA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '39',
#   '40',
#   '2.500'],
#  ['row-j5tf~pevn.7ufp',
#   '00000000-0000-0000-2374-06377B049465',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-01-31T00:00:00',
#   'Pima',
#   'AZ',
#   'Passenger',
#   '0',
#   '2',
#   '2',
#   '483',
#   '485',
#   '0.4123711340206185567010309278'],
#  ['row-cdha-jcjv_nbsz',
#   '00000000-0000-0000-B93C-4758D457AF42',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-07-31T00:00:00',
#   'Asotin',
#   'WA',
#   'Passenger',
#   '16',
#   '12',
#   '28',
#   '12373',
#   '12401',
#   '0.2257882428836384162567534876'],
#  ['row-wcih~475u-25sc',
#   '00000000-0000-0000-5D6E-30E2EB6233D6',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-09-30T00:00:00',
#   'Garfield',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '985',
#   '985',
#   '0'],
#  ['row-4k23.acty_4g3s',
#   '00000000-0000-0000-1A90-C691CBFD77D2',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-11-30T00:00:00',
#   'Columbia',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '1538',
#   '1538',
#   '0'],
#  ['row-86dy-j9ym.ci65',
#   '00000000-0000-0000-04EF-7B8F252C390B',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-02-28T00:00:00',
#   'Lee',
#   'AL',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '15',
#   '16',
#   '6.2500'],
#  ['row-c4my-5u54_3cfk',
#   '00000000-0000-0000-66DE-57506D0D4093',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-06-30T00:00:00',
#   'Williams',
#   'ND',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '11',
#   '12',
#   '8.333333333333333333333333333'],
#  ['row-cjmr.ayd2~xsv9',
#   '00000000-0000-0000-2315-E134FE096083',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-09-30T00:00:00',
#   'Meade',
#   'KY',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '26',
#   '27',
#   '3.703703703703703703703703704'],
#  ['row-y6ev.ae4p~umww',
#   '00000000-0000-0000-CEC3-27C3F9D903B2',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-04-30T00:00:00',
#   'Dorchester',
#   'SC',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '51',
#   '52',
#   '1.923076923076923076923076923'],
#  ['row-jrws~fw9n.ht2d',
#   '00000000-0000-0000-7007-BE841F51FB56',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-11-30T00:00:00',
#   'Portsmouth',
#   'VA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '80',
#   '81',
#   '1.234567901234567901234567901'],
#  ['row-6juw.p4yh.mbbv',
#   '00000000-0000-0000-6B6B-C9A5AA75AD04',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-03-31T00:00:00',
#   'Prince William',
#   'VA',
#   'Passenger',
#   '1',
#   '2',
#   '3',
#   '175',
#   '178',
#   '1.685393258426966292134831461'],
#  ['row-bvuv_3g3t-u63y',
#   '00000000-0000-0000-6674-CFA5187EE837',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-05-31T00:00:00',
#   'Leavenworth',
#   'KS',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '103',
#   '104',
#   '0.9615384615384615384615384615'],
#  ['row-syic_eu8z-ja2n',
#   '00000000-0000-0000-5657-A78EE6BED1B6',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-10-31T00:00:00',
#   'Fairfax',
#   'VA',
#   'Passenger',
#   '7',
#   '3',
#   '10',
#   '623',
#   '633',
#   '1.579778830963665086887835703'],
#  ['row-khs4-9q6q.5g9p',
#   '00000000-0000-0000-E062-21FA906ED564',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2018-11-30T00:00:00',
#   'Brevard',
#   'FL',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '96',
#   '97',
#   '1.030927835051546391752577320'],
#  ['row-cr5r_ebaj~ydjd',
#   '00000000-0000-0000-EC9A-356FDDAAE795',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-12-31T00:00:00',
#   'San Juan',
#   'WA',
#   'Passenger',
#   '559',
#   '170',
#   '729',
#   '13886',
#   '14615',
#   '4.988026000684228532329798153'],
#  ['row-sw4q.fqdf_n9i3',
#   '00000000-0000-0000-26A7-4BC6BC8AD4DA',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-10-31T00:00:00',
#   'Douglas',
#   'NE',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '60',
#   '61',
#   '1.639344262295081967213114754'],
#  ['row-n3a9~86wx_bc7s',
#   '00000000-0000-0000-AF43-FC8DF7798D8F',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-12-31T00:00:00',
#   'Anne Arundel',
#   'MD',
#   'Passenger',
#   '3',
#   '3',
#   '6',
#   '313',
#   '319',
#   '1.880877742946708463949843260'],
#  ['row-bvdu-e2wu_5vds',
#   '00000000-0000-0000-01DF-4456551118DC',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-03-31T00:00:00',
#   'Norfolk',
#   'VA',
#   'Passenger',
#   '2',
#   '2',
#   '4',
#   '290',
#   '294',
#   '1.360544217687074829931972789'],
#  ['row-6qi7~2n5f-ga33',
#   '00000000-0000-0000-9F33-03F7EF3C3722',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-01-31T00:00:00',
#   'Spartanburg',
#   'SC',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '48',
#   '49',
#   '2.040816326530612244897959184'],
#  ['row-hj2k~j3vd.g6bh',
#   '00000000-0000-0000-A5FA-99F0975B8F74',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-09-30T00:00:00',
#   'Portsmouth',
#   'VA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '64',
#   '65',
#   '1.538461538461538461538461538'],
#  ['row-a8wm-vvkb_tz4w',
#   '00000000-0000-0000-38DF-32E3FFDB1F1D',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-07-31T00:00:00',
#   'Las Animas',
#   'CO',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '1',
#   '2',
#   '50.0'],
#  ['row-j5pb-dmfg~skv7',
#   '00000000-0000-0000-6259-110D3FF5F0FD',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-11-30T00:00:00',
#   'Okanogan',
#   'WA',
#   'Truck',
#   '2',
#   '0',
#   '2',
#   '16451',
#   '16453',
#   '0.01215583784112319941651978363'],
#  ['row-tb8x-wucz~b56q',
#   '00000000-0000-0000-F44D-BF94638A53A0',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-01-31T00:00:00',
#   'Calvert',
#   'MD',
#   'Passenger',
#   '0',
#   '2',
#   '2',
#   '82',
#   '84',
#   '2.380952380952380952380952381'],
#  ['row-hrgg_srqg~g3ia',
#   '00000000-0000-0000-C495-8E7DF864A605',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-03-31T00:00:00',
#   'Multnomah',
#   'OR',
#   'Passenger',
#   '1',
#   '4',
#   '5',
#   '604',
#   '609',
#   '0.8210180623973727422003284072'],
#  ['row-mjq5-rpmm-gpgn',
#   '00000000-0000-0000-21CF-1304A373B64A',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-06-30T00:00:00',
#   'Columbia',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '1531',
#   '1531',
#   '0'],
#  ['row-smfw_3hwn.7gda',
#   '00000000-0000-0000-8BDA-77FDE11B0021',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-11-30T00:00:00',
#   'Washoe',
#   'NV',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '110',
#   '111',
#   '0.9009009009009009009009009009'],
#  ['row-rejz_x29y.yhen',
#   '00000000-0000-0000-D760-667C648EB4B6',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-11-30T00:00:00',
#   'Suffolk',
#   'MA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '37',
#   '38',
#   '2.631578947368421052631578947'],
#  ['row-4m6b~v5qv-s4jc',
#   '00000000-0000-0000-3035-5B4923FCD4DA',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-06-30T00:00:00',
#   'Marion',
#   'IA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '1',
#   '2',
#   '50.0'],
#  ['row-ad2h.qtpt.7u5n',
#   '00000000-0000-0000-29B1-90992D03597B',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-07-31T00:00:00',
#   'Carroll',
#   'NH',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '5',
#   '6',
#   '16.66666666666666666666666667'],
#  ['row-cqxe.n5h4~nfre',
#   '00000000-0000-0000-D4A0-D314203AF111',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-04-30T00:00:00',
#   'Middlesex',
#   'NJ',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '18',
#   '19',
#   '5.263157894736842105263157895'],
#  ['row-xija~cndb.px62',
#   '00000000-0000-0000-59E3-B24378109511',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-05-31T00:00:00',
#   'Grant',
#   'WA',
#   'Passenger',
#   '39',
#   '59',
#   '98',
#   '64554',
#   '64652',
#   '0.1515807708964919878735383283'],
#  ['row-f4n5.fbq6~vhvz',
#   '00000000-0000-0000-7238-7618BACB3690',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-12-31T00:00:00',
#   'Island',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '21483',
#   '21483',
#   '0'],
#  ['row-kjh7.6hk2.9zjw',
#   '00000000-0000-0000-AA43-DA1295AE304E',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-04-30T00:00:00',
#   'Kootenai',
#   'ID',
#   'Passenger',
#   '1',
#   '2',
#   '3',
#   '216',
#   '219',
#   '1.369863013698630136986301370'],
#  ['row-zhf3_9dse.6hhx',
#   '00000000-0000-0000-994C-B42BA22FA561',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-08-31T00:00:00',
#   'Berkeley',
#   'SC',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '117',
#   '118',
#   '0.8474576271186440677966101695'],
#  ['row-tx4h~xkgz-75d2',
#   '00000000-0000-0000-8029-378364D0C693',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-10-31T00:00:00',
#   'Lee',
#   'FL',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '53',
#   '54',
#   '1.851851851851851851851851852'],
#  ['row-vr55~b589~pqqu',
#   '00000000-0000-0000-F8F0-7127ACA23BA1',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-07-31T00:00:00',
#   'Larimer',
#   'CO',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '51',
#   '52',
#   '1.923076923076923076923076923'],
#  ['row-udr7-wzgi-x97r',
#   '00000000-0000-0000-1B1B-D701C45506C3',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-07-31T00:00:00',
#   'Pend Oreille',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '5646',
#   '5646',
#   '0'],
#  ['row-y5r6.g244-upry',
#   '00000000-0000-0000-FAC0-03F9230CD553',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-10-31T00:00:00',
#   'Walla Walla',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '14048',
#   '14048',
#   '0'],
#  ['row-xa8g.3ftx_bwtd',
#   '00000000-0000-0000-5E2C-96F6D6A9EE94',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-09-30T00:00:00',
#   'Kittitas',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '13658',
#   '13658',
#   '0'],
#  ['row-p4st_489t-9pqt',
#   '00000000-0000-0000-05CF-06F276652315',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-06-30T00:00:00',
#   'Kittitas',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '14590',
#   '14590',
#   '0'],
#  ['row-hkts_ykvg-kjae',
#   '00000000-0000-0000-46A7-84EBF0AE5700',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-10-31T00:00:00',
#   'Jefferson',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '9572',
#   '9572',
#   '0'],
#  ['row-x4yj~cbwp~gnnh',
#   '00000000-0000-0000-0344-B9F68D7A1BBA',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-10-31T00:00:00',
#   'Kittitas',
#   'WA',
#   'Passenger',
#   '432',
#   '113',
#   '545',
#   '29278',
#   '29823',
#   '1.827448613486235455856218355'],
#  ['row-fmfg.yt94.jd2x',
#   '00000000-0000-0000-B655-50CE5F12ECC7',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-10-31T00:00:00',
#   None,
#   None,
#   'Passenger',
#   '6',
#   '2',
#   '8',
#   '417',
#   '425',
#   '1.882352941176470588235294118'],
#  ['row-49ez~iuny-xs9f',
#   '00000000-0000-0000-222D-112181760775',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-09-30T00:00:00',
#   'DeKalb',
#   'GA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '83',
#   '84',
#   '1.190476190476190476190476190'],
#  ['row-hijh_uvay-myqk',
#   '00000000-0000-0000-EFB0-F2BB6F9A08EF',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2018-05-31T00:00:00',
#   'Carroll',
#   'NH',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '1',
#   '2',
#   '50.0'],
#  ['row-hzd4.kjuf-xm32',
#   '00000000-0000-0000-A193-725ADF68FBD3',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-01-31T00:00:00',
#   'Napa',
#   'CA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '12',
#   '13',
#   '7.692307692307692307692307692'],
#  ['row-td3a_9nmy_w4ew',
#   '00000000-0000-0000-74D3-5804607C0E24',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-01-31T00:00:00',
#   'Jefferson',
#   'WA',
#   'Passenger',
#   '224',
#   '139',
#   '363',
#   '25206',
#   '25569',
#   '1.419687903320427079666783996'],
#  ['row-ycxb-u2u3.z7k5',
#   '00000000-0000-0000-CB29-1C1A631F7B21',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-07-31T00:00:00',
#   'Grays Harbor',
#   'WA',
#   'Passenger',
#   '176',
#   '146',
#   '322',
#   '49495',
#   '49817',
#   '0.6463656984563502418853001987'],
#  ['row-wik3.cbue_azzi',
#   '00000000-0000-0000-FC69-BF9E8AC3148C',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-01-31T00:00:00',
#   'Skagit',
#   'WA',
#   'Passenger',
#   '270',
#   '186',
#   '456',
#   '91355',
#   '91811',
#   '0.4966725120083650107285619370'],
#  ['row-3rvr_3h46~aud2',
#   '00000000-0000-0000-1BF4-4F60551247B9',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-11-30T00:00:00',
#   'Sacramento',
#   'CA',
#   'Passenger',
#   '1',
#   '1',
#   '2',
#   '331',
#   '333',
#   '0.6006006006006006006006006006'],
#  ['row-rrai~f2ke.v9gd',
#   '00000000-0000-0000-CF5C-FBF3F97574C5',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-08-31T00:00:00',
#   'Jackson',
#   'MO',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '59',
#   '60',
#   '1.666666666666666666666666667'],
#  ['row-fuvt~4sqj~ci48',
#   '00000000-0000-0000-1319-13E32A9E0E97',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2018-10-31T00:00:00',
#   'Lewis',
#   'WA',
#   'Passenger',
#   '88',
#   '72',
#   '160',
#   '58039',
#   '58199',
#   '0.2749188130380247083283217925'],
#  ['row-ct76.bm2m_4atf',
#   '00000000-0000-0000-7CDB-4E703A4CE583',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-03-31T00:00:00',
#   'Columbia',
#   'WA',
#   'Passenger',
#   '3',
#   '3',
#   '6',
#   '2417',
#   '2423',
#   '0.2476269087907552620718118035'],
#  ['row-tk8i_9cbi.n4g7',
#   '00000000-0000-0000-EB00-8A8309DA004E',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2018-06-30T00:00:00',
#   'Travis',
#   'TX',
#   'Passenger',
#   '1',
#   '1',
# ...
#   '00000000-0000-0000-11BB-555A52A7A314',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-07-31T00:00:00',
#   'Shelby',
#   'TN',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '113',
#   '114',
#   '0.8771929824561403508771929825'],
#  ['row-wx7t~k4nk-v6kx',
#   '00000000-0000-0000-7A0D-ED0AC9401455',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2018-05-31T00:00:00',
#   'Island',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '20871',
#   '20871',
#   '0'],
#  ['row-9uya~dzj4~8dab',
#   '00000000-0000-0000-9EFD-2D682B2E1420',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-04-30T00:00:00',
#   'Essex',
#   'MA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '13',
#   '14',
#   '7.142857142857142857142857143'],
#  ['row-cdde_tr8u.7iz6',
#   '00000000-0000-0000-3D21-8DD2277FDCA5',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-04-30T00:00:00',
#   'Palm Beach',
#   'FL',
#   'Passenger',
#   '0',
#   '2',
#   '2',
#   '81',
#   '83',
#   '2.409638554216867469879518072'],
#  ['row-xyfz.9tg3-4p9a',
#   '00000000-0000-0000-980D-E31717C7981B',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2024-03-31T00:00:00',
#   'York',
#   'VA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '59',
#   '60',
#   '1.666666666666666666666666667'],
#  ['row-4axx.f5q4-6j2t',
#   '00000000-0000-0000-6C40-E82B473DD7EF',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-03-31T00:00:00',
#   'Fairbanks North Star',
#   'AK',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '80',
#   '81',
#   '1.234567901234567901234567901'],
#  ['row-rvid~drya~twy8',
#   '00000000-0000-0000-C21C-355BF8AB69EC',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-02-28T00:00:00',
#   'Rock Island',
#   'IL',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '15',
#   '16',
#   '6.2500'],
#  ['row-zttt.sd9m.3qmr',
#   '00000000-0000-0000-36B6-7D5646AB56F1',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-11-30T00:00:00',
#   'Skagit',
#   'WA',
#   'Passenger',
#   '666',
#   '299',
#   '965',
#   '91247',
#   '92212',
#   '1.046501539929727150479330239'],
#  ['row-jpy5~ft5f.ms6h',
#   '00000000-0000-0000-D1A2-766FEDD1520E',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-05-31T00:00:00',
#   'Fulton',
#   'GA',
#   'Passenger',
#   '1',
#   '3',
#   '4',
#   '110',
#   '114',
#   '3.508771929824561403508771930'],
#  ['row-ty4g_crxr-fy4f',
#   '00000000-0000-0000-D7D6-CCB8C939BFCA',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-11-30T00:00:00',
#   'Walla Walla',
#   'WA',
#   'Truck',
#   '3',
#   '0',
#   '3',
#   '13909',
#   '13912',
#   '0.02156411730879815986198964922'],
#  ['row-ui3y-zuyr_5sud',
#   '00000000-0000-0000-D832-E629442D3B0B',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-10-31T00:00:00',
#   'Providence',
#   'RI',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '20',
#   '21',
#   '4.761904761904761904761904762'],
#  ['row-p8uy~h4fd.f7pc',
#   '00000000-0000-0000-0439-0F4AC4088230',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2018-07-31T00:00:00',
#   'Pierce',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '138039',
#   '138039',
#   '0'],
#  ['row-9a9a-akne~q3h5',
#   '00000000-0000-0000-EF15-2E4BD2784F5B',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-08-31T00:00:00',
#   'Riverside',
#   'CA',
#   'Passenger',
#   '3',
#   '2',
#   '5',
#   '654',
#   '659',
#   '0.7587253414264036418816388467'],
#  ['row-hq2s~tsvf-3yv4',
#   '00000000-0000-0000-F8FE-AFD66C0590DA',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-12-31T00:00:00',
#   'Honolulu',
#   'HI',
#   'Passenger',
#   '4',
#   '4',
#   '8',
#   '394',
#   '402',
#   '1.990049751243781094527363184'],
#  ['row-w5cy-7kk5.fzwr',
#   '00000000-0000-0000-940A-663B93E49E49',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-12-31T00:00:00',
#   'Alameda',
#   'CA',
#   'Passenger',
#   '5',
#   '0',
#   '5',
#   '228',
#   '233',
#   '2.145922746781115879828326180'],
#  ['row-pwzx_w4r6_nr52',
#   '00000000-0000-0000-4EC7-ADC5E089C207',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-04-30T00:00:00',
#   'Nassau',
#   'NY',
#   'Passenger',
#   '3',
#   '0',
#   '3',
#   '35',
#   '38',
#   '7.894736842105263157894736842'],
#  ['row-ayka~5q9r-d9bu',
#   '00000000-0000-0000-6AE8-870135064906',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-02-28T00:00:00',
#   'Jackson',
#   'MO',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '73',
#   '74',
#   '1.351351351351351351351351351'],
#  ['row-svam.uyue-zj2k',
#   '00000000-0000-0000-4E19-72D36F1CE19A',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-12-31T00:00:00',
#   'Stevens',
#   'WA',
#   'Passenger',
#   '37',
#   '40',
#   '77',
#   '30216',
#   '30293',
#   '0.2541841349486680091110157462'],
#  ['row-ebsi_8mzy~msrj',
#   '00000000-0000-0000-EC6F-8C0AB44AC625',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-05-31T00:00:00',
#   'Virginia Beach',
#   'VA',
#   'Passenger',
#   '2',
#   '0',
#   '2',
#   '621',
#   '623',
#   '0.3210272873194221508828250401'],
#  ['row-49h6.rdss-idwy',
#   '00000000-0000-0000-1D3C-7CBC3CC5F03B',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-01-31T00:00:00',
#   'Columbia',
#   'WA',
#   'Passenger',
#   '3',
#   '3',
#   '6',
#   '2448',
#   '2454',
#   '0.2444987775061124694376528117'],
#  ['row-af2g.ysur.yr54',
#   '00000000-0000-0000-48CC-5207CBDC08D9',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-11-30T00:00:00',
#   'Douglas',
#   'NE',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '52',
#   '53',
#   '1.886792452830188679245283019'],
#  ['row-waen_7xna~9fn4',
#   '00000000-0000-0000-A30A-0CB46F9C6703',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2020-04-30T00:00:00',
#   'Randolph',
#   'NC',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '8',
#   '9',
#   '11.11111111111111111111111111'],
#  ['row-k66g_53hh-gdgk',
#   '00000000-0000-0000-3061-7D80988BF7AE',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-06-30T00:00:00',
#   'Benton',
#   'WA',
#   'Passenger',
#   '516',
#   '393',
#   '909',
#   '136335',
#   '137244',
#   '0.6623240360234327183702019760'],
#  ['row-23ik_zxx7_ff9a',
#   '00000000-0000-0000-D541-F7CBFDF314CE',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-12-31T00:00:00',
#   'Kittitas',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '14796',
#   '14796',
#   '0'],
#  ['row-p8qq~zjvz-9dvg',
#   '00000000-0000-0000-C5D7-9A45C928073E',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-01-31T00:00:00',
#   'Galveston',
#   'TX',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '18',
#   '19',
#   '5.263157894736842105263157895'],
#  ['row-pn7r.vuk2.zwg5',
#   '00000000-0000-0000-C42D-9DC3F4542DC5',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2018-07-31T00:00:00',
#   'Queens',
#   'NY',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '62',
#   '63',
#   '1.587301587301587301587301587'],
#  ['row-stpk-68si.sxqs',
#   '00000000-0000-0000-C24B-49BA56B86BFF',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-01-31T00:00:00',
#   'St. Louis',
#   'MO',
#   'Passenger',
#   '2',
#   '0',
#   '2',
#   '59',
#   '61',
#   '3.278688524590163934426229508'],
#  ['row-mkfg~gvi4-pjdi',
#   '00000000-0000-0000-98C9-598066C5D524',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2024-01-31T00:00:00',
#   'Santa Cruz',
#   'CA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '20',
#   '21',
#   '4.761904761904761904761904762'],
#  ['row-rb6g_wbhj-uqq4',
#   '00000000-0000-0000-A3D2-1DE1106390B6',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-11-30T00:00:00',
#   'Santa Clara',
#   'CA',
#   'Passenger',
#   '12',
#   '2',
#   '14',
#   '147',
#   '161',
#   '8.695652173913043478260869565'],
#  ['row-m4yc_dbdg~8ywe',
#   '00000000-0000-0000-E79A-657AD31C9B29',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2024-02-29T00:00:00',
#   'Sarasota',
#   'FL',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '20',
#   '21',
#   '4.761904761904761904761904762'],
#  ['row-pqw5~e8ym.84vy',
#   '00000000-0000-0000-0B69-A70C82DF1E63',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-12-31T00:00:00',
#   'Bucks',
#   'PA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '23',
#   '24',
#   '4.166666666666666666666666667'],
#  ['row-uwsw.kn3x_gwm7',
#   '00000000-0000-0000-8161-8AADF34B2018',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-07-31T00:00:00',
#   'Hanover',
#   'VA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '1',
#   '2',
#   '50.0'],
#  ['row-c9qc~dz4z~gfhb',
#   '00000000-0000-0000-060F-DBB492C0AF2D',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-11-30T00:00:00',
#   'Virginia Beach',
#   'VA',
#   'Passenger',
#   '2',
#   '0',
#   '2',
#   '575',
#   '577',
#   '0.3466204506065857885615251300'],
#  ['row-q6x8.gcit.3qqx',
#   '00000000-0000-0000-E4C2-CFA71F7BBC5D',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-05-31T00:00:00',
#   'Muscogee',
#   'GA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '98',
#   '99',
#   '1.010101010101010101010101010'],
#  ['row-ivcx_zv4a_mrdy',
#   '00000000-0000-0000-499E-2E4BD1CD0FA0',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-03-31T00:00:00',
#   'Hudson',
#   'NJ',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '23',
#   '24',
#   '4.166666666666666666666666667'],
#  ['row-ux68_svaq_a5wx',
#   '00000000-0000-0000-6D46-3517AFEFE810',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-09-30T00:00:00',
#   'Nassau',
#   'NY',
#   'Passenger',
#   '4',
#   '0',
#   '4',
#   '41',
#   '45',
#   '8.888888888888888888888888889'],
#  ['row-979e-r3ru.nyiy',
#   '00000000-0000-0000-A3B3-97DE19C31E87',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2018-05-31T00:00:00',
#   'Beaufort',
#   'SC',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '40',
#   '41',
#   '2.439024390243902439024390244'],
#  ['row-7x5d~x38b-gad5',
#   '00000000-0000-0000-9FA8-C42A19D735AB',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-12-31T00:00:00',
#   'Carroll',
#   'NH',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '5',
#   '6',
#   '16.66666666666666666666666667'],
#  ['row-7459~pnjr~p992',
#   '00000000-0000-0000-31F7-442227F2D9E9',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-06-30T00:00:00',
#   'Anne Arundel',
#   'MD',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '498',
#   '499',
#   '0.2004008016032064128256513026'],
#  ['row-u8ni~68p8.p6ya',
#   '00000000-0000-0000-4652-F52E0602BA09',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-01-31T00:00:00',
#   'Travis',
#   'TX',
#   'Passenger',
#   '3',
#   '1',
#   '4',
#   '213',
#   '217',
#   '1.843317972350230414746543779'],
#  ['row-g7ri-jhix~suyk',
#   '00000000-0000-0000-2CDF-FD79D8270BDB',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-04-30T00:00:00',
#   'Harris',
#   'TX',
#   'Passenger',
#   '1',
#   '1',
#   '2',
#   '234',
#   '236',
#   '0.8474576271186440677966101695'],
#  ['row-s4yf~2423-cysh',
#   '00000000-0000-0000-2005-905348DD0E23',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-09-30T00:00:00',
#   'Houston',
#   'GA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '58',
#   '59',
#   '1.694915254237288135593220339'],
#  ['row-hcu8_2ssr_6nfq',
#   '00000000-0000-0000-35B0-1BE12F2C8DE3',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-05-31T00:00:00',
#   'Albemarle',
#   'VA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '31',
#   '32',
#   '3.12500'],
#  ['row-uhy2-je4i_risj',
#   '00000000-0000-0000-4BFA-C0DBA080DB38',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-10-31T00:00:00',
#   'Monterey',
#   'CA',
#   'Passenger',
#   '0',
#   '2',
#   '2',
#   '194',
#   '196',
#   '1.020408163265306122448979592'],
#  ['row-ws9i-at96-jjim',
#   '00000000-0000-0000-1BEA-6E51CBCFA6AD',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-05-31T00:00:00',
#   'Alameda',
#   'CA',
#   'Passenger',
#   '1',
#   '1',
#   '2',
#   '376',
#   '378',
#   '0.5291005291005291005291005291'],
#  ['row-wqen_e52h.diwk',
#   '00000000-0000-0000-D5AE-CBA40EE5F73A',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-01-31T00:00:00',
#   'Duval',
#   'FL',
#   'Passenger',
#   '0',
#   '2',
#   '2',
#   '321',
#   '323',
#   '0.6191950464396284829721362229'],
#  ['row-jcrw.5mtm~mfhc',
#   '00000000-0000-0000-C191-C33CC2BB7269',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-09-30T00:00:00',
#   'Nueces',
#   'TX',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '67',
#   '68',
#   '1.470588235294117647058823529'],
#  ['row-zvs5~3378.yesc',
#   '00000000-0000-0000-3A5D-7025275F1E2A',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-12-31T00:00:00',
#   'Stafford',
#   'VA',
#   'Passenger',
#   '3',
#   '0',
#   '3',
#   '72',
#   '75',
#   '4.00'],
#  ['row-uhhn.jg3n-gcew',
#   '00000000-0000-0000-67B1-8F175802FE2E',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-06-30T00:00:00',
#   'Riverside',
#   'CA',
#   'Passenger',
#   '8',
#   '1',
#   '9',
#   '480',
#   '489',
#   '1.840490797546012269938650307'],
#  ['row-kikm.c4cv~rr2g',
#   '00000000-0000-0000-DCC8-2814EA9B913C',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-10-31T00:00:00',
#   'Clark',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '83992',
#   '83992',
#   '0'],
#  ['row-4pxv.w7vq_gvgx',
#   '00000000-0000-0000-A060-103D598389D3',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-06-30T00:00:00',
#   'Benton',
#   'WA',
#   'Truck',
#   '3',
#   '0',
#   '3',
#   '43557',
#   '43560',
#   '0.006887052341597796143250688705'],
#  ['row-b46j_s7xq-uwih',
#   '00000000-0000-0000-F076-6AB308A78396',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-06-30T00:00:00',
#   'Mason',
#   'WA',
#   'Passenger',
#   '445',
#   '206',
#   '651',
#   '46320',
#   '46971',
#   '1.385961550744076132081497094'],
#  ['row-r8ge_75qb_khhh',
#   '00000000-0000-0000-3E70-A62978D25CCD',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2017-09-30T00:00:00',
#   'District of Columbia',
#   'DC',
#   'Passenger',
#   '0',
#   '2',
#   '2',
#   '202',
#   '204',
#   '0.9803921568627450980392156863'],
#  ['row-r8dy~b8ee-rzvp',
#   '00000000-0000-0000-EAB8-AF2C49B1EC81',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-05-31T00:00:00',
#   'Ventura',
#   'CA',
#   'Passenger',
#   '0',
#   '2',
#   '2',
#   '321',
#   '323',
#   '0.6191950464396284829721362229'],
#  ['row-s48u-wkqs_5eut',
#   '00000000-0000-0000-C44B-A6854047720E',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-06-30T00:00:00',
#   'Jefferson',
#   'WA',
#   'Truck',
#   '12',
#   '0',
#   '12',
#   '9332',
#   '9344',
#   '0.1284246575342465753424657534'],
#  ['row-vxqe~47jp-vjsy',
#   '00000000-0000-0000-3E67-165BEBBACFAB',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-03-31T00:00:00',
#   'Wichita',
#   'TX',
#   'Passenger',
#   '2',
#   '0',
#   '2',
#   '39',
#   '41',
#   '4.878048780487804878048780488'],
#  ['row-kb8v.3erg.9kr8',
#   '00000000-0000-0000-97C5-EA771E7415E9',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-05-31T00:00:00',
#   'Hawaii',
#   'HI',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '42',
#   '43',
#   '2.325581395348837209302325581'],
#  ['row-r84x.pi6i.tvbr',
#   '00000000-0000-0000-15C6-86609149672A',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2019-10-31T00:00:00',
#   'Whitman',
#   'WA',
#   'Passenger',
#   '38',
#   '45',
#   '83',
#   '22706',
#   '22789',
#   '0.3642108034578085918644960288'],
#  ['row-wbui.g3wv_43hy',
#   '00000000-0000-0000-1EA3-CAAF05C150D5',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-07-31T00:00:00',
#   'Hennepin',
#   'MN',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '36',
#   '37',
#   '2.702702702702702702702702703'],
#  ['row-rc5z_2gvd-fz2c',
#   '00000000-0000-0000-8D71-AAC74D646345',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2023-05-31T00:00:00',
#   'Kittitas',
#   'WA',
#   'Passenger',
#   '344',
#   '104',
#   '448',
#   '29417',
#   '29865',
#   '1.500083710028461409676879290'],
#  ['row-xz4e.wn69_rrxb',
#   '00000000-0000-0000-9145-3A7E2CBDE629',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2021-04-30T00:00:00',
#   'Lincoln',
#   'WA',
#   'Passenger',
#   '5',
#   '13',
#   '18',
#   '7749',
#   '7767',
#   '0.2317497103128621089223638470'],
#  ['row-r525-hxgn~6rdq',
#   '00000000-0000-0000-0376-466D3CC6F405',
#   0,
#   1713474420,
#   None,
#   1713474420,
#   None,
#   '{ }',
#   '2022-10-31T00:00:00',
#   'Cumberland',
#   'NC',
#   'Passenger',
#   '1',
#   '4',
#   '5',
#   '360',
#   '365',
#   '1.369863013698630136986301370'],
#  ...]

# %%
info = newdata['data']
df = pd.DataFrame(info)
df
# Out:
#                        0                                     1   2   \
# 0      row-txmj.9xki-teqc  00000000-0000-0000-3BEB-D46C134BD6D7   0
# 1      row-2h8w.5k3c~aukx  00000000-0000-0000-423F-847EA1E0E72A   0
# 2      row-3snj~v22r~5cky  00000000-0000-0000-8FE3-66BD5DC299BD   0
# 3      row-im3h-cypn_ycer  00000000-0000-0000-94D4-27279BD8C159   0
# 4      row-756x_sycu_v9c6  00000000-0000-0000-B273-329343B58BB6   0
# ...                   ...                                   ...  ..
# 21202  row-g9we-6z4j-cmuk  00000000-0000-0000-286A-2B55FDD3DC13   0
# 21203  row-rbxz~pbdg-whct  00000000-0000-0000-2B55-11E4FBA1B8EC   0
# 21204  row-nxmt.btp3~mz7h  00000000-0000-0000-2EE9-1190C3DC0364   0
# 21205  row-jxg4.pyzd_2v87  00000000-0000-0000-FAE0-9D76E3E16804   0
# 21206  row-7zwz~rewr.kdia  00000000-0000-0000-8EEA-2E3C14A1FE8D   0
#
#                3     4           5     6    7                    8   \
# 0      1713474420  None  1713474420  None  { }  2022-04-30T00:00:00
# 1      1713474420  None  1713474420  None  { }  2017-05-31T00:00:00
# 2      1713474420  None  1713474420  None  { }  2019-10-31T00:00:00
# 3      1713474420  None  1713474420  None  { }  2024-01-31T00:00:00
# 4      1713474420  None  1713474420  None  { }  2018-02-28T00:00:00
# ...           ...   ...         ...   ...  ...                  ...
# 21202  1713474420  None  1713474420  None  { }  2021-03-31T00:00:00
# 21203  1713474420  None  1713474420  None  { }  2023-02-28T00:00:00
# 21204  1713474420  None  1713474420  None  { }  2020-06-30T00:00:00
# 21205  1713474420  None  1713474420  None  { }  2020-02-29T00:00:00
# 21206  1713474420  None  1713474420  None  { }  2021-07-31T00:00:00
#
#                  9   10         11   12  13   14     15     16  \
# 0         Wahkiakum  WA      Truck    0   0    0   1815   1815
# 1             Adams  WA      Truck    0   0    0   5079   5079
# 2            Collin  TX  Passenger    2   1    3    142    145
# 3          Franklin  WA      Truck   10   0   10  20616  20626
# 4      Grays Harbor  WA      Truck    0   0    0  20109  20109
# ...             ...  ..        ...  ...  ..  ...    ...    ...
# 21202   Carson City  NV  Passenger    1   0    1     12     13
# 21203         Adams  WA  Passenger   21  11   32  13009  13041
# 21204       Douglas  NE  Passenger    0   1    1     55     56
# 21205        Chelan  WA  Passenger  216  78  294  54600  54894
# 21206    Chesapeake  VA  Passenger    0   3    3    411    414
#
#                                     17
# 0                                    0
# 1                                    0
# 2        2.068965517241379310344827586
# 3      0.04848249781828759817705808203
# 4                                    0
# ...                                ...
# 21202    7.692307692307692307692307692
# 21203   0.2453799555248830611149451729
# 21204    1.785714285714285714285714286
# 21205   0.5355776587605202754399387911
# 21206   0.7246376811594202898550724638
#
# [21207 rows x 18 columns]

# %%
df1 = df.drop(df.columns[0:8], axis=1)
df1
# Out:
#                         8             9   10         11   12  13   14     15  \
# 0      2022-04-30T00:00:00     Wahkiakum  WA      Truck    0   0    0   1815
# 1      2017-05-31T00:00:00         Adams  WA      Truck    0   0    0   5079
# 2      2019-10-31T00:00:00        Collin  TX  Passenger    2   1    3    142
# 3      2024-01-31T00:00:00      Franklin  WA      Truck   10   0   10  20616
# 4      2018-02-28T00:00:00  Grays Harbor  WA      Truck    0   0    0  20109
# ...                    ...           ...  ..        ...  ...  ..  ...    ...
# 21202  2021-03-31T00:00:00   Carson City  NV  Passenger    1   0    1     12
# 21203  2023-02-28T00:00:00         Adams  WA  Passenger   21  11   32  13009
# 21204  2020-06-30T00:00:00       Douglas  NE  Passenger    0   1    1     55
# 21205  2020-02-29T00:00:00        Chelan  WA  Passenger  216  78  294  54600
# 21206  2021-07-31T00:00:00    Chesapeake  VA  Passenger    0   3    3    411
#
#           16                               17
# 0       1815                                0
# 1       5079                                0
# 2        145    2.068965517241379310344827586
# 3      20626  0.04848249781828759817705808203
# 4      20109                                0
# ...      ...                              ...
# 21202     13    7.692307692307692307692307692
# 21203  13041   0.2453799555248830611149451729
# 21204     56    1.785714285714285714285714286
# 21205  54894   0.5355776587605202754399387911
# 21206    414   0.7246376811594202898550724638
#
# [21207 rows x 10 columns]

# %%
df1 = df1.set_axis(['Date','County','State','Vehicle Primary Use','Battery Electric Vehicles (BEVs)','Plug-In Hybrid Electric Vehicles (PHEVs)','Electric Vehicle (EV) Total','Non-Electric Vehicle Total','Total Vehicles','Percent Electric Vehicles'], axis=1)
df1
# Out:
#                       Date        County State Vehicle Primary Use  \
# 0      2022-04-30T00:00:00     Wahkiakum    WA               Truck
# 1      2017-05-31T00:00:00         Adams    WA               Truck
# 2      2019-10-31T00:00:00        Collin    TX           Passenger
# 3      2024-01-31T00:00:00      Franklin    WA               Truck
# 4      2018-02-28T00:00:00  Grays Harbor    WA               Truck
# ...                    ...           ...   ...                 ...
# 21202  2021-03-31T00:00:00   Carson City    NV           Passenger
# 21203  2023-02-28T00:00:00         Adams    WA           Passenger
# 21204  2020-06-30T00:00:00       Douglas    NE           Passenger
# 21205  2020-02-29T00:00:00        Chelan    WA           Passenger
# 21206  2021-07-31T00:00:00    Chesapeake    VA           Passenger
#
#       Battery Electric Vehicles (BEVs)  \
# 0                                    0
# 1                                    0
# 2                                    2
# 3                                   10
# 4                                    0
# ...                                ...
# 21202                                1
# 21203                               21
# 21204                                0
# 21205                              216
# 21206                                0
#
#       Plug-In Hybrid Electric Vehicles (PHEVs) Electric Vehicle (EV) Total  \
# 0                                            0                           0
# 1                                            0                           0
# 2                                            1                           3
# 3                                            0                          10
# 4                                            0                           0
# ...                                        ...                         ...
# 21202                                        0                           1
# 21203                                       11                          32
# 21204                                        1                           1
# 21205                                       78                         294
# 21206                                        3                           3
#
#       Non-Electric Vehicle Total Total Vehicles  \
# 0                           1815           1815
# 1                           5079           5079
# 2                            142            145
# 3                          20616          20626
# 4                          20109          20109
# ...                          ...            ...
# 21202                         12             13
# 21203                      13009          13041
# 21204                         55             56
# 21205                      54600          54894
# 21206                        411            414
#
#              Percent Electric Vehicles
# 0                                    0
# 1                                    0
# 2        2.068965517241379310344827586
# 3      0.04848249781828759817705808203
# 4                                    0
# ...                                ...
# 21202    7.692307692307692307692307692
# 21203   0.2453799555248830611149451729
# 21204    1.785714285714285714285714286
# 21205   0.5355776587605202754399387911
# 21206   0.7246376811594202898550724638
#
# [21207 rows x 10 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21207 entries, 0 to 21206
# Data columns (total 10 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Date                                      21207 non-null  object
#  1   County                                    21120 non-null  object
#  2   State                                     21120 non-null  object
#  3   Vehicle Primary Use                       21207 non-null  object
#  4   Battery Electric Vehicles (BEVs)          21207 non-null  object
#  5   Plug-In Hybrid Electric Vehicles (PHEVs)  21207 non-null  object
#  6   Electric Vehicle (EV) Total               21207 non-null  object
#  7   Non-Electric Vehicle Total                21207 non-null  object
#  8   Total Vehicles                            21207 non-null  object
#  9   Percent Electric Vehicles                 21207 non-null  object
# dtypes: object(10)
# memory usage: 1.6+ MB

# %%
df1.describe()
# Out:
#                        Date   County  State Vehicle Primary Use  \
# count                 21207    21120  21120               21207
# unique                   87      313     50                   2
# top     2022-04-30T00:00:00  Douglas     WA           Passenger
# freq                    285      291   6786               17721
#
#        Battery Electric Vehicles (BEVs)  \
# count                             21207
# unique                             1221
# top                                   1
# freq                               7054
#
#        Plug-In Hybrid Electric Vehicles (PHEVs) Electric Vehicle (EV) Total  \
# count                                     21207                       21207
# unique                                      944                        1421
# top                                           0                           1
# freq                                      10010                        9510
#
#        Non-Electric Vehicle Total Total Vehicles Percent Electric Vehicles
# count                       21207          21207                     21207
# unique                       7150           7155                      6343
# top                             1              2                         0
# freq                          298            298                      2270
