# %% [markdown]
# ## Actividad VI- Obtención datos desde API
#
# **Consigna**
#
# 1. Buscar información en APIs públicas (i.e Twitter, NewsAPI, Spotify, Google Apis, etc).
#
# 2. Extraer datos e importarlos a un dataframe realizando una exploración simple (i.e filas, columnas, tipos de datos). Se sugiere que estos datos complementen el dataset elegido en el Elección de potenciales Datasets e importe con la librería Pandas.

# %% [markdown]
# **Desarrollo**
#
# Me interesa conocer el comportamiento de la popularidad de ventas de vehículos eléctricos, en éste caso se evalúan datos del Estado de Washington en Estados Unidos.
#
# Seleccioné el siguiente Dataset para el proyecto desde las actividades anteriores.
# Este Dataset muestra los Vehículos de Batería Eléctrica (BEVs) y Vehículos Eléctricos Híbridos (PHEVs), registrados actualmente en el Departamento de Licencias del Estado de Washington (DOL). Metadata Actualizada: March 16, 2024 URL: https://catalog.data.gov/dataset/electric-vehicle-population-data

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Cargamos el Dataset original del proyecto, mediante la librería pandas, para compararlo con el nuevo obtenido para ésta activiad mediante API Pública.**

# %%
Dataset = pd.read_csv("https://raw.githubusercontent.com/Fab-RG/Bootcamp-DS/main/Actividad%202/Electric_Vehicle_Population_Data.csv", sep=",")
Dataset.head()
# Out:
#    VIN (1-10)     County       City State  Postal Code  Model Year   Make  \
# 0  5YJYGDEE1L       King    Seattle    WA      98122.0        2020  TESLA
# 1  7SAYGDEE9P  Snohomish    Bothell    WA      98021.0        2023  TESLA
# 2  5YJSA1E4XK       King    Seattle    WA      98109.0        2019  TESLA
# 3  5YJSA1E27G       King   Issaquah    WA      98027.0        2016  TESLA
# 4  5YJYGDEE5M     Kitsap  Suquamish    WA      98392.0        2021  TESLA
#
#      Model           Electric Vehicle Type  \
# 0  MODEL Y  Battery Electric Vehicle (BEV)
# 1  MODEL Y  Battery Electric Vehicle (BEV)
# 2  MODEL S  Battery Electric Vehicle (BEV)
# 3  MODEL S  Battery Electric Vehicle (BEV)
# 4  MODEL Y  Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible             291
# 1  Eligibility unknown as battery range has not b...               0
# 2            Clean Alternative Fuel Vehicle Eligible             270
# 3            Clean Alternative Fuel Vehicle Eligible             210
# 4  Eligibility unknown as battery range has not b...               0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                  37.0       125701579
# 1          0                   1.0       244285107
# 2          0                  36.0       156773144
# 3          0                   5.0       165103011
# 4          0                  23.0       205138552
#
#                 Vehicle Location  \
# 0   POINT (-122.30839 47.610365)
# 1  POINT (-122.179458 47.802589)
# 2   POINT (-122.34848 47.632405)
# 3   POINT (-122.03646 47.534065)
# 4   POINT (-122.55717 47.733415)
#
#                                 Electric Utility  2020 Census Tract
# 0   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 1                         PUGET SOUND ENERGY INC       5.306105e+10
# 2   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 3  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 4                         PUGET SOUND ENERGY INC       5.303594e+10

# %% [markdown]
# **El nuevo Dataset que descargamos para ésta actividad es el siguiente.**

# %%
NewData = pd.read_csv("Electric_Vehicle_Population_Size_History_By_County.csv", sep=",")
NewData.head()
# Out:
#                Date        County State Vehicle Primary Use  \
# 0     April 30 2022     Wahkiakum    WA               Truck
# 1       May 31 2017         Adams    WA               Truck
# 2   October 31 2019        Collin    TX           Passenger
# 3   January 31 2024      Franklin    WA               Truck
# 4  February 28 2018  Grays Harbor    WA               Truck
#
#    Battery Electric Vehicles (BEVs)  Plug-In Hybrid Electric Vehicles (PHEVs)  \
# 0                                 0                                         0
# 1                                 0                                         0
# 2                                 2                                         1
# 3                                10                                         0
# 4                                 0                                         0
#
#    Electric Vehicle (EV) Total  Non-Electric Vehicle Total  Total Vehicles  \
# 0                            0                        1815            1815
# 1                            0                        5079            5079
# 2                            3                         142             145
# 3                           10                       20616           20626
# 4                            0                       20109           20109
#
#    Percent Electric Vehicles
# 0                       0.00
# 1                       0.00
# 2                       2.07
# 3                       0.05
# 4                       0.00

# %% [markdown]
# **1. Se importa nuevo Dataset, medianta API Pública, con información de vehículos eléctricos registrados en Estado de Washington en Estados Unidos, discriminados por Condados.**

# %%
import requests                                    
url = "https://data.wa.gov/api/views/3d5d-sdqb/rows.json?accessType=DOWNLOAD"       
headers = {"Accept-Encoding": "gzip, deflate"}     
response = requests.get(url, headers=headers)      
newdata = response.json()                            
newdata
# Out:
# {'meta': {'view': {'id': '3d5d-sdqb',
#    'name': 'Electric Vehicle Population Size History By County',
#    'assetType': 'dataset',
#    'attribution': 'Washington State Department of Licensing',
#    'averageRating': 0,
#    'category': 'Transportation',
#    'createdAt': 1591046256,
#    'description': 'This shows the number of vehicles that were registered by Washington State Department of Licensing (DOL) each month. The data is separated by county for passenger vehicles and trucks. \n\nDOL integrates National Highway Traffic Safety Administration (NHTSA) data and the Environmental Protection Agency (EPA) fuel efficiency ratings with DOL titling and registration data to create this information.',
#    'displayType': 'table',
#    'downloadCount': 10193,
#    'hideFromCatalog': False,
#    'hideFromDataJson': False,
#    'licenseId': 'ODBL',
#    'locked': False,
#    'newBackend': True,
#    'numberOfComments': 0,
#    'oid': 34339220,
#    'provenance': 'official',
#    'publicationAppendEnabled': False,
#    'publicationDate': 1591379619,
#    'publicationGroup': 17186729,
#    'publicationStage': 'published',
#    'rowsUpdatedAt': 1716314813,
#    'rowsUpdatedBy': 'kgaq-6gwr',
#    'tableId': 17199524,
#    'totalTimesRated': 0,
#    'viewCount': 3856,
#    'viewLastModified': 1716314806,
#    'viewType': 'tabular',
#    'approvals': [{'reviewedAt': 1591380915,
#      'reviewedAutomatically': True,
#      'state': 'approved',
#      'submissionId': 2285192,
#      'submissionObject': 'public_audience_request',
#      'submissionOutcome': 'change_audience',
#      'submittedAt': 1591380915,
#      'targetAudience': 'public',
#      'workflowId': 2106,
#      'submissionDetails': {'permissionType': 'READ'},
#      'submissionOutcomeApplication': {'endedAt': 1591380916,
#       'failureCount': 0,
#       'startedAt': 1591380915,
#       'status': 'success'},
#      'submitter': {'id': 'dphz-szpx', 'displayName': 'Faith'}}],
#    'clientContext': {'clientContextVariables': [], 'inheritedVariables': {}},
#    'columns': [{'id': -1,
#      'name': 'sid',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':sid',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'id',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':id',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'position',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':position',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'created_at',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':created_at',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'created_meta',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':created_meta',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'updated_at',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':updated_at',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'updated_meta',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':updated_meta',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'meta',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':meta',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': 472621118,
#      'name': 'Date',
#      'dataTypeName': 'calendar_date',
#      'description': 'Counts of registered vehicles are taken on this day (the end of this month).',
#      'fieldName': 'date',
#      'position': 1,
#      'renderTypeName': 'calendar_date',
#      'tableColumnId': 103990567,
#      'cachedContents': {'non_null': '21582',
#       'largest': '2024-04-30T00:00:00.000',
#       'null': '0',
#       'top': [{'item': '2022-11-30T00:00:00.000', 'count': '289'},
#        {'item': '2022-10-31T00:00:00.000', 'count': '288'},
#        {'item': '2022-04-30T00:00:00.000', 'count': '288'},
#        {'item': '2022-12-31T00:00:00.000', 'count': '288'},
#        {'item': '2023-02-28T00:00:00.000', 'count': '287'},
#        {'item': '2022-09-30T00:00:00.000', 'count': '287'},
#        {'item': '2023-01-31T00:00:00.000', 'count': '287'},
#        {'item': '2022-03-31T00:00:00.000', 'count': '286'},
#        {'item': '2023-03-31T00:00:00.000', 'count': '285'},
#        {'item': '2022-06-30T00:00:00.000', 'count': '285'},
#        {'item': '2022-05-31T00:00:00.000', 'count': '285'},
#        {'item': '2023-04-30T00:00:00.000', 'count': '285'},
#        {'item': '2022-08-31T00:00:00.000', 'count': '283'},
#        {'item': '2022-02-28T00:00:00.000', 'count': '282'},
#        {'item': '2023-05-31T00:00:00.000', 'count': '281'},
#        {'item': '2022-07-31T00:00:00.000', 'count': '281'},
#        {'item': '2021-10-31T00:00:00.000', 'count': '281'},
#        {'item': '2021-11-30T00:00:00.000', 'count': '280'},
#        {'item': '2022-01-31T00:00:00.000', 'count': '280'},
#        {'item': '2023-06-30T00:00:00.000', 'count': '278'}],
#       'smallest': '2017-01-31T00:00:00.000',
#       'count': '21582',
#       'cardinality': '88'},
#      'format': {'view': 'date_monthdy'}},
#     {'id': 472621119,
#      'name': 'County',
#      'dataTypeName': 'text',
#      'description': "This is the geographic region of a state that a vehicle's owner is listed to reside within. Vehicles registered in Washington state may be located in other states.",
#      'fieldName': 'county',
#      'position': 2,
#      'renderTypeName': 'text',
#      'tableColumnId': 103990568,
#      'cachedContents': {'non_null': '21494',
#       'largest': 'Yuba',
#       'null': '88',
#       'top': [{'item': 'Douglas', 'count': '295'},
#        {'item': 'Montgomery', 'count': '291'},
#        {'item': 'Jefferson', 'count': '268'},
#        {'item': 'Clark', 'count': '264'},
#        {'item': 'Franklin', 'count': '223'},
#        {'item': 'Columbia', 'count': '223'},
#        {'item': 'Orange', 'count': '207'},
#        {'item': 'Adams', 'count': '202'},
#        {'item': 'Lincoln', 'count': '199'},
#        {'item': 'Garfield', 'count': '196'},
#        {'item': 'San Juan', 'count': '187'},
#        {'item': 'Lewis', 'count': '180'},
#        {'item': 'Mason', 'count': '176'},
#        {'item': 'Walla Walla', 'count': '176'},
#        {'item': 'Asotin', 'count': '176'},
#        {'item': 'Pacific', 'count': '176'},
#        {'item': 'Clallam', 'count': '176'},
#        {'item': 'Stevens', 'count': '176'},
#        {'item': 'Okanogan', 'count': '176'},
#        {'item': 'Thurston', 'count': '176'}],
#       'smallest': 'Ada',
#       'count': '21582',
#       'cardinality': '315'},
#      'format': {}},
#     {'id': 472621120,
#      'name': 'State',
#      'dataTypeName': 'text',
#      'description': 'This is the geographic region of the country associated with the record. These addresses may be located in other states.',
#      'fieldName': 'state',
#      'position': 3,
#      'renderTypeName': 'text',
#      'tableColumnId': 103990558,
#      'cachedContents': {'non_null': '21494',
#       'largest': 'WY',
#       'null': '88',
#       'top': [{'item': 'WA', 'count': '6864'},
#        {'item': 'CA', 'count': '1719'},
#        {'item': 'VA', 'count': '1354'},
#        {'item': 'FL', 'count': '1133'},
#        {'item': 'TX', 'count': '1103'},
#        {'item': 'MD', 'count': '782'},
#        {'item': 'OR', 'count': '544'},
#        {'item': 'CO', 'count': '517'},
#        {'item': 'GA', 'count': '493'},
#        {'item': 'NC', 'count': '468'},
#        {'item': 'NY', 'count': '440'},
#        {'item': 'NJ', 'count': '391'},
#        {'item': 'IL', 'count': '383'},
#        {'item': 'ID', 'count': '320'},
#        {'item': 'HI', 'count': '309'},
#        {'item': 'AZ', 'count': '308'},
#        {'item': 'SC', 'count': '299'},
#        {'item': 'MA', 'count': '284'},
#        {'item': 'PA', 'count': '278'},
#        {'item': 'MO', 'count': '268'}],
#       'smallest': 'AK',
#       'count': '21582',
#       'cardinality': '50'},
#      'format': {}},
#     {'id': 472621121,
#      'name': 'Vehicle Primary Use',
#      'dataTypeName': 'text',
#      'description': 'This describes the primary intended use of the vehicle.',
#      'fieldName': 'vehicle_primary_use',
#      'position': 4,
#      'renderTypeName': 'text',
#      'tableColumnId': 104001400,
#      'cachedContents': {'non_null': '21582',
#       'largest': 'Truck',
#       'null': '0',
#       'top': [{'item': 'Passenger', 'count': '18052'},
#        {'item': 'Truck', 'count': '3530'}],
#       'smallest': 'Passenger',
#       'count': '21582',
#       'cardinality': '2'},
#      'format': {}},
#     {'id': 472621122,
#      'name': 'Battery Electric Vehicles (BEVs)',
#      'dataTypeName': 'number',
#      'description': 'The count of vehicles that are known to be propelled solely by an energy derived from an onboard electric battery.',
#      'fieldName': 'battery_electric_vehicles_bevs_',
#      'position': 5,
#      'renderTypeName': 'number',
#      'tableColumnId': 104001399,
#      'cachedContents': {'non_null': '21582',
#       'largest': '75487',
#       'null': '0',
#       'top': [{'item': '1', 'count': '7203'},
#        {'item': '0', 'count': '6893'},
#        {'item': '2', 'count': '1875'},
#        {'item': '3', 'count': '822'},
#        {'item': '4', 'count': '418'},
#        {'item': '5', 'count': '326'},
#        {'item': '6', 'count': '210'},
#        {'item': '7', 'count': '170'},
#        {'item': '8', 'count': '134'},
#        {'item': '9', 'count': '86'},
#        {'item': '10', 'count': '80'},
#        {'item': '12', 'count': '68'},
#        {'item': '11', 'count': '52'},
#        {'item': '17', 'count': '49'},
#        {'item': '19', 'count': '42'},
#        {'item': '16', 'count': '42'},
#        {'item': '18', 'count': '38'},
#        {'item': '20', 'count': '36'},
#        {'item': '21', 'count': '36'},
#        {'item': '23', 'count': '36'}],
#       'smallest': '0',
#       'count': '21582',
#       'cardinality': '1238'},
#      'format': {}},
#     {'id': 472621123,
#      'name': 'Plug-In Hybrid Electric Vehicles (PHEVs)',
#      'dataTypeName': 'number',
#      'description': 'The count of vehicles that are known to be propelled from energy partially sourced from an onboard electric battery that is capable of being recharged from an external source.',
#      'fieldName': 'plug_in_hybrid_electric_vehicles_phevs_',
#      'position': 6,
#      'renderTypeName': 'number',
#      'tableColumnId': 104001398,
#      'cachedContents': {'non_null': '21582',
#       'largest': '18450',
#       'null': '0',
#       'top': [{'item': '0', 'count': '10234'},
#        {'item': '1', 'count': '5811'},
#        {'item': '2', 'count': '1491'},
#        {'item': '3', 'count': '512'},
#        {'item': '4', 'count': '231'},
#        {'item': '5', 'count': '145'},
#        {'item': '6', 'count': '86'},
#        {'item': '7', 'count': '76'},
#        {'item': '8', 'count': '37'},
#        {'item': '12', 'count': '36'},
#        {'item': '9', 'count': '36'},
#        {'item': '11', 'count': '32'},
#        {'item': '19', 'count': '30'},
#        {'item': '17', 'count': '29'},
#        {'item': '21', 'count': '29'},
#        {'item': '33', 'count': '28'},
#        {'item': '10', 'count': '25'},
#        {'item': '22', 'count': '24'},
#        {'item': '18', 'count': '23'},
#        {'item': '32', 'count': '22'}],
#       'smallest': '0',
#       'count': '21582',
#       'cardinality': '950'},
#      'format': {}},
#     {'id': 472621124,
#      'name': 'Electric Vehicle (EV) Total',
#      'dataTypeName': 'number',
#      'description': 'The sum of Battery Electric Vehicles (BEVs) and Plug-in Hybrid Electric Vehicles (PHEVs).',
#      'fieldName': 'electric_vehicle_ev_total',
#      'position': 7,
#      'renderTypeName': 'number',
#      'tableColumnId': 103990566,
#      'cachedContents': {'non_null': '21582',
#       'largest': '93937',
#       'null': '0',
#       'top': [{'item': '1', 'count': '9661'},
#        {'item': '2', 'count': '2692'},
#        {'item': '0', 'count': '2273'},
#        {'item': '3', 'count': '1164'},
#        {'item': '4', 'count': '712'},
#        {'item': '5', 'count': '376'},
#        {'item': '6', 'count': '294'},
#        {'item': '7', 'count': '262'},
#        {'item': '8', 'count': '180'},
#        {'item': '9', 'count': '145'},
#        {'item': '10', 'count': '122'},
#        {'item': '11', 'count': '82'},
#        {'item': '12', 'count': '81'},
#        {'item': '13', 'count': '75'},
#        {'item': '14', 'count': '50'},
#        {'item': '15', 'count': '47'},
#        {'item': '16', 'count': '39'},
#        {'item': '19', 'count': '37'},
#        {'item': '17', 'count': '32'},
#        {'item': '18', 'count': '31'}],
#       'smallest': '0',
#       'count': '21582',
#       'cardinality': '1432'},
#      'format': {}},
#     {'id': 472621125,
#      'name': 'Non-Electric Vehicle Total',
#      'dataTypeName': 'number',
#      'description': 'The count of vehicles that are not electric vehicles.',
#      'fieldName': 'non_electric_vehicles',
#      'position': 8,
#      'renderTypeName': 'number',
#      'tableColumnId': 104098606,
#      'cachedContents': {'non_null': '21582',
#       'largest': '1399671',
#       'null': '0',
#       'top': [{'item': '1', 'count': '301'},
#        {'item': '5', 'count': '221'},
#        {'item': '4', 'count': '196'},
#        {'item': '6', 'count': '185'},
#        {'item': '3', 'count': '180'},
#        {'item': '0', 'count': '163'},
#        {'item': '11', 'count': '153'},
#        {'item': '7', 'count': '153'},
#        {'item': '13', 'count': '150'},
#        {'item': '12', 'count': '145'},
#        {'item': '9', 'count': '139'},
#        {'item': '10', 'count': '136'},
#        {'item': '21', 'count': '135'},
#        {'item': '18', 'count': '125'},
#        {'item': '20', 'count': '125'},
#        {'item': '36', 'count': '122'},
#        {'item': '38', 'count': '118'},
#        {'item': '8', 'count': '117'},
#        {'item': '19', 'count': '116'},
#        {'item': '40', 'count': '114'}],
#       'smallest': '0',
#       'count': '21582',
#       'cardinality': '7213'},
#      'format': {}},
#     {'id': 472621126,
#      'name': 'Total Vehicles',
#      'dataTypeName': 'number',
#      'description': 'All powered vehicles registered in the county. This includes electric vehicles.',
#      'fieldName': 'total_vehicles',
#      'position': 9,
#      'renderTypeName': 'number',
#      'tableColumnId': 104001397,
#      'cachedContents': {'non_null': '21582',
#       'largest': '1430786',
#       'null': '0',
#       'top': [{'item': '2', 'count': '301'},
#        {'item': '6', 'count': '221'},
#        {'item': '5', 'count': '197'},
#        {'item': '7', 'count': '184'},
#        {'item': '4', 'count': '179'},
#        {'item': '1', 'count': '163'},
#        {'item': '14', 'count': '155'},
#        {'item': '12', 'count': '146'},
#        {'item': '8', 'count': '146'},
#        {'item': '11', 'count': '141'},
#        {'item': '13', 'count': '138'},
#        {'item': '21', 'count': '136'},
#        {'item': '10', 'count': '132'},
#        {'item': '38', 'count': '128'},
#        {'item': '22', 'count': '127'},
#        {'item': '37', 'count': '125'},
#        {'item': '19', 'count': '123'},
#        {'item': '15', 'count': '119'},
#        {'item': '41', 'count': '116'},
#        {'item': '9', 'count': '116'}],
#       'smallest': '1',
#       'count': '21582',
#       'cardinality': '7230'},
#      'format': {}},
#     {'id': 472621127,
#      'name': 'Percent Electric Vehicles',
#      'dataTypeName': 'number',
#      'description': 'Comparison of electric vehicles versus their non-electric counterparts.',
#      'fieldName': 'percent_electric_vehicles',
#      'position': 10,
#      'renderTypeName': 'number',
#      'tableColumnId': 104099062,
#      'cachedContents': {'non_null': '21582',
#       'largest': '100',
#       'null': '0',
#       'top': [{'item': '0', 'count': '2273'},
#        {'item': '50.0', 'count': '301'},
#        {'item': '16.66666666666666666666666667', 'count': '229'},
#        {'item': '14.28571428571428571428571429', 'count': '209'},
#        {'item': '20.0', 'count': '202'},
#        {'item': '25.00', 'count': '183'},
#        {'item': '100', 'count': '163'},
#        {'item': '12.500', 'count': '159'},
#        {'item': '8.333333333333333333333333333', 'count': '151'},
#        {'item': '7.142857142857142857142857143', 'count': '147'},
#        {'item': '5.263157894736842105263157895', 'count': '146'},
#        {'item': '11.11111111111111111111111111', 'count': '144'},
#        {'item': '10.0', 'count': '142'},
#        {'item': '4.761904761904761904761904762', 'count': '142'},
#        {'item': '4.545454545454545454545454545', 'count': '139'},
#        {'item': '9.090909090909090909090909091', 'count': '138'},
#        {'item': '7.692307692307692307692307692', 'count': '136'},
#        {'item': '5.00', 'count': '129'},
#        {'item': '4.166666666666666666666666667', 'count': '128'},
#        {'item': '3.571428571428571428571428571', 'count': '123'}],
#       'smallest': '0',
#       'count': '21582',
#       'cardinality': '6400'},
#      'format': {'precision': '2'}}],
#    'grants': [{'inherited': False, 'type': 'viewer', 'flags': ['public']}],
#    'license': {'name': 'Open Data Commons Open Database License',
#     'termsLink': 'http://opendatacommons.org/licenses/odbl/1.0/'},
#    'metadata': {'custom_fields': {'Temporal': {'Posting Frequency': 'Monthly',
#       'Period of Time': 'Data includes historical Electric Vehicle population counts from January 2017 through April 2024.'},
#      'Identification': {'Originator': 'Research and Analysis Office, Department of Licensing',
#       'Metadata Language': 'English'},
#      'Notes': {'1. ': 'A Battery Electric Vehicle (BEV) is an all-electric vehicle using one or more batteries to store the electrical energy that powers the motor and is charged by plugging the vehicle in to an electric power source. A Plug-in Hybrid Electric Vehicle (PHEV) is a vehicle that uses one or more batteries to power an electric motor; uses another fuel, such as gasoline or diesel, to power an internal combustion engine or other propulsion source; and is charged by plugging the vehicle in to an electric power source.',
#       '2. ': 'Vehicles registered with a military installation address may not have an assigned county. These vehicles are not included in the final counts.',
#       '3. ': 'Monthly count of vehicles for a county may change from this report and prior reports. Processes were implemented to more accurately assign county at the time of registration.'}},
#     'rowLabel': 'Monthly count of vehicles for a county',
#     'availableDisplayTypes': ['table', 'fatrow', 'page']},
#    'owner': {'id': 'eagg-6py7',
#     'displayName': 'Department of Licensing',
#     'profileImageUrlLarge': '/api/users/eagg-6py7/profile_images/LARGE',
#     'profileImageUrlMedium': '/api/users/eagg-6py7/profile_images/THUMB',
#     'profileImageUrlSmall': '/api/users/eagg-6py7/profile_images/TINY',
#     'screenName': 'Department of Licensing',
#     'type': 'interactive',
#     'flags': ['acceptedEula', 'mayBeStoriesCoOwner']},
#    'query': {},
#    'rights': ['read'],
#    'tableAuthor': {'id': 'eagg-6py7',
#     'displayName': 'Department of Licensing',
#     'profileImageUrlLarge': '/api/users/eagg-6py7/profile_images/LARGE',
#     'profileImageUrlMedium': '/api/users/eagg-6py7/profile_images/THUMB',
#     'profileImageUrlSmall': '/api/users/eagg-6py7/profile_images/TINY',
#     'screenName': 'Department of Licensing',
#     'type': 'interactive',
#     'flags': ['acceptedEula', 'mayBeStoriesCoOwner']},
#    'tags': ['battery electric',
#     'bev',
#     'plug-in',
#     'hybrid',
#     'phev',
#     'electric',
#     'vehicle',
#     'clean energy',
#     'population growth',
#     'rao_open_data',
#     'dol_open_data',
#     'department of licensing',
#     'dol',
#     'rao_ev',
#     'rao_veh'],
#    'flags': ['default',
#     'ownerMayBeContacted',
#     'restorable',
#     'restorePossibleForType']}},
#  'data': [['row-uc79~tpp3-5zxb',
#    '00000000-0000-0000-19FC-D5232A6F8D55',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2017-10-31T00:00:00',
#    'Saratoga',
#    'NY',
#    'Passenger',
#    '1',
#    '1',
#    '2',
#    '72',
#    '74',
#    '2.702702702702702702702702703'],
#   ['row-xc2i-z4xj_qa66',
#    '00000000-0000-0000-B75D-F6056FF7869D',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2017-02-28T00:00:00',
#    'Clallam',
#    'WA',
#    'Passenger',
#    '75',
#    '64',
#    '139',
#    '47978',
#    '48117',
#    '0.2888791903069601180455971902'],
#   ['row-pmup~x6gc~tm94',
#    '00000000-0000-0000-B010-7D96241E7BE6',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2020-08-31T00:00:00',
#    'Kittitas',
#    'WA',
#    'Passenger',
#    '110',
#    '47',
#    '157',
#    '29763',
#    '29920',
#    '0.5247326203208556149732620321'],
#   ['row-ucnf-kkrn_ax53',
#    '00000000-0000-0000-BF41-9DE0FFE2B78B',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2023-07-31T00:00:00',
#    'Asotin',
#    'WA',
#    'Passenger',
#    '37',
#    '23',
#    '60',
#    '12371',
#    '12431',
#    '0.4826643069744992357815139570'],
#   ['row-ikva~vuqm_4e8c',
#    '00000000-0000-0000-FBC7-67DDDA10A339',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2019-06-30T00:00:00',
#    'Riverside',
#    'CA',
#    'Passenger',
#    '2',
#    '2',
#    '4',
#    '664',
#    '668',
#    '0.5988023952095808383233532934'],
#   ['row-kdji.na4k_zv7y',
#    '00000000-0000-0000-B8D1-A16925297C54',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2017-09-30T00:00:00',
#    'DeKalb',
#    'GA',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '86',
#    '87',
#    '1.149425287356321839080459770'],
#   ['row-hp6z.y75v_zpr9',
#    '00000000-0000-0000-7FC4-7FFAA89AB190',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-08-31T00:00:00',
#    'Columbia',
#    'OR',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '18',
#    '19',
#    '5.263157894736842105263157895'],
#   ['row-mmfg~misa_6b34',
#    '00000000-0000-0000-55E0-F552A82C3BF9',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2021-10-31T00:00:00',
#    'Larimer',
#    'CO',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '48',
#    '49',
#    '2.040816326530612244897959184'],
#   ['row-9r4e~e3pw.uaxg',
#    '00000000-0000-0000-F6D2-170D2E20AEAF',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2019-07-31T00:00:00',
#    'Pacific',
#    'WA',
#    'Passenger',
#    '24',
#    '30',
#    '54',
#    '16024',
#    '16078',
#    '0.3358626694862545092673218062'],
#   ['row-iwhj.thcj_x9w6',
#    '00000000-0000-0000-FCE9-B7D18E519AF3',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2017-05-31T00:00:00',
#    'Nueces',
#    'TX',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '98',
#    '99',
#    '1.010101010101010101010101010'],
#   ['row-7j9m_x6xd_f7kt',
#    '00000000-0000-0000-8BA1-88305D05DBCE',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-10-31T00:00:00',
#    'Kootenai',
#    'ID',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '152',
#    '153',
#    '0.6535947712418300653594771242'],
#   ['row-2us7~3ahb-5egp',
#    '00000000-0000-0000-43EE-B401894E0C8C',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-04-30T00:00:00',
#    'Kern',
#    'CA',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '198',
#    '199',
#    '0.5025125628140703517587939698'],
#   ['row-fsss-kexk.s9rs',
#    '00000000-0000-0000-C54C-082276A2A4DB',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2020-01-31T00:00:00',
#    'Santa Rosa',
#    'FL',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '92',
#    '93',
#    '1.075268817204301075268817204'],
#   ['row-jehi-qf92.c4iu',
#    '00000000-0000-0000-DA01-D0714EEBCBE0',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2024-01-31T00:00:00',
#    'Lee',
#    'AL',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '12',
#    '13',
#    '7.692307692307692307692307692'],
#   ['row-jmtz~dwpm_fvam',
#    '00000000-0000-0000-E41A-7048D484960F',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2021-11-30T00:00:00',
#    'Bartow',
#    'GA',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '5',
#    '6',
#    '16.66666666666666666666666667'],
#   ['row-ammw.c7de~nyxh',
#    '00000000-0000-0000-F19B-3A63069A49DF',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2019-01-31T00:00:00',
#    'Grays Harbor',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '20316',
#    '20316',
#    '0'],
#   ['row-bpgw.ng8c-w93e',
#    '00000000-0000-0000-DEBB-6BE08C0C1E02',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2019-12-31T00:00:00',
#    'Lewis',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '26087',
#    '26087',
#    '0'],
#   ['row-3v6k~2psi.pwq9',
#    '00000000-0000-0000-2CAA-95BF0A371F0B',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2023-12-31T00:00:00',
#    'Ferry',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '3517',
#    '3517',
#    '0'],
#   ['row-fjsa~xr5n.2efq',
#    '00000000-0000-0000-8038-3A8C504E80D8',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2017-08-31T00:00:00',
#    'Utah',
#    'UT',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '155',
#    '156',
#    '0.6410256410256410256410256410'],
#   ['row-5hcu_w4mu-7zr6',
#    '00000000-0000-0000-E0C6-C9864B7F30C2',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2018-07-31T00:00:00',
#    'Washtenaw',
#    'MI',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '38',
#    '39',
#    '2.564102564102564102564102564'],
#   ['row-5n4j.j82z~d2cg',
#    '00000000-0000-0000-E51D-8527BAA71386',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2023-04-30T00:00:00',
#    'Whitman',
#    'WA',
#    'Passenger',
#    '138',
#    '72',
#    '210',
#    '21953',
#    '22163',
#    '0.9475251545368406804133014484'],
#   ['row-v27y-rkbx.sd88',
#    '00000000-0000-0000-A6CE-D72A76C514ED',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2017-02-28T00:00:00',
#    'Canyon',
#    'ID',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '110',
#    '111',
#    '0.9009009009009009009009009009'],
#   ['row-cgdu_d34f.6i4i',
#    '00000000-0000-0000-6231-C2337BCBD855',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2017-11-30T00:00:00',
#    'Garfield',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '935',
#    '935',
#    '0'],
#   ['row-nhuv~mrg6~u9gb',
#    '00000000-0000-0000-26CC-AE46F8691C22',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2017-01-31T00:00:00',
#    'Nantucket',
#    'MA',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '3',
#    '4',
#    '25.00'],
#   ['row-tdd7~z292~b9zx',
#    '00000000-0000-0000-D401-AA3D5FE9438C',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2017-05-31T00:00:00',
#    'Okanogan',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '16212',
#    '16212',
#    '0'],
#   ['row-zfe3_fc4p_d86f',
#    '00000000-0000-0000-C9AF-A89F0683D422',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-02-28T00:00:00',
#    'Escambia',
#    'FL',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '150',
#    '151',
#    '0.6622516556291390728476821192'],
#   ['row-cjj9~ajq5.hfmr',
#    '00000000-0000-0000-0B37-2EB87E84C36E',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2024-01-31T00:00:00',
#    'San Joaquin',
#    'CA',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '63',
#    '64',
#    '1.562500'],
#   ['row-txdk_6p3d.mten',
#    '00000000-0000-0000-BEC6-7916F8B4D480',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2017-04-30T00:00:00',
#    'Hamilton',
#    'TN',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '26',
#    '27',
#    '3.703703703703703703703703704'],
#   ['row-wjrz.zsmr-siqs',
#    '00000000-0000-0000-2C45-E88F1213160A',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2023-01-31T00:00:00',
#    'Richmond',
#    'NY',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '4',
#    '5',
#    '20.0'],
#   ['row-cbk7_rbyg.n4hk',
#    '00000000-0000-0000-4F33-9B3015DA996E',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-07-31T00:00:00',
#    'Carroll',
#    'NH',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '5',
#    '6',
#    '16.66666666666666666666666667'],
#   ['row-fwcp.x6vz.bw8b',
#    '00000000-0000-0000-22BF-47537F12A5E6',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2021-12-31T00:00:00',
#    'Snohomish',
#    'WA',
#    'Truck',
#    '2',
#    '0',
#    '2',
#    '125388',
#    '125390',
#    '0.001595023526597017306005263578'],
#   ['row-4a84-jers.28t8',
#    '00000000-0000-0000-69E5-299A3568CDFE',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2021-02-28T00:00:00',
#    'Spokane',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '100967',
#    '100967',
#    '0'],
#   ['row-cbb8_x4d9~53b8',
#    '00000000-0000-0000-59CE-D87BBBF3CA44',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2017-12-31T00:00:00',
#    'Benton',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '40577',
#    '40577',
#    '0'],
#   ['row-kxij~pi2q~bha9',
#    '00000000-0000-0000-DD6A-698C38CBF8B8',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2018-12-31T00:00:00',
#    'Norfolk',
#    'VA',
#    'Passenger',
#    '2',
#    '2',
#    '4',
#    '342',
#    '346',
#    '1.156069364161849710982658960'],
#   ['row-j698_ibac.w6kv',
#    '00000000-0000-0000-2D40-AAA08F525C85',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2017-03-31T00:00:00',
#    'Shelby',
#    'TN',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '113',
#    '114',
#    '0.8771929824561403508771929825'],
#   ['row-mxzu-587n-q4xj',
#    '00000000-0000-0000-7D4A-C11A6703B55C',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2023-03-31T00:00:00',
#    'King',
#    'WA',
#    'Truck',
#    '567',
#    '2',
#    '569',
#    '176588',
#    '177157',
#    '0.3211840345004713333370964737'],
#   ['row-ects~nej6~6x7x',
#    '00000000-0000-0000-E133-196CAB33A5AD',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2023-02-28T00:00:00',
#    'Grays Harbor',
#    'WA',
#    'Truck',
#    '2',
#    '0',
#    '2',
#    '21033',
#    '21035',
#    '0.009507962918944616115997147611'],
#   ['row-aits-t8tc.t9ux',
#    '00000000-0000-0000-B6BC-84158B8FB8FA',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-09-30T00:00:00',
#    'Jefferson',
#    'WA',
#    'Truck',
#    '3',
#    '0',
#    '3',
#    '9376',
#    '9379',
#    '0.03198635248960443544087855848'],
#   ['row-h6mx~ipiw~j6ah',
#    '00000000-0000-0000-FF8B-334DBEF6387C',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2018-11-30T00:00:00',
#    'Cook',
#    'IL',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '256',
#    '257',
#    '0.3891050583657587548638132296'],
#   ['row-cxmj_tfvz~wmdv',
#    '00000000-0000-0000-050F-8D9F2FF4F829',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2024-03-31T00:00:00',
#    'Arapahoe',
#    'CO',
#    'Passenger',
#    '1',
#    '1',
#    '2',
#    '62',
#    '64',
#    '3.12500'],
#   ['row-gp9b~jqie.54u4',
#    '00000000-0000-0000-7797-6647FBCE4773',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2024-04-30T00:00:00',
#    'Collier',
#    'FL',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '11',
#    '12',
#    '8.333333333333333333333333333'],
#   ['row-2k4f~j4ui~w22z',
#    '00000000-0000-0000-4C81-AC856D980FB0',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2021-07-31T00:00:00',
#    'Mercer',
#    'NJ',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '14',
#    '15',
#    '6.666666666666666666666666667'],
#   ['row-6m8z~4eji~9taq',
#    '00000000-0000-0000-6E98-6E326911A4E2',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2018-09-30T00:00:00',
#    'DeKalb',
#    'IN',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '1',
#    '2',
#    '50.0'],
#   ['row-rsjv~3m92.3mpm',
#    '00000000-0000-0000-F5A8-55E5DA39B15E',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2017-06-30T00:00:00',
#    'Whatcom',
#    'WA',
#    'Truck',
#    '2',
#    '0',
#    '2',
#    '41619',
#    '41621',
#    '0.004805266572163090747459215300'],
#   ['row-dk93.tjuk-wytk',
#    '00000000-0000-0000-0967-24A45FE09E3E',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-07-31T00:00:00',
#    'Wahkiakum',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '1799',
#    '1799',
#    '0'],
#   ['row-gpxp_wr4k~ncrj',
#    '00000000-0000-0000-F751-61EF73E4597E',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2023-11-30T00:00:00',
#    'El Paso',
#    'CO',
#    'Passenger',
#    '5',
#    '1',
#    '6',
#    '447',
#    '453',
#    '1.324503311258278145695364238'],
#   ['row-y78x_hbcx.6hj4',
#    '00000000-0000-0000-90CA-56010E82E0C1',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-07-31T00:00:00',
#    'Burlington',
#    'NJ',
#    'Passenger',
#    '0',
#    '2',
#    '2',
#    '104',
#    '106',
#    '1.886792452830188679245283019'],
#   ['row-66rq_c53u-dgmh',
#    '00000000-0000-0000-A1DD-25B544A9111D',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2024-01-31T00:00:00',
#    'Otero',
#    'NM',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '22',
#    '23',
#    '4.347826086956521739130434783'],
#   ['row-kwcg~gm2p~jgdh',
#    '00000000-0000-0000-F07C-F8183A2320C5',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2023-09-30T00:00:00',
#    'Kootenai',
#    'ID',
#    'Truck',
#    '1',
#    '0',
#    '1',
#    '25',
#    '26',
#    '3.846153846153846153846153846'],
#   ['row-3e3v-syqp.asae',
#    '00000000-0000-0000-D986-DB6DC70C7730',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-07-31T00:00:00',
#    'Cass',
#    'MN',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '2',
#    '3',
#    '33.33333333333333333333333333'],
#   ['row-giqv.vxdq.yudj',
#    '00000000-0000-0000-BBC4-EE274A43F478',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2021-01-31T00:00:00',
#    'Shelby',
#    'OH',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '2',
#    '3',
#    '33.33333333333333333333333333'],
#   ['row-825e-cfqj-vyp4',
#    '00000000-0000-0000-8E51-2097D0F433EB',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2018-09-30T00:00:00',
#    'Yakima',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '58679',
#    '58679',
#    '0'],
#   ['row-xryd.74re.5bmz',
#    '00000000-0000-0000-57FB-7DEF354FD001',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2017-05-31T00:00:00',
#    'Pima',
#    'AZ',
#    'Passenger',
#    '0',
#    '2',
#    '2',
#    '459',
#    '461',
#    '0.4338394793926247288503253796'],
#   ['row-baxi.k2gz~ijrs',
#    '00000000-0000-0000-80F4-A8405E1519AE',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2019-12-31T00:00:00',
#    'Douglas',
#    'NE',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '59',
#    '60',
#    '1.666666666666666666666666667'],
#   ['row-i97n~p3ms_jygv',
#    '00000000-0000-0000-0A9B-077959151FDF',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2021-04-30T00:00:00',
#    'Pulaski',
#    'MO',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '149',
#    '150',
#    '0.6666666666666666666666666667'],
#   ['row-dn76-gr68_um5j',
#    '00000000-0000-0000-651C-2BEA7832444A',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2021-07-31T00:00:00',
#    'Douglas',
#    'NE',
#    'Passenger',
#    '1',
#    '1',
#    '2',
#    '55',
#    '57',
#    '3.508771929824561403508771930'],
#   ['row-h575~wbcp~yy5b',
#    '00000000-0000-0000-77F4-40267DC0E6CA',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-06-30T00:00:00',
#    'Spartanburg',
#    'SC',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '39',
#    '40',
#    '2.500'],
#   ['row-mgua-uts9.aqwz',
#    '00000000-0000-0000-C502-8FB839E7F9DB',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-08-31T00:00:00',
#    'Mason',
#    'WA',
#    'Truck',
#    '4',
#    '0',
#    '4',
#    '20946',
#    '20950',
#    '0.01909307875894988066825775656'],
#   ['row-gx7b-xujk~dhgb',
#    '00000000-0000-0000-1BC3-DB3971592511',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2021-04-30T00:00:00',
#    'Ferry',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '3651',
#    '3651',
#    '0'],
#   ['row-35hv~wqri~k7nt',
#    '00000000-0000-0000-ABFA-76F84CEE5BD4',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2020-07-31T00:00:00',
#    'Douglas',
#    'WA',
#    'Passenger',
#    '76',
#    '41',
#    '117',
#    '28043',
#    '28160',
#    '0.4154829545454545454545454545'],
#   ['row-dwih~8yme-em7y',
#    '00000000-0000-0000-BB53-E977A8E84C00',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-02-28T00:00:00',
#    'Grays Harbor',
#    'WA',
#    'Passenger',
#    '202',
#    '157',
#    '359',
#    '49288',
#    '49647',
#    '0.7231051221624670171410155699'],
#   ['row-rbft_7q9u.ynrj',
#    '00000000-0000-0000-7F93-6E043243A8C1',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2018-03-31T00:00:00',
#    'Ventura',
#    'CA',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '336',
#    '337',
#    '0.2967359050445103857566765579'],
#   ['row-v6h8-ukdj~cy93',
#    '00000000-0000-0000-02B6-58345F85FB74',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2024-01-31T00:00:00',
#    'Lake',
#    'IN',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '5',
#    '6',
#    '16.66666666666666666666666667'],
#   ['row-x9ge.nbns_rxme',
#    '00000000-0000-0000-EFB7-903F03346DB5',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2017-06-30T00:00:00',
#    'Hamilton',
#    'TN',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '19',
#    '20',
#    '5.00'],
#   ['row-wj35_igsa~igge',
#    '00000000-0000-0000-9A72-B28E0465EADD',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2020-01-31T00:00:00',
#    'Vigo',
#    'IN',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '6',
#    '7',
#    '14.28571428571428571428571429'],
#   ['row-s4jh_kefp_yz7j',
#    '00000000-0000-0000-198E-10996A534F46',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2020-04-30T00:00:00',
#    'Kern',
#    'CA',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '229',
#    '230',
#    '0.4347826086956521739130434783'],
#   ['row-978z-gir3~qekh',
#    '00000000-0000-0000-2995-171ED80DB7CC',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2018-05-31T00:00:00',
#    'Spokane',
#    'WA',
#    'Truck',
#    '1',
#    '0',
#    '1',
#    '92354',
#    '92355',
#    '0.001082778409398516593579124032'],
#   ['row-tcie_7muh.8x98',
#    '00000000-0000-0000-ECD8-4AFA4DB91C8F',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2019-05-31T00:00:00',
#    'Columbia',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '1532',
#    '1532',
#    '0'],
#   ['row-j74w-mubw_feme',
#    '00000000-0000-0000-AE59-4212DD50EC5A',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2019-01-31T00:00:00',
#    'Skamania',
#    'WA',
#    'Passenger',
#    '18',
#    '15',
#    '33',
#    '8735',
#    '8768',
#    '0.3763686131386861313868613139'],
#   ['row-3r2u_gkqw.diyf',
#    '00000000-0000-0000-18D9-B8428E9AEB19',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2017-01-31T00:00:00',
#    'Salt Lake',
#    'UT',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '360',
#    '361',
#    '0.2770083102493074792243767313'],
#   ['row-kpsd.dqfa_e6g5',
#    '00000000-0000-0000-3431-2EF1553C7056',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2023-11-30T00:00:00',
#    'Washoe',
#    'NV',
#    'Passenger',
#    '2',
#    '0',
#    '2',
#    '49',
#    '51',
#    '3.921568627450980392156862745'],
#   ['row-bkpf.bwbt.wz8f',
#    '00000000-0000-0000-570D-1B557F8DCE96',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-07-31T00:00:00',
#    'DeKalb',
#    'GA',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '51',
#    '52',
#    '1.923076923076923076923076923'],
#   ['row-stcg.ydqy-g5vq',
#    '00000000-0000-0000-638F-ED91038A3C51',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-03-31T00:00:00',
#    'King',
#    'WA',
#    'Passenger',
#    '37912',
#    '10700',
#    '48612',
#    '1350004',
#    '1398616',
#    '3.475721713465311422148752767'],
#   ['row-67rh_iydq-iphy',
#    '00000000-0000-0000-FDF3-386F8DBF052A',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2019-01-31T00:00:00',
#    'Kitsap',
#    'WA',
#    'Passenger',
#    '981',
#    '556',
#    '1537',
#    '179904',
#    '181441',
#    '0.8471073241439365964693757199'],
#   ['row-f2jv-idp2-he4w',
#    '00000000-0000-0000-7AFD-AC4D6A9E91DA',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2024-03-31T00:00:00',
#    'Pierce',
#    'WA',
#    'Truck',
#    '273',
#    '0',
#    '273',
#    '131289',
#    '131562',
#    '0.2075067268664203949468691567'],
#   ['row-kk9d~brcm-59hw',
#    '00000000-0000-0000-E3C9-DE1600D3DF0A',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2023-06-30T00:00:00',
#    None,
#    None,
#    'Passenger',
#    '5',
#    '0',
#    '5',
#    '271',
#    '276',
#    '1.811594202898550724637681159'],
#   ['row-vn22-7dzz.5puv',
#    '00000000-0000-0000-06AB-EBBA9AD00A25',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2021-04-30T00:00:00',
#    'Tulsa',
#    'OK',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '47',
#    '48',
#    '2.083333333333333333333333333'],
#   ['row-jijt.chk2~8sia',
#    '00000000-0000-0000-D05D-1E04C193AC11',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2018-06-30T00:00:00',
#    'Kitsap',
#    'WA',
#    'Passenger',
#    '797',
#    '460',
#    '1257',
#    '178497',
#    '179754',
#    '0.6992890283387295971160586134'],
#   ['row-3ma3-zngk~f97u',
#    '00000000-0000-0000-664A-045A3EA5BB13',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-03-31T00:00:00',
#    'Lewis',
#    'WA',
#    'Passenger',
#    '224',
#    '166',
#    '390',
#    '59432',
#    '59822',
#    '0.6519340710775300056835277991'],
#   ['row-yxdi_jkku~qxfk',
#    '00000000-0000-0000-9EC1-0C06A3D95B61',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2023-03-31T00:00:00',
#    'Okanogan',
#    'WA',
#    'Truck',
#    '3',
#    '0',
#    '3',
#    '16487',
#    '16490',
#    '0.01819284414796846573681018799'],
#   ['row-9unn~6fkp~5pi7',
#    '00000000-0000-0000-8F43-FDF1564D12A2',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2018-10-31T00:00:00',
#    'Multnomah',
#    'OR',
#    'Passenger',
#    '3',
#    '4',
#    '7',
#    '772',
#    '779',
#    '0.8985879332477535301668806162'],
#   ['row-q38g~ruu2.vi7e',
#    '00000000-0000-0000-B3DC-A785416183DD',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2019-12-31T00:00:00',
#    'Ventura',
#    'CA',
#    'Passenger',
#    '0',
#    '2',
#    '2',
#    '311',
#    '313',
#    '0.6389776357827476038338658147'],
#   ['row-ykhy-w9qw.4gwp',
#    '00000000-0000-0000-0230-5159DA020C51',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2018-05-31T00:00:00',
#    'Lumpkin',
#    'GA',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '7',
#    '8',
#    '12.500'],
#   ['row-8vgb~hb3p~byge',
#    '00000000-0000-0000-816C-03F600B50C47',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2017-04-30T00:00:00',
#    'Pend Oreille',
#    'WA',
#    'Passenger',
#    '1',
#    '4',
#    '5',
#    '9320',
#    '9325',
#    '0.05361930294906166219839142091'],
#   ['row-z6nu~7724.bmq5',
#    '00000000-0000-0000-2055-B9FAAFD269BA',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2020-02-29T00:00:00',
#    None,
#    None,
#    'Passenger',
#    '6',
#    '2',
#    '8',
#    '416',
#    '424',
#    '1.886792452830188679245283019'],
#   ['row-j6yj_zm9r~2zw5',
#    '00000000-0000-0000-DA3E-F07939840D13',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2023-04-30T00:00:00',
#    'Garfield',
#    'WA',
#    'Passenger',
#    '1',
#    '3',
#    '4',
#    '1309',
#    '1313',
#    '0.3046458492003046458492003046'],
#   ['row-3z88_6d6d~vtzf',
#    '00000000-0000-0000-8A40-D85C44323CA3',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2021-12-31T00:00:00',
#    'Anne Arundel',
#    'MD',
#    'Passenger',
#    '3',
#    '1',
#    '4',
#    '362',
#    '366',
#    '1.092896174863387978142076503'],
#   ['row-k4kc-kwyf~dyxj',
#    '00000000-0000-0000-3C7D-2A22DF68F114',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2021-07-31T00:00:00',
#    'St. Clair',
#    'IL',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '139',
#    '140',
#    '0.7142857142857142857142857143'],
#   ['row-5dde_992s.xrah',
#    '00000000-0000-0000-7D02-6804724794F6',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2024-02-29T00:00:00',
#    'Charlottesville',
#    'VA',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '3',
#    '4',
#    '25.00'],
#   ['row-d2pz_f9c8~55dt',
#    '00000000-0000-0000-3C17-A967FADAB0CA',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2019-09-30T00:00:00',
#    'Berkshire',
#    'MA',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '4',
#    '5',
#    '20.0'],
#   ['row-iehr-zymp-nqc3',
#    '00000000-0000-0000-00CF-67B3C3C6D267',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2018-10-31T00:00:00',
#    'Thurston',
#    'WA',
#    'Passenger',
#    '663',
#    '551',
#    '1214',
#    '194970',
#    '196184',
#    '0.6188068344003588467968845574'],
#   ['row-s9ch~mdee-gqpw',
#    '00000000-0000-0000-825A-7AD6D14BD28E',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2020-02-29T00:00:00',
#    'Klickitat',
#    'WA',
#    'Passenger',
#    '49',
#    '41',
#    '90',
#    '15681',
#    '15771',
#    '0.5706676811869887768689366559'],
#   ['row-dn37-j8ru.q9f2',
#    '00000000-0000-0000-F702-1C481BBC7E08',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2018-06-30T00:00:00',
#    'Charles',
#    'MD',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '84',
#    '85',
#    '1.176470588235294117647058824'],
#   ['row-9u2x.z88t-wiz5',
#    '00000000-0000-0000-A638-9D201D0494A4',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-01-31T00:00:00',
#    'Adams',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '5433',
#    '5433',
#    '0'],
#   ['row-tvq6.4jd9.dmtc',
#    '00000000-0000-0000-4A07-56983D98C3CC',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-11-30T00:00:00',
#    "St. Mary's",
#    'MD',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '183',
#    '184',
#    '0.5434782608695652173913043478'],
#   ['row-d4j3-wqc2-qhvn',
#    '00000000-0000-0000-9255-FA141AF06F7F',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2023-03-31T00:00:00',
#    'Charleston',
#    'SC',
#    'Passenger',
#    '2',
#    '2',
#    '4',
#    '59',
#    '63',
#    '6.349206349206349206349206349'],
#   ['row-ayn8_rp3f~ph3e',
#    '00000000-0000-0000-29A7-36A5973A38D1',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2023-01-31T00:00:00',
#    'Goochland',
#    'VA',
#    'Passenger',
#    '2',
#    '2',
#    '4',
#    '87',
#    '91',
#    '4.395604395604395604395604396'],
#   ['row-w5jz.34en~nu7h',
#    '00000000-0000-0000-0336-30FB3E0C9B19',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2021-08-31T00:00:00',
#    'Saratoga',
#    'NY',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '42',
#    '43',
#    '2.325581395348837209302325581'],
#   ['row-b7ep~gnm7_cwkf',
#    '00000000-0000-0000-8F9E-D9E4B9000333',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2019-04-30T00:00:00',
#    'Whatcom',
#    'WA',
#    'Truck',
#    '2',
#    '0',
#    '2',
#    '42768',
#    '42770',
#    '0.004676174888940846387654898293'],
#   ['row-au34_vrdh-fcbt',
#    '00000000-0000-0000-FBB1-CDF9D2137A87',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2020-01-31T00:00:00',
#    'Washoe',
#    'NV',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '115',
#    '116',
#    '0.8620689655172413793103448276'],
#   ['row-dn2k~364m.expb',
#    '00000000-0000-0000-2CC3-9055F15E5650',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2021-05-31T00:00:00',
#    'Fairfax',
#    'VA',
#    'Passenger',
#    '5',
#    '4',
#    '9',
#    '719',
#    '728',
#    '1.236263736263736263736263736'],
#   ['row-7tr7.eh46~inju',
#    '00000000-0000-0000-E0C0-74E274AEB787',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2019-03-31T00:00:00',
#    'Montgomery',
#    'MD',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '276',
#    '277',
#    '0.3610108303249097472924187726'],
#   ['row-s6ng_u99n~w4m8',
#    '00000000-0000-0000-33BA-F714DC94740C',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2018-09-30T00:00:00',
#    'Richland',
#    'SC',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '169',
#    '170',
#    '0.5882352941176470588235294118'],
#   ['row-9qiv~a8pu_pnzu',
# ...
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2024-01-31T00:00:00',
#    'Yakima',
#    'WA',
#    'Passenger',
#    '662',
#    '305',
#    '967',
#    '166127',
#    '167094',
#    '0.5787161717356697427795133278'],
#   ['row-yved_zd3w.zt9n',
#    '00000000-0000-0000-EA7D-DAD62EBD3E1D',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2021-05-31T00:00:00',
#    'Klickitat',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '8255',
#    '8255',
#    '0'],
#   ['row-wdus~af9y~3qbv',
#    '00000000-0000-0000-5636-E50C3FFDB80E',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2023-07-31T00:00:00',
#    'Stevens',
#    'WA',
#    'Passenger',
#    '118',
#    '69',
#    '187',
#    '29625',
#    '29812',
#    '0.6272641889172145444787333959'],
#   ['row-cxsh-tz6c~uqhd',
#    '00000000-0000-0000-7270-63F2B96024CE',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2018-07-31T00:00:00',
#    'Kittitas',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '14057',
#    '14057',
#    '0'],
#   ['row-6zyx-4b84_9xdr',
#    '00000000-0000-0000-D1A4-3C97FCAA0838',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2023-03-31T00:00:00',
#    'Jefferson',
#    'WA',
#    'Truck',
#    '9',
#    '0',
#    '9',
#    '9322',
#    '9331',
#    '0.09645268459972135891115636052'],
#   ['row-y8em_t8kt.6shp',
#    '00000000-0000-0000-8369-D43DAAD93D03',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2020-04-30T00:00:00',
#    'Skagit',
#    'WA',
#    'Passenger',
#    '397',
#    '215',
#    '612',
#    '91456',
#    '92068',
#    '0.6647260720337142112351740018'],
#   ['row-czku-im27~qdy6',
#    '00000000-0000-0000-5246-DF3F473C495E',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2021-08-31T00:00:00',
#    'Pend Oreille',
#    'WA',
#    'Passenger',
#    '16',
#    '7',
#    '23',
#    '9236',
#    '9259',
#    '0.2484069553947510530294848256'],
#   ['row-kduf-nh6n_9pgm',
#    '00000000-0000-0000-0DFF-49FDE2130FD0',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-11-30T00:00:00',
#    'Okanogan',
#    'WA',
#    'Truck',
#    '2',
#    '0',
#    '2',
#    '16451',
#    '16453',
#    '0.01215583784112319941651978363'],
#   ['row-d5ni-ncu9.bq5v',
#    '00000000-0000-0000-0260-EF3FAB5A4670',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2019-07-31T00:00:00',
#    'Prince William',
#    'VA',
#    'Passenger',
#    '1',
#    '4',
#    '5',
#    '249',
#    '254',
#    '1.968503937007874015748031496'],
#   ['row-6tpx-b74h_yew7',
#    '00000000-0000-0000-8EF4-B5D293B1A5B8',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-11-30T00:00:00',
#    'Chesterfield',
#    'VA',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '38',
#    '39',
#    '2.564102564102564102564102564'],
#   ['row-pq9j-7y7j~6r9f',
#    '00000000-0000-0000-E5F6-2DF21BCBDB25',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2018-04-30T00:00:00',
#    'Caddo',
#    'LA',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '23',
#    '24',
#    '4.166666666666666666666666667'],
#   ['row-rtys~9mkj_7qsc',
#    '00000000-0000-0000-AED5-721AAF936DBD',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2017-09-30T00:00:00',
#    'Alameda',
#    'CA',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '357',
#    '358',
#    '0.2793296089385474860335195531'],
#   ['row-if65.mmfd~w73t',
#    '00000000-0000-0000-166B-DEDA59F7DD24',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2020-06-30T00:00:00',
#    'Clallam',
#    'WA',
#    'Passenger',
#    '228',
#    '168',
#    '396',
#    '50086',
#    '50482',
#    '0.7844380175111921080781268571'],
#   ['row-e55n~zjtv-yamt',
#    '00000000-0000-0000-903C-9FFE83E5A229',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2023-12-31T00:00:00',
#    'Stevens',
#    'WA',
#    'Truck',
#    '3',
#    '0',
#    '3',
#    '18612',
#    '18615',
#    '0.01611603545527800161160354553'],
#   ['row-pk2j~whcm_4khs',
#    '00000000-0000-0000-99EA-B972072E97A4',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2024-03-31T00:00:00',
#    'Benton',
#    'WA',
#    'Passenger',
#    '1478',
#    '671',
#    '2149',
#    '134141',
#    '136290',
#    '1.576784797123780174627632255'],
#   ['row-vtvt.8gjb_5bsz',
#    '00000000-0000-0000-DE03-CD747919E331',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2018-06-30T00:00:00',
#    'Franklin',
#    'WA',
#    'Passenger',
#    '39',
#    '66',
#    '105',
#    '57847',
#    '57952',
#    '0.1811844284925455549420209829'],
#   ['row-8nmw_6s4z~i73w',
#    '00000000-0000-0000-F4D6-696BEA50437E',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2024-03-31T00:00:00',
#    None,
#    None,
#    'Passenger',
#    '3',
#    '0',
#    '3',
#    '224',
#    '227',
#    '1.321585903083700440528634361'],
#   ['row-93sd.f54v_mjhr',
#    '00000000-0000-0000-186D-211E8E3CA421',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2023-02-28T00:00:00',
#    'Franklin',
#    'WA',
#    'Truck',
#    '4',
#    '0',
#    '4',
#    '20955',
#    '20959',
#    '0.01908488000381697600076339520'],
#   ['row-gq5m.rpik~pdxw',
#    '00000000-0000-0000-C9A2-95D5042F7F2C',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2017-04-30T00:00:00',
#    'Portsmouth',
#    'VA',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '66',
#    '67',
#    '1.492537313432835820895522388'],
#   ['row-brza~zhxv-vxmm',
#    '00000000-0000-0000-33AD-E19AA6451640',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2019-01-31T00:00:00',
#    "Prince George's",
#    'MD',
#    'Passenger',
#    '1',
#    '1',
#    '2',
#    '187',
#    '189',
#    '1.058201058201058201058201058'],
#   ['row-f8pi-7ncy.yei6',
#    '00000000-0000-0000-6E6A-C57E4AEBDC58',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2017-09-30T00:00:00',
#    'Travis',
#    'TX',
#    'Passenger',
#    '1',
#    '1',
#    '2',
#    '196',
#    '198',
#    '1.010101010101010101010101010'],
#   ['row-ve4q-vk9w_kajj',
#    '00000000-0000-0000-945D-D9C94F46DF33',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2024-02-29T00:00:00',
#    'St. Louis',
#    'MO',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '48',
#    '49',
#    '2.040816326530612244897959184'],
#   ['row-gnxb-5jec~ppv4',
#    '00000000-0000-0000-B51D-D790DC1BB2E9',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2018-02-28T00:00:00',
#    'Garfield',
#    'WA',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '1323',
#    '1324',
#    '0.07552870090634441087613293051'],
#   ['row-qgqp-aikm.xaju',
#    '00000000-0000-0000-8CFE-B24A4F980CE9',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2020-04-30T00:00:00',
#    'Rockingham',
#    'NH',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '26',
#    '27',
#    '3.703703703703703703703703704'],
#   ['row-uvyy~f7ik.ktcn',
#    '00000000-0000-0000-3B16-0CEA67353806',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2020-04-30T00:00:00',
#    "Prince George's",
#    'MD',
#    'Passenger',
#    '1',
#    '1',
#    '2',
#    '169',
#    '171',
#    '1.169590643274853801169590643'],
#   ['row-3wkw_f6ww-e286',
#    '00000000-0000-0000-15D0-C548BA0373F6',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-03-31T00:00:00',
#    'Pennington',
#    'SD',
#    'Passenger',
#    '2',
#    '0',
#    '2',
#    '32',
#    '34',
#    '5.882352941176470588235294118'],
#   ['row-mp29.p7sb-8ba4',
#    '00000000-0000-0000-2AD4-068BF5ECA974',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-12-31T00:00:00',
#    'Sarpy',
#    'NE',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '60',
#    '61',
#    '1.639344262295081967213114754'],
#   ['row-gtn4~ynuc_y8ng',
#    '00000000-0000-0000-6026-D2350A5811A8',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2017-05-31T00:00:00',
#    'Snohomish',
#    'WA',
#    'Passenger',
#    '1740',
#    '866',
#    '2606',
#    '512561',
#    '515167',
#    '0.5058553828176106000578453201'],
#   ['row-cpm3.ut9t.5ii4',
#    '00000000-0000-0000-1077-E3ACF056BD98',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2021-08-31T00:00:00',
#    'Lewis',
#    'WA',
#    'Passenger',
#    '181',
#    '153',
#    '334',
#    '59617',
#    '59951',
#    '0.5571216493469666894630615002'],
#   ['row-eyzi-wu49_x75c',
#    '00000000-0000-0000-2B9A-C13A59AF0E23',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-07-31T00:00:00',
#    'Skagit',
#    'WA',
#    'Truck',
#    '5',
#    '0',
#    '5',
#    '32270',
#    '32275',
#    '0.01549186676994577846630518978'],
#   ['row-kva3_ndg3_fgnj',
#    '00000000-0000-0000-5B92-1B3256AA1E43',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2021-09-30T00:00:00',
#    'Loudoun',
#    'VA',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '69',
#    '70',
#    '1.428571428571428571428571429'],
#   ['row-yqbv~xr5u.iufz',
#    '00000000-0000-0000-6787-DFCA2954AFCF',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-08-31T00:00:00',
#    'Lewis',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '26311',
#    '26311',
#    '0'],
#   ['row-gzgd-4hqy-m7tz',
#    '00000000-0000-0000-E62C-893A171182E7',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2020-02-29T00:00:00',
#    'Broward',
#    'FL',
#    'Passenger',
#    '2',
#    '1',
#    '3',
#    '123',
#    '126',
#    '2.380952380952380952380952381'],
#   ['row-gqcj.qccp~zaxe',
#    '00000000-0000-0000-94A8-B2B2DCA78F69',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2021-08-31T00:00:00',
#    'Sonoma',
#    'CA',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '93',
#    '94',
#    '1.063829787234042553191489362'],
#   ['row-9bzn_q53e~pbjv',
#    '00000000-0000-0000-CE85-B1B45981E213',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2023-07-31T00:00:00',
#    'Pulaski',
#    'AR',
#    'Passenger',
#    '2',
#    '0',
#    '2',
#    '18',
#    '20',
#    '10.0'],
#   ['row-zx5s_376u.r6vd',
#    '00000000-0000-0000-1651-5442EE6563E0',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2023-02-28T00:00:00',
#    'El Paso',
#    'TX',
#    'Passenger',
#    '3',
#    '0',
#    '3',
#    '316',
#    '319',
#    '0.9404388714733542319749216301'],
#   ['row-ygcq~58si.4giz',
#    '00000000-0000-0000-9306-C71D2BBCCCBD',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2019-03-31T00:00:00',
#    'El Paso',
#    'TX',
#    'Passenger',
#    '2',
#    '0',
#    '2',
#    '492',
#    '494',
#    '0.4048582995951417004048582996'],
#   ['row-sdht.bhdh~tk4q',
#    '00000000-0000-0000-1BF9-8DDADFA63CA8',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2019-11-30T00:00:00',
#    'Pima',
#    'AZ',
#    'Passenger',
#    '2',
#    '1',
#    '3',
#    '397',
#    '400',
#    '0.7500'],
#   ['row-ty5p~ahmx.u3gm',
#    '00000000-0000-0000-C1F2-630AC1C09261',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2020-05-31T00:00:00',
#    'Kern',
#    'CA',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '229',
#    '230',
#    '0.4347826086956521739130434783'],
#   ['row-vcjc~5vaw.3wgt',
#    '00000000-0000-0000-99CC-762335C29150',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2021-01-31T00:00:00',
#    'Columbia',
#    'OR',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '23',
#    '24',
#    '4.166666666666666666666666667'],
#   ['row-ezyv_cng2-r8ic',
#    '00000000-0000-0000-9E62-A5C7E5F9EC8A',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2023-03-31T00:00:00',
#    'Stevens',
#    'WA',
#    'Truck',
#    '2',
#    '0',
#    '2',
#    '18737',
#    '18739',
#    '0.01067292811782912642083355569'],
#   ['row-ns8y~39hy-diyc',
#    '00000000-0000-0000-02F9-41BFA084DBC7',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-06-30T00:00:00',
#    'Maui',
#    'HI',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '27',
#    '28',
#    '3.571428571428571428571428571'],
#   ['row-zkbb-km8p-dnn6',
#    '00000000-0000-0000-0F11-21F26BB98C63',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-12-31T00:00:00',
#    'Bartow',
#    'GA',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '5',
#    '6',
#    '16.66666666666666666666666667'],
#   ['row-azg6_34jx_cmnv',
#    '00000000-0000-0000-8701-544B4692EC02',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2018-08-31T00:00:00',
#    'Alameda',
#    'CA',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '347',
#    '348',
#    '0.2873563218390804597701149425'],
#   ['row-n7i6~v3uu.2hhn',
#    '00000000-0000-0000-F282-D472E6D2470C',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2017-12-31T00:00:00',
#    'Whitman',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '8452',
#    '8452',
#    '0'],
#   ['row-4qfg_ikpb.dmif',
#    '00000000-0000-0000-B527-9CE78BBF129E',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2021-12-31T00:00:00',
#    'District of Columbia',
#    'DC',
#    'Passenger',
#    '4',
#    '0',
#    '4',
#    '190',
#    '194',
#    '2.061855670103092783505154639'],
#   ['row-kiur.ebwk~4wq4',
#    '00000000-0000-0000-CA9B-81CB831C31B8',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2018-08-31T00:00:00',
#    'Lincoln',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '4571',
#    '4571',
#    '0'],
#   ['row-za8c.25cn-nnjh',
#    '00000000-0000-0000-C3E7-8150185196C7',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2019-01-31T00:00:00',
#    'Garfield',
#    'WA',
#    'Truck',
#    '0',
#    '0',
#    '0',
#    '961',
#    '961',
#    '0'],
#   ['row-4mgi-7rrm~ugjf',
#    '00000000-0000-0000-C76C-BA075219C21E',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2024-03-31T00:00:00',
#    'Asotin',
#    'WA',
#    'Truck',
#    '2',
#    '0',
#    '2',
#    '6504',
#    '6506',
#    '0.03074085459575776206578542883'],
#   ['row-pvin~vz5d.b5vv',
#    '00000000-0000-0000-F373-625FAB5DEAE2',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-06-30T00:00:00',
#    'Onslow',
#    'NC',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '167',
#    '168',
#    '0.5952380952380952380952380952'],
#   ['row-6att_ih4r~qjrj',
#    '00000000-0000-0000-2D6E-DD7F07F27970',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2021-07-31T00:00:00',
#    'Anne Arundel',
#    'MD',
#    'Passenger',
#    '3',
#    '1',
#    '4',
#    '386',
#    '390',
#    '1.025641025641025641025641026'],
#   ['row-fw2x.j32x~jb9q',
#    '00000000-0000-0000-15DE-0521B8B15813',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2019-02-28T00:00:00',
#    'Harris',
#    'TX',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '278',
#    '279',
#    '0.3584229390681003584229390681'],
#   ['row-guqi.p8we-ej2b',
#    '00000000-0000-0000-0F0D-A917BEA6748B',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2020-01-31T00:00:00',
#    'Okanogan',
#    'WA',
#    'Passenger',
#    '32',
#    '30',
#    '62',
#    '26209',
#    '26271',
#    '0.2360016748505957139050664231'],
#   ['row-k9n2~7t49-qvp2',
#    '00000000-0000-0000-C16E-7238E5396B8B',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2020-06-30T00:00:00',
#    'Island',
#    'WA',
#    'Truck',
#    '1',
#    '0',
#    '1',
#    '21195',
#    '21196',
#    '0.004717871296471032270239667862'],
#   ['row-7nex.qw4e-pb2f',
#    '00000000-0000-0000-A652-E06B7900633D',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2017-05-31T00:00:00',
#    'Sumter',
#    'FL',
#    'Passenger',
#    '0',
#    '1',
#    '1',
#    '10',
#    '11',
#    '9.090909090909090909090909091'],
#   ['row-y9k2_9b6m~etbr',
#    '00000000-0000-0000-6E13-34492859598A',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-07-31T00:00:00',
#    'Asotin',
#    'WA',
#    'Passenger',
#    '24',
#    '19',
#    '43',
#    '12616',
#    '12659',
#    '0.3396792795639465992574452958'],
#   ['row-avm6.vmtn.ax4u',
#    '00000000-0000-0000-D0E6-B69D166C0AAF',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2019-08-31T00:00:00',
#    'Solano',
#    'CA',
#    'Passenger',
#    '1',
#    '0',
#    '1',
#    '211',
#    '212',
#    '0.4716981132075471698113207547'],
#   ['row-bvjv~62iv.zaeq',
#    '00000000-0000-0000-78B5-476752D8B5BC',
#    0,
#    1716314809,
#    None,
#    1716314809,
#    None,
#    '{ }',
#    '2022-02-28T00:00:00',
#    'Boulder',
#    'CO',
#    'Passenger',
#    '2',
#    '0',
#    '2',
#    '46',
#    '48',
#    '4.166666666666666666666666667'],
#   ...]}

# %% [markdown]
# **2. Se realiza exploración de datos simple y se lee Dataset mediante librería pandas, después de ordenarlo.**

# %%
newdata.keys()
# Out:
# dict_keys(['meta', 'data'])

# %%
newdata['meta']
# Out:
# {'view': {'id': '3d5d-sdqb',
#   'name': 'Electric Vehicle Population Size History By County',
#   'assetType': 'dataset',
#   'attribution': 'Washington State Department of Licensing',
#   'averageRating': 0,
#   'category': 'Transportation',
#   'createdAt': 1591046256,
#   'description': 'This shows the number of vehicles that were registered by Washington State Department of Licensing (DOL) each month. The data is separated by county for passenger vehicles and trucks. \n\nDOL integrates National Highway Traffic Safety Administration (NHTSA) data and the Environmental Protection Agency (EPA) fuel efficiency ratings with DOL titling and registration data to create this information.',
#   'displayType': 'table',
#   'downloadCount': 10193,
#   'hideFromCatalog': False,
#   'hideFromDataJson': False,
#   'licenseId': 'ODBL',
#   'locked': False,
#   'newBackend': True,
#   'numberOfComments': 0,
#   'oid': 34339220,
#   'provenance': 'official',
#   'publicationAppendEnabled': False,
#   'publicationDate': 1591379619,
#   'publicationGroup': 17186729,
#   'publicationStage': 'published',
#   'rowsUpdatedAt': 1716314813,
#   'rowsUpdatedBy': 'kgaq-6gwr',
#   'tableId': 17199524,
#   'totalTimesRated': 0,
#   'viewCount': 3856,
#   'viewLastModified': 1716314806,
#   'viewType': 'tabular',
#   'approvals': [{'reviewedAt': 1591380915,
#     'reviewedAutomatically': True,
#     'state': 'approved',
#     'submissionId': 2285192,
#     'submissionObject': 'public_audience_request',
#     'submissionOutcome': 'change_audience',
#     'submittedAt': 1591380915,
#     'targetAudience': 'public',
#     'workflowId': 2106,
#     'submissionDetails': {'permissionType': 'READ'},
#     'submissionOutcomeApplication': {'endedAt': 1591380916,
#      'failureCount': 0,
#      'startedAt': 1591380915,
#      'status': 'success'},
#     'submitter': {'id': 'dphz-szpx', 'displayName': 'Faith'}}],
#   'clientContext': {'clientContextVariables': [], 'inheritedVariables': {}},
#   'columns': [{'id': -1,
#     'name': 'sid',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':sid',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'id',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':id',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'position',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':position',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'created_at',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':created_at',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'created_meta',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':created_meta',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'updated_at',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':updated_at',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'updated_meta',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':updated_meta',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'meta',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':meta',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': 472621118,
#     'name': 'Date',
#     'dataTypeName': 'calendar_date',
#     'description': 'Counts of registered vehicles are taken on this day (the end of this month).',
#     'fieldName': 'date',
#     'position': 1,
#     'renderTypeName': 'calendar_date',
#     'tableColumnId': 103990567,
#     'cachedContents': {'non_null': '21582',
#      'largest': '2024-04-30T00:00:00.000',
#      'null': '0',
#      'top': [{'item': '2022-11-30T00:00:00.000', 'count': '289'},
#       {'item': '2022-10-31T00:00:00.000', 'count': '288'},
#       {'item': '2022-04-30T00:00:00.000', 'count': '288'},
#       {'item': '2022-12-31T00:00:00.000', 'count': '288'},
#       {'item': '2023-02-28T00:00:00.000', 'count': '287'},
#       {'item': '2022-09-30T00:00:00.000', 'count': '287'},
#       {'item': '2023-01-31T00:00:00.000', 'count': '287'},
#       {'item': '2022-03-31T00:00:00.000', 'count': '286'},
#       {'item': '2023-03-31T00:00:00.000', 'count': '285'},
#       {'item': '2022-06-30T00:00:00.000', 'count': '285'},
#       {'item': '2022-05-31T00:00:00.000', 'count': '285'},
#       {'item': '2023-04-30T00:00:00.000', 'count': '285'},
#       {'item': '2022-08-31T00:00:00.000', 'count': '283'},
#       {'item': '2022-02-28T00:00:00.000', 'count': '282'},
#       {'item': '2023-05-31T00:00:00.000', 'count': '281'},
#       {'item': '2022-07-31T00:00:00.000', 'count': '281'},
#       {'item': '2021-10-31T00:00:00.000', 'count': '281'},
#       {'item': '2021-11-30T00:00:00.000', 'count': '280'},
#       {'item': '2022-01-31T00:00:00.000', 'count': '280'},
#       {'item': '2023-06-30T00:00:00.000', 'count': '278'}],
#      'smallest': '2017-01-31T00:00:00.000',
#      'count': '21582',
#      'cardinality': '88'},
#     'format': {'view': 'date_monthdy'}},
#    {'id': 472621119,
#     'name': 'County',
#     'dataTypeName': 'text',
#     'description': "This is the geographic region of a state that a vehicle's owner is listed to reside within. Vehicles registered in Washington state may be located in other states.",
#     'fieldName': 'county',
#     'position': 2,
#     'renderTypeName': 'text',
#     'tableColumnId': 103990568,
#     'cachedContents': {'non_null': '21494',
#      'largest': 'Yuba',
#      'null': '88',
#      'top': [{'item': 'Douglas', 'count': '295'},
#       {'item': 'Montgomery', 'count': '291'},
#       {'item': 'Jefferson', 'count': '268'},
#       {'item': 'Clark', 'count': '264'},
#       {'item': 'Franklin', 'count': '223'},
#       {'item': 'Columbia', 'count': '223'},
#       {'item': 'Orange', 'count': '207'},
#       {'item': 'Adams', 'count': '202'},
#       {'item': 'Lincoln', 'count': '199'},
#       {'item': 'Garfield', 'count': '196'},
#       {'item': 'San Juan', 'count': '187'},
#       {'item': 'Lewis', 'count': '180'},
#       {'item': 'Mason', 'count': '176'},
#       {'item': 'Walla Walla', 'count': '176'},
#       {'item': 'Asotin', 'count': '176'},
#       {'item': 'Pacific', 'count': '176'},
#       {'item': 'Clallam', 'count': '176'},
#       {'item': 'Stevens', 'count': '176'},
#       {'item': 'Okanogan', 'count': '176'},
#       {'item': 'Thurston', 'count': '176'}],
#      'smallest': 'Ada',
#      'count': '21582',
#      'cardinality': '315'},
#     'format': {}},
#    {'id': 472621120,
#     'name': 'State',
#     'dataTypeName': 'text',
#     'description': 'This is the geographic region of the country associated with the record. These addresses may be located in other states.',
#     'fieldName': 'state',
#     'position': 3,
#     'renderTypeName': 'text',
#     'tableColumnId': 103990558,
#     'cachedContents': {'non_null': '21494',
#      'largest': 'WY',
#      'null': '88',
#      'top': [{'item': 'WA', 'count': '6864'},
#       {'item': 'CA', 'count': '1719'},
#       {'item': 'VA', 'count': '1354'},
#       {'item': 'FL', 'count': '1133'},
#       {'item': 'TX', 'count': '1103'},
#       {'item': 'MD', 'count': '782'},
#       {'item': 'OR', 'count': '544'},
#       {'item': 'CO', 'count': '517'},
#       {'item': 'GA', 'count': '493'},
#       {'item': 'NC', 'count': '468'},
#       {'item': 'NY', 'count': '440'},
#       {'item': 'NJ', 'count': '391'},
#       {'item': 'IL', 'count': '383'},
#       {'item': 'ID', 'count': '320'},
#       {'item': 'HI', 'count': '309'},
#       {'item': 'AZ', 'count': '308'},
#       {'item': 'SC', 'count': '299'},
#       {'item': 'MA', 'count': '284'},
#       {'item': 'PA', 'count': '278'},
#       {'item': 'MO', 'count': '268'}],
#      'smallest': 'AK',
#      'count': '21582',
#      'cardinality': '50'},
#     'format': {}},
#    {'id': 472621121,
#     'name': 'Vehicle Primary Use',
#     'dataTypeName': 'text',
#     'description': 'This describes the primary intended use of the vehicle.',
#     'fieldName': 'vehicle_primary_use',
#     'position': 4,
#     'renderTypeName': 'text',
#     'tableColumnId': 104001400,
#     'cachedContents': {'non_null': '21582',
#      'largest': 'Truck',
#      'null': '0',
#      'top': [{'item': 'Passenger', 'count': '18052'},
#       {'item': 'Truck', 'count': '3530'}],
#      'smallest': 'Passenger',
#      'count': '21582',
#      'cardinality': '2'},
#     'format': {}},
#    {'id': 472621122,
#     'name': 'Battery Electric Vehicles (BEVs)',
#     'dataTypeName': 'number',
#     'description': 'The count of vehicles that are known to be propelled solely by an energy derived from an onboard electric battery.',
#     'fieldName': 'battery_electric_vehicles_bevs_',
#     'position': 5,
#     'renderTypeName': 'number',
#     'tableColumnId': 104001399,
#     'cachedContents': {'non_null': '21582',
#      'largest': '75487',
#      'null': '0',
#      'top': [{'item': '1', 'count': '7203'},
#       {'item': '0', 'count': '6893'},
#       {'item': '2', 'count': '1875'},
#       {'item': '3', 'count': '822'},
#       {'item': '4', 'count': '418'},
#       {'item': '5', 'count': '326'},
#       {'item': '6', 'count': '210'},
#       {'item': '7', 'count': '170'},
#       {'item': '8', 'count': '134'},
#       {'item': '9', 'count': '86'},
#       {'item': '10', 'count': '80'},
#       {'item': '12', 'count': '68'},
#       {'item': '11', 'count': '52'},
#       {'item': '17', 'count': '49'},
#       {'item': '19', 'count': '42'},
#       {'item': '16', 'count': '42'},
#       {'item': '18', 'count': '38'},
#       {'item': '20', 'count': '36'},
#       {'item': '21', 'count': '36'},
#       {'item': '23', 'count': '36'}],
#      'smallest': '0',
#      'count': '21582',
#      'cardinality': '1238'},
#     'format': {}},
#    {'id': 472621123,
#     'name': 'Plug-In Hybrid Electric Vehicles (PHEVs)',
#     'dataTypeName': 'number',
#     'description': 'The count of vehicles that are known to be propelled from energy partially sourced from an onboard electric battery that is capable of being recharged from an external source.',
#     'fieldName': 'plug_in_hybrid_electric_vehicles_phevs_',
#     'position': 6,
#     'renderTypeName': 'number',
#     'tableColumnId': 104001398,
#     'cachedContents': {'non_null': '21582',
#      'largest': '18450',
#      'null': '0',
#      'top': [{'item': '0', 'count': '10234'},
#       {'item': '1', 'count': '5811'},
#       {'item': '2', 'count': '1491'},
#       {'item': '3', 'count': '512'},
#       {'item': '4', 'count': '231'},
#       {'item': '5', 'count': '145'},
#       {'item': '6', 'count': '86'},
#       {'item': '7', 'count': '76'},
#       {'item': '8', 'count': '37'},
#       {'item': '12', 'count': '36'},
#       {'item': '9', 'count': '36'},
#       {'item': '11', 'count': '32'},
#       {'item': '19', 'count': '30'},
#       {'item': '17', 'count': '29'},
#       {'item': '21', 'count': '29'},
#       {'item': '33', 'count': '28'},
#       {'item': '10', 'count': '25'},
#       {'item': '22', 'count': '24'},
#       {'item': '18', 'count': '23'},
#       {'item': '32', 'count': '22'}],
#      'smallest': '0',
#      'count': '21582',
#      'cardinality': '950'},
#     'format': {}},
#    {'id': 472621124,
#     'name': 'Electric Vehicle (EV) Total',
#     'dataTypeName': 'number',
#     'description': 'The sum of Battery Electric Vehicles (BEVs) and Plug-in Hybrid Electric Vehicles (PHEVs).',
#     'fieldName': 'electric_vehicle_ev_total',
#     'position': 7,
#     'renderTypeName': 'number',
#     'tableColumnId': 103990566,
#     'cachedContents': {'non_null': '21582',
#      'largest': '93937',
#      'null': '0',
#      'top': [{'item': '1', 'count': '9661'},
#       {'item': '2', 'count': '2692'},
#       {'item': '0', 'count': '2273'},
#       {'item': '3', 'count': '1164'},
#       {'item': '4', 'count': '712'},
#       {'item': '5', 'count': '376'},
#       {'item': '6', 'count': '294'},
#       {'item': '7', 'count': '262'},
#       {'item': '8', 'count': '180'},
#       {'item': '9', 'count': '145'},
#       {'item': '10', 'count': '122'},
#       {'item': '11', 'count': '82'},
#       {'item': '12', 'count': '81'},
#       {'item': '13', 'count': '75'},
#       {'item': '14', 'count': '50'},
#       {'item': '15', 'count': '47'},
#       {'item': '16', 'count': '39'},
#       {'item': '19', 'count': '37'},
#       {'item': '17', 'count': '32'},
#       {'item': '18', 'count': '31'}],
#      'smallest': '0',
#      'count': '21582',
#      'cardinality': '1432'},
#     'format': {}},
#    {'id': 472621125,
#     'name': 'Non-Electric Vehicle Total',
#     'dataTypeName': 'number',
#     'description': 'The count of vehicles that are not electric vehicles.',
#     'fieldName': 'non_electric_vehicles',
#     'position': 8,
#     'renderTypeName': 'number',
#     'tableColumnId': 104098606,
#     'cachedContents': {'non_null': '21582',
#      'largest': '1399671',
#      'null': '0',
#      'top': [{'item': '1', 'count': '301'},
#       {'item': '5', 'count': '221'},
#       {'item': '4', 'count': '196'},
#       {'item': '6', 'count': '185'},
#       {'item': '3', 'count': '180'},
#       {'item': '0', 'count': '163'},
#       {'item': '11', 'count': '153'},
#       {'item': '7', 'count': '153'},
#       {'item': '13', 'count': '150'},
#       {'item': '12', 'count': '145'},
#       {'item': '9', 'count': '139'},
#       {'item': '10', 'count': '136'},
#       {'item': '21', 'count': '135'},
#       {'item': '18', 'count': '125'},
#       {'item': '20', 'count': '125'},
#       {'item': '36', 'count': '122'},
#       {'item': '38', 'count': '118'},
#       {'item': '8', 'count': '117'},
#       {'item': '19', 'count': '116'},
#       {'item': '40', 'count': '114'}],
#      'smallest': '0',
#      'count': '21582',
#      'cardinality': '7213'},
#     'format': {}},
#    {'id': 472621126,
#     'name': 'Total Vehicles',
#     'dataTypeName': 'number',
#     'description': 'All powered vehicles registered in the county. This includes electric vehicles.',
#     'fieldName': 'total_vehicles',
#     'position': 9,
#     'renderTypeName': 'number',
#     'tableColumnId': 104001397,
#     'cachedContents': {'non_null': '21582',
#      'largest': '1430786',
#      'null': '0',
#      'top': [{'item': '2', 'count': '301'},
#       {'item': '6', 'count': '221'},
#       {'item': '5', 'count': '197'},
#       {'item': '7', 'count': '184'},
#       {'item': '4', 'count': '179'},
#       {'item': '1', 'count': '163'},
#       {'item': '14', 'count': '155'},
#       {'item': '12', 'count': '146'},
#       {'item': '8', 'count': '146'},
#       {'item': '11', 'count': '141'},
#       {'item': '13', 'count': '138'},
#       {'item': '21', 'count': '136'},
#       {'item': '10', 'count': '132'},
#       {'item': '38', 'count': '128'},
#       {'item': '22', 'count': '127'},
#       {'item': '37', 'count': '125'},
#       {'item': '19', 'count': '123'},
#       {'item': '15', 'count': '119'},
#       {'item': '41', 'count': '116'},
#       {'item': '9', 'count': '116'}],
#      'smallest': '1',
#      'count': '21582',
#      'cardinality': '7230'},
#     'format': {}},
#    {'id': 472621127,
#     'name': 'Percent Electric Vehicles',
#     'dataTypeName': 'number',
#     'description': 'Comparison of electric vehicles versus their non-electric counterparts.',
#     'fieldName': 'percent_electric_vehicles',
#     'position': 10,
#     'renderTypeName': 'number',
#     'tableColumnId': 104099062,
#     'cachedContents': {'non_null': '21582',
#      'largest': '100',
#      'null': '0',
#      'top': [{'item': '0', 'count': '2273'},
#       {'item': '50.0', 'count': '301'},
#       {'item': '16.66666666666666666666666667', 'count': '229'},
#       {'item': '14.28571428571428571428571429', 'count': '209'},
#       {'item': '20.0', 'count': '202'},
#       {'item': '25.00', 'count': '183'},
#       {'item': '100', 'count': '163'},
#       {'item': '12.500', 'count': '159'},
#       {'item': '8.333333333333333333333333333', 'count': '151'},
#       {'item': '7.142857142857142857142857143', 'count': '147'},
#       {'item': '5.263157894736842105263157895', 'count': '146'},
#       {'item': '11.11111111111111111111111111', 'count': '144'},
#       {'item': '10.0', 'count': '142'},
#       {'item': '4.761904761904761904761904762', 'count': '142'},
#       {'item': '4.545454545454545454545454545', 'count': '139'},
#       {'item': '9.090909090909090909090909091', 'count': '138'},
#       {'item': '7.692307692307692307692307692', 'count': '136'},
#       {'item': '5.00', 'count': '129'},
#       {'item': '4.166666666666666666666666667', 'count': '128'},
#       {'item': '3.571428571428571428571428571', 'count': '123'}],
#      'smallest': '0',
#      'count': '21582',
#      'cardinality': '6400'},
#     'format': {'precision': '2'}}],
#   'grants': [{'inherited': False, 'type': 'viewer', 'flags': ['public']}],
#   'license': {'name': 'Open Data Commons Open Database License',
#    'termsLink': 'http://opendatacommons.org/licenses/odbl/1.0/'},
#   'metadata': {'custom_fields': {'Temporal': {'Posting Frequency': 'Monthly',
#      'Period of Time': 'Data includes historical Electric Vehicle population counts from January 2017 through April 2024.'},
#     'Identification': {'Originator': 'Research and Analysis Office, Department of Licensing',
#      'Metadata Language': 'English'},
#     'Notes': {'1. ': 'A Battery Electric Vehicle (BEV) is an all-electric vehicle using one or more batteries to store the electrical energy that powers the motor and is charged by plugging the vehicle in to an electric power source. A Plug-in Hybrid Electric Vehicle (PHEV) is a vehicle that uses one or more batteries to power an electric motor; uses another fuel, such as gasoline or diesel, to power an internal combustion engine or other propulsion source; and is charged by plugging the vehicle in to an electric power source.',
#      '2. ': 'Vehicles registered with a military installation address may not have an assigned county. These vehicles are not included in the final counts.',
#      '3. ': 'Monthly count of vehicles for a county may change from this report and prior reports. Processes were implemented to more accurately assign county at the time of registration.'}},
#    'rowLabel': 'Monthly count of vehicles for a county',
#    'availableDisplayTypes': ['table', 'fatrow', 'page']},
#   'owner': {'id': 'eagg-6py7',
#    'displayName': 'Department of Licensing',
#    'profileImageUrlLarge': '/api/users/eagg-6py7/profile_images/LARGE',
#    'profileImageUrlMedium': '/api/users/eagg-6py7/profile_images/THUMB',
#    'profileImageUrlSmall': '/api/users/eagg-6py7/profile_images/TINY',
#    'screenName': 'Department of Licensing',
#    'type': 'interactive',
#    'flags': ['acceptedEula', 'mayBeStoriesCoOwner']},
#   'query': {},
#   'rights': ['read'],
#   'tableAuthor': {'id': 'eagg-6py7',
#    'displayName': 'Department of Licensing',
#    'profileImageUrlLarge': '/api/users/eagg-6py7/profile_images/LARGE',
#    'profileImageUrlMedium': '/api/users/eagg-6py7/profile_images/THUMB',
#    'profileImageUrlSmall': '/api/users/eagg-6py7/profile_images/TINY',
#    'screenName': 'Department of Licensing',
#    'type': 'interactive',
#    'flags': ['acceptedEula', 'mayBeStoriesCoOwner']},
#   'tags': ['battery electric',
#    'bev',
#    'plug-in',
#    'hybrid',
#    'phev',
#    'electric',
#    'vehicle',
#    'clean energy',
#    'population growth',
#    'rao_open_data',
#    'dol_open_data',
#    'department of licensing',
#    'dol',
#    'rao_ev',
#    'rao_veh'],
#   'flags': ['default',
#    'ownerMayBeContacted',
#    'restorable',
#    'restorePossibleForType']}}

# %%
column = newdata['meta']['view']['columns'][8:][0]['name']
column
# Out:
# 'Date'

# %%
newdata['data']
# Out:
# [['row-uc79~tpp3-5zxb',
#   '00000000-0000-0000-19FC-D5232A6F8D55',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-10-31T00:00:00',
#   'Saratoga',
#   'NY',
#   'Passenger',
#   '1',
#   '1',
#   '2',
#   '72',
#   '74',
#   '2.702702702702702702702702703'],
#  ['row-xc2i-z4xj_qa66',
#   '00000000-0000-0000-B75D-F6056FF7869D',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-02-28T00:00:00',
#   'Clallam',
#   'WA',
#   'Passenger',
#   '75',
#   '64',
#   '139',
#   '47978',
#   '48117',
#   '0.2888791903069601180455971902'],
#  ['row-pmup~x6gc~tm94',
#   '00000000-0000-0000-B010-7D96241E7BE6',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-08-31T00:00:00',
#   'Kittitas',
#   'WA',
#   'Passenger',
#   '110',
#   '47',
#   '157',
#   '29763',
#   '29920',
#   '0.5247326203208556149732620321'],
#  ['row-ucnf-kkrn_ax53',
#   '00000000-0000-0000-BF41-9DE0FFE2B78B',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-07-31T00:00:00',
#   'Asotin',
#   'WA',
#   'Passenger',
#   '37',
#   '23',
#   '60',
#   '12371',
#   '12431',
#   '0.4826643069744992357815139570'],
#  ['row-ikva~vuqm_4e8c',
#   '00000000-0000-0000-FBC7-67DDDA10A339',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-06-30T00:00:00',
#   'Riverside',
#   'CA',
#   'Passenger',
#   '2',
#   '2',
#   '4',
#   '664',
#   '668',
#   '0.5988023952095808383233532934'],
#  ['row-kdji.na4k_zv7y',
#   '00000000-0000-0000-B8D1-A16925297C54',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-09-30T00:00:00',
#   'DeKalb',
#   'GA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '86',
#   '87',
#   '1.149425287356321839080459770'],
#  ['row-hp6z.y75v_zpr9',
#   '00000000-0000-0000-7FC4-7FFAA89AB190',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-08-31T00:00:00',
#   'Columbia',
#   'OR',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '18',
#   '19',
#   '5.263157894736842105263157895'],
#  ['row-mmfg~misa_6b34',
#   '00000000-0000-0000-55E0-F552A82C3BF9',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-10-31T00:00:00',
#   'Larimer',
#   'CO',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '48',
#   '49',
#   '2.040816326530612244897959184'],
#  ['row-9r4e~e3pw.uaxg',
#   '00000000-0000-0000-F6D2-170D2E20AEAF',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-07-31T00:00:00',
#   'Pacific',
#   'WA',
#   'Passenger',
#   '24',
#   '30',
#   '54',
#   '16024',
#   '16078',
#   '0.3358626694862545092673218062'],
#  ['row-iwhj.thcj_x9w6',
#   '00000000-0000-0000-FCE9-B7D18E519AF3',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-05-31T00:00:00',
#   'Nueces',
#   'TX',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '98',
#   '99',
#   '1.010101010101010101010101010'],
#  ['row-7j9m_x6xd_f7kt',
#   '00000000-0000-0000-8BA1-88305D05DBCE',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-10-31T00:00:00',
#   'Kootenai',
#   'ID',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '152',
#   '153',
#   '0.6535947712418300653594771242'],
#  ['row-2us7~3ahb-5egp',
#   '00000000-0000-0000-43EE-B401894E0C8C',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-04-30T00:00:00',
#   'Kern',
#   'CA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '198',
#   '199',
#   '0.5025125628140703517587939698'],
#  ['row-fsss-kexk.s9rs',
#   '00000000-0000-0000-C54C-082276A2A4DB',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-01-31T00:00:00',
#   'Santa Rosa',
#   'FL',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '92',
#   '93',
#   '1.075268817204301075268817204'],
#  ['row-jehi-qf92.c4iu',
#   '00000000-0000-0000-DA01-D0714EEBCBE0',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2024-01-31T00:00:00',
#   'Lee',
#   'AL',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '12',
#   '13',
#   '7.692307692307692307692307692'],
#  ['row-jmtz~dwpm_fvam',
#   '00000000-0000-0000-E41A-7048D484960F',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-11-30T00:00:00',
#   'Bartow',
#   'GA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '5',
#   '6',
#   '16.66666666666666666666666667'],
#  ['row-ammw.c7de~nyxh',
#   '00000000-0000-0000-F19B-3A63069A49DF',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-01-31T00:00:00',
#   'Grays Harbor',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '20316',
#   '20316',
#   '0'],
#  ['row-bpgw.ng8c-w93e',
#   '00000000-0000-0000-DEBB-6BE08C0C1E02',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-12-31T00:00:00',
#   'Lewis',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '26087',
#   '26087',
#   '0'],
#  ['row-3v6k~2psi.pwq9',
#   '00000000-0000-0000-2CAA-95BF0A371F0B',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-12-31T00:00:00',
#   'Ferry',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '3517',
#   '3517',
#   '0'],
#  ['row-fjsa~xr5n.2efq',
#   '00000000-0000-0000-8038-3A8C504E80D8',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-08-31T00:00:00',
#   'Utah',
#   'UT',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '155',
#   '156',
#   '0.6410256410256410256410256410'],
#  ['row-5hcu_w4mu-7zr6',
#   '00000000-0000-0000-E0C6-C9864B7F30C2',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2018-07-31T00:00:00',
#   'Washtenaw',
#   'MI',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '38',
#   '39',
#   '2.564102564102564102564102564'],
#  ['row-5n4j.j82z~d2cg',
#   '00000000-0000-0000-E51D-8527BAA71386',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-04-30T00:00:00',
#   'Whitman',
#   'WA',
#   'Passenger',
#   '138',
#   '72',
#   '210',
#   '21953',
#   '22163',
#   '0.9475251545368406804133014484'],
#  ['row-v27y-rkbx.sd88',
#   '00000000-0000-0000-A6CE-D72A76C514ED',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-02-28T00:00:00',
#   'Canyon',
#   'ID',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '110',
#   '111',
#   '0.9009009009009009009009009009'],
#  ['row-cgdu_d34f.6i4i',
#   '00000000-0000-0000-6231-C2337BCBD855',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-11-30T00:00:00',
#   'Garfield',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '935',
#   '935',
#   '0'],
#  ['row-nhuv~mrg6~u9gb',
#   '00000000-0000-0000-26CC-AE46F8691C22',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-01-31T00:00:00',
#   'Nantucket',
#   'MA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '3',
#   '4',
#   '25.00'],
#  ['row-tdd7~z292~b9zx',
#   '00000000-0000-0000-D401-AA3D5FE9438C',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-05-31T00:00:00',
#   'Okanogan',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '16212',
#   '16212',
#   '0'],
#  ['row-zfe3_fc4p_d86f',
#   '00000000-0000-0000-C9AF-A89F0683D422',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-02-28T00:00:00',
#   'Escambia',
#   'FL',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '150',
#   '151',
#   '0.6622516556291390728476821192'],
#  ['row-cjj9~ajq5.hfmr',
#   '00000000-0000-0000-0B37-2EB87E84C36E',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2024-01-31T00:00:00',
#   'San Joaquin',
#   'CA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '63',
#   '64',
#   '1.562500'],
#  ['row-txdk_6p3d.mten',
#   '00000000-0000-0000-BEC6-7916F8B4D480',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-04-30T00:00:00',
#   'Hamilton',
#   'TN',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '26',
#   '27',
#   '3.703703703703703703703703704'],
#  ['row-wjrz.zsmr-siqs',
#   '00000000-0000-0000-2C45-E88F1213160A',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-01-31T00:00:00',
#   'Richmond',
#   'NY',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '4',
#   '5',
#   '20.0'],
#  ['row-cbk7_rbyg.n4hk',
#   '00000000-0000-0000-4F33-9B3015DA996E',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-07-31T00:00:00',
#   'Carroll',
#   'NH',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '5',
#   '6',
#   '16.66666666666666666666666667'],
#  ['row-fwcp.x6vz.bw8b',
#   '00000000-0000-0000-22BF-47537F12A5E6',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-12-31T00:00:00',
#   'Snohomish',
#   'WA',
#   'Truck',
#   '2',
#   '0',
#   '2',
#   '125388',
#   '125390',
#   '0.001595023526597017306005263578'],
#  ['row-4a84-jers.28t8',
#   '00000000-0000-0000-69E5-299A3568CDFE',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-02-28T00:00:00',
#   'Spokane',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '100967',
#   '100967',
#   '0'],
#  ['row-cbb8_x4d9~53b8',
#   '00000000-0000-0000-59CE-D87BBBF3CA44',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-12-31T00:00:00',
#   'Benton',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '40577',
#   '40577',
#   '0'],
#  ['row-kxij~pi2q~bha9',
#   '00000000-0000-0000-DD6A-698C38CBF8B8',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2018-12-31T00:00:00',
#   'Norfolk',
#   'VA',
#   'Passenger',
#   '2',
#   '2',
#   '4',
#   '342',
#   '346',
#   '1.156069364161849710982658960'],
#  ['row-j698_ibac.w6kv',
#   '00000000-0000-0000-2D40-AAA08F525C85',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-03-31T00:00:00',
#   'Shelby',
#   'TN',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '113',
#   '114',
#   '0.8771929824561403508771929825'],
#  ['row-mxzu-587n-q4xj',
#   '00000000-0000-0000-7D4A-C11A6703B55C',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-03-31T00:00:00',
#   'King',
#   'WA',
#   'Truck',
#   '567',
#   '2',
#   '569',
#   '176588',
#   '177157',
#   '0.3211840345004713333370964737'],
#  ['row-ects~nej6~6x7x',
#   '00000000-0000-0000-E133-196CAB33A5AD',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-02-28T00:00:00',
#   'Grays Harbor',
#   'WA',
#   'Truck',
#   '2',
#   '0',
#   '2',
#   '21033',
#   '21035',
#   '0.009507962918944616115997147611'],
#  ['row-aits-t8tc.t9ux',
#   '00000000-0000-0000-B6BC-84158B8FB8FA',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-09-30T00:00:00',
#   'Jefferson',
#   'WA',
#   'Truck',
#   '3',
#   '0',
#   '3',
#   '9376',
#   '9379',
#   '0.03198635248960443544087855848'],
#  ['row-h6mx~ipiw~j6ah',
#   '00000000-0000-0000-FF8B-334DBEF6387C',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2018-11-30T00:00:00',
#   'Cook',
#   'IL',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '256',
#   '257',
#   '0.3891050583657587548638132296'],
#  ['row-cxmj_tfvz~wmdv',
#   '00000000-0000-0000-050F-8D9F2FF4F829',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2024-03-31T00:00:00',
#   'Arapahoe',
#   'CO',
#   'Passenger',
#   '1',
#   '1',
#   '2',
#   '62',
#   '64',
#   '3.12500'],
#  ['row-gp9b~jqie.54u4',
#   '00000000-0000-0000-7797-6647FBCE4773',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2024-04-30T00:00:00',
#   'Collier',
#   'FL',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '11',
#   '12',
#   '8.333333333333333333333333333'],
#  ['row-2k4f~j4ui~w22z',
#   '00000000-0000-0000-4C81-AC856D980FB0',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-07-31T00:00:00',
#   'Mercer',
#   'NJ',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '14',
#   '15',
#   '6.666666666666666666666666667'],
#  ['row-6m8z~4eji~9taq',
#   '00000000-0000-0000-6E98-6E326911A4E2',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2018-09-30T00:00:00',
#   'DeKalb',
#   'IN',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '1',
#   '2',
#   '50.0'],
#  ['row-rsjv~3m92.3mpm',
#   '00000000-0000-0000-F5A8-55E5DA39B15E',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-06-30T00:00:00',
#   'Whatcom',
#   'WA',
#   'Truck',
#   '2',
#   '0',
#   '2',
#   '41619',
#   '41621',
#   '0.004805266572163090747459215300'],
#  ['row-dk93.tjuk-wytk',
#   '00000000-0000-0000-0967-24A45FE09E3E',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-07-31T00:00:00',
#   'Wahkiakum',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '1799',
#   '1799',
#   '0'],
#  ['row-gpxp_wr4k~ncrj',
#   '00000000-0000-0000-F751-61EF73E4597E',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-11-30T00:00:00',
#   'El Paso',
#   'CO',
#   'Passenger',
#   '5',
#   '1',
#   '6',
#   '447',
#   '453',
#   '1.324503311258278145695364238'],
#  ['row-y78x_hbcx.6hj4',
#   '00000000-0000-0000-90CA-56010E82E0C1',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-07-31T00:00:00',
#   'Burlington',
#   'NJ',
#   'Passenger',
#   '0',
#   '2',
#   '2',
#   '104',
#   '106',
#   '1.886792452830188679245283019'],
#  ['row-66rq_c53u-dgmh',
#   '00000000-0000-0000-A1DD-25B544A9111D',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2024-01-31T00:00:00',
#   'Otero',
#   'NM',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '22',
#   '23',
#   '4.347826086956521739130434783'],
#  ['row-kwcg~gm2p~jgdh',
#   '00000000-0000-0000-F07C-F8183A2320C5',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-09-30T00:00:00',
#   'Kootenai',
#   'ID',
#   'Truck',
#   '1',
#   '0',
#   '1',
#   '25',
#   '26',
#   '3.846153846153846153846153846'],
#  ['row-3e3v-syqp.asae',
#   '00000000-0000-0000-D986-DB6DC70C7730',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-07-31T00:00:00',
#   'Cass',
#   'MN',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '2',
#   '3',
#   '33.33333333333333333333333333'],
#  ['row-giqv.vxdq.yudj',
#   '00000000-0000-0000-BBC4-EE274A43F478',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-01-31T00:00:00',
#   'Shelby',
#   'OH',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '2',
#   '3',
#   '33.33333333333333333333333333'],
#  ['row-825e-cfqj-vyp4',
#   '00000000-0000-0000-8E51-2097D0F433EB',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2018-09-30T00:00:00',
#   'Yakima',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '58679',
#   '58679',
#   '0'],
#  ['row-xryd.74re.5bmz',
#   '00000000-0000-0000-57FB-7DEF354FD001',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-05-31T00:00:00',
#   'Pima',
#   'AZ',
#   'Passenger',
#   '0',
#   '2',
#   '2',
#   '459',
#   '461',
#   '0.4338394793926247288503253796'],
#  ['row-baxi.k2gz~ijrs',
#   '00000000-0000-0000-80F4-A8405E1519AE',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-12-31T00:00:00',
#   'Douglas',
#   'NE',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '59',
#   '60',
#   '1.666666666666666666666666667'],
#  ['row-i97n~p3ms_jygv',
#   '00000000-0000-0000-0A9B-077959151FDF',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-04-30T00:00:00',
#   'Pulaski',
#   'MO',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '149',
#   '150',
#   '0.6666666666666666666666666667'],
#  ['row-dn76-gr68_um5j',
#   '00000000-0000-0000-651C-2BEA7832444A',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-07-31T00:00:00',
#   'Douglas',
#   'NE',
#   'Passenger',
#   '1',
#   '1',
#   '2',
#   '55',
#   '57',
#   '3.508771929824561403508771930'],
#  ['row-h575~wbcp~yy5b',
#   '00000000-0000-0000-77F4-40267DC0E6CA',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-06-30T00:00:00',
#   'Spartanburg',
#   'SC',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '39',
#   '40',
#   '2.500'],
#  ['row-mgua-uts9.aqwz',
#   '00000000-0000-0000-C502-8FB839E7F9DB',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-08-31T00:00:00',
#   'Mason',
#   'WA',
#   'Truck',
#   '4',
#   '0',
#   '4',
#   '20946',
#   '20950',
#   '0.01909307875894988066825775656'],
#  ['row-gx7b-xujk~dhgb',
#   '00000000-0000-0000-1BC3-DB3971592511',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-04-30T00:00:00',
#   'Ferry',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '3651',
#   '3651',
#   '0'],
#  ['row-35hv~wqri~k7nt',
#   '00000000-0000-0000-ABFA-76F84CEE5BD4',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-07-31T00:00:00',
#   'Douglas',
#   'WA',
#   'Passenger',
#   '76',
#   '41',
#   '117',
#   '28043',
#   '28160',
#   '0.4154829545454545454545454545'],
#  ['row-dwih~8yme-em7y',
#   '00000000-0000-0000-BB53-E977A8E84C00',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-02-28T00:00:00',
#   'Grays Harbor',
#   'WA',
#   'Passenger',
#   '202',
#   '157',
#   '359',
#   '49288',
#   '49647',
#   '0.7231051221624670171410155699'],
#  ['row-rbft_7q9u.ynrj',
#   '00000000-0000-0000-7F93-6E043243A8C1',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2018-03-31T00:00:00',
#   'Ventura',
#   'CA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '336',
#   '337',
#   '0.2967359050445103857566765579'],
#  ['row-v6h8-ukdj~cy93',
#   '00000000-0000-0000-02B6-58345F85FB74',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2024-01-31T00:00:00',
#   'Lake',
#   'IN',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '5',
#   '6',
#   '16.66666666666666666666666667'],
#  ['row-x9ge.nbns_rxme',
#   '00000000-0000-0000-EFB7-903F03346DB5',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-06-30T00:00:00',
#   'Hamilton',
#   'TN',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '19',
#   '20',
#   '5.00'],
#  ['row-wj35_igsa~igge',
#   '00000000-0000-0000-9A72-B28E0465EADD',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-01-31T00:00:00',
#   'Vigo',
#   'IN',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '6',
#   '7',
#   '14.28571428571428571428571429'],
#  ['row-s4jh_kefp_yz7j',
#   '00000000-0000-0000-198E-10996A534F46',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-04-30T00:00:00',
#   'Kern',
#   'CA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '229',
#   '230',
#   '0.4347826086956521739130434783'],
#  ['row-978z-gir3~qekh',
#   '00000000-0000-0000-2995-171ED80DB7CC',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2018-05-31T00:00:00',
#   'Spokane',
#   'WA',
#   'Truck',
#   '1',
#   '0',
#   '1',
#   '92354',
#   '92355',
#   '0.001082778409398516593579124032'],
#  ['row-tcie_7muh.8x98',
#   '00000000-0000-0000-ECD8-4AFA4DB91C8F',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-05-31T00:00:00',
#   'Columbia',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '1532',
#   '1532',
#   '0'],
#  ['row-j74w-mubw_feme',
#   '00000000-0000-0000-AE59-4212DD50EC5A',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-01-31T00:00:00',
#   'Skamania',
#   'WA',
#   'Passenger',
#   '18',
#   '15',
#   '33',
#   '8735',
#   '8768',
#   '0.3763686131386861313868613139'],
#  ['row-3r2u_gkqw.diyf',
#   '00000000-0000-0000-18D9-B8428E9AEB19',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-01-31T00:00:00',
#   'Salt Lake',
#   'UT',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '360',
#   '361',
#   '0.2770083102493074792243767313'],
#  ['row-kpsd.dqfa_e6g5',
#   '00000000-0000-0000-3431-2EF1553C7056',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-11-30T00:00:00',
#   'Washoe',
#   'NV',
#   'Passenger',
#   '2',
#   '0',
#   '2',
#   '49',
#   '51',
#   '3.921568627450980392156862745'],
#  ['row-bkpf.bwbt.wz8f',
#   '00000000-0000-0000-570D-1B557F8DCE96',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-07-31T00:00:00',
#   'DeKalb',
#   'GA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '51',
#   '52',
#   '1.923076923076923076923076923'],
#  ['row-stcg.ydqy-g5vq',
#   '00000000-0000-0000-638F-ED91038A3C51',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-03-31T00:00:00',
#   'King',
#   'WA',
#   'Passenger',
#   '37912',
#   '10700',
#   '48612',
#   '1350004',
#   '1398616',
#   '3.475721713465311422148752767'],
#  ['row-67rh_iydq-iphy',
#   '00000000-0000-0000-FDF3-386F8DBF052A',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-01-31T00:00:00',
#   'Kitsap',
#   'WA',
#   'Passenger',
#   '981',
#   '556',
#   '1537',
#   '179904',
#   '181441',
#   '0.8471073241439365964693757199'],
#  ['row-f2jv-idp2-he4w',
#   '00000000-0000-0000-7AFD-AC4D6A9E91DA',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2024-03-31T00:00:00',
#   'Pierce',
#   'WA',
#   'Truck',
#   '273',
#   '0',
#   '273',
#   '131289',
#   '131562',
#   '0.2075067268664203949468691567'],
#  ['row-kk9d~brcm-59hw',
#   '00000000-0000-0000-E3C9-DE1600D3DF0A',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-06-30T00:00:00',
#   None,
#   None,
#   'Passenger',
#   '5',
#   '0',
#   '5',
#   '271',
#   '276',
#   '1.811594202898550724637681159'],
#  ['row-vn22-7dzz.5puv',
#   '00000000-0000-0000-06AB-EBBA9AD00A25',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-04-30T00:00:00',
#   'Tulsa',
#   'OK',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '47',
#   '48',
#   '2.083333333333333333333333333'],
#  ['row-jijt.chk2~8sia',
#   '00000000-0000-0000-D05D-1E04C193AC11',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2018-06-30T00:00:00',
#   'Kitsap',
#   'WA',
#   'Passenger',
#   '797',
#   '460',
#   '1257',
#   '178497',
#   '179754',
#   '0.6992890283387295971160586134'],
#  ['row-3ma3-zngk~f97u',
#   '00000000-0000-0000-664A-045A3EA5BB13',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-03-31T00:00:00',
#   'Lewis',
#   'WA',
#   'Passenger',
#   '224',
#   '166',
#   '390',
#   '59432',
#   '59822',
#   '0.6519340710775300056835277991'],
#  ['row-yxdi_jkku~qxfk',
#   '00000000-0000-0000-9EC1-0C06A3D95B61',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-03-31T00:00:00',
#   'Okanogan',
#   'WA',
#   'Truck',
#   '3',
#   '0',
#   '3',
#   '16487',
#   '16490',
#   '0.01819284414796846573681018799'],
#  ['row-9unn~6fkp~5pi7',
#   '00000000-0000-0000-8F43-FDF1564D12A2',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2018-10-31T00:00:00',
#   'Multnomah',
#   'OR',
#   'Passenger',
#   '3',
#   '4',
#   '7',
#   '772',
#   '779',
#   '0.8985879332477535301668806162'],
#  ['row-q38g~ruu2.vi7e',
#   '00000000-0000-0000-B3DC-A785416183DD',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-12-31T00:00:00',
#   'Ventura',
#   'CA',
#   'Passenger',
#   '0',
#   '2',
#   '2',
#   '311',
#   '313',
#   '0.6389776357827476038338658147'],
#  ['row-ykhy-w9qw.4gwp',
#   '00000000-0000-0000-0230-5159DA020C51',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2018-05-31T00:00:00',
#   'Lumpkin',
#   'GA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '7',
#   '8',
#   '12.500'],
#  ['row-8vgb~hb3p~byge',
#   '00000000-0000-0000-816C-03F600B50C47',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-04-30T00:00:00',
#   'Pend Oreille',
#   'WA',
#   'Passenger',
#   '1',
#   '4',
#   '5',
#   '9320',
#   '9325',
#   '0.05361930294906166219839142091'],
#  ['row-z6nu~7724.bmq5',
#   '00000000-0000-0000-2055-B9FAAFD269BA',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-02-29T00:00:00',
#   None,
#   None,
#   'Passenger',
#   '6',
#   '2',
#   '8',
#   '416',
#   '424',
#   '1.886792452830188679245283019'],
#  ['row-j6yj_zm9r~2zw5',
#   '00000000-0000-0000-DA3E-F07939840D13',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-04-30T00:00:00',
#   'Garfield',
#   'WA',
#   'Passenger',
#   '1',
#   '3',
#   '4',
#   '1309',
#   '1313',
#   '0.3046458492003046458492003046'],
#  ['row-3z88_6d6d~vtzf',
#   '00000000-0000-0000-8A40-D85C44323CA3',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-12-31T00:00:00',
#   'Anne Arundel',
#   'MD',
#   'Passenger',
#   '3',
#   '1',
#   '4',
#   '362',
#   '366',
#   '1.092896174863387978142076503'],
#  ['row-k4kc-kwyf~dyxj',
#   '00000000-0000-0000-3C7D-2A22DF68F114',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-07-31T00:00:00',
#   'St. Clair',
#   'IL',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '139',
#   '140',
#   '0.7142857142857142857142857143'],
#  ['row-5dde_992s.xrah',
#   '00000000-0000-0000-7D02-6804724794F6',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2024-02-29T00:00:00',
#   'Charlottesville',
#   'VA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '3',
#   '4',
#   '25.00'],
#  ['row-d2pz_f9c8~55dt',
#   '00000000-0000-0000-3C17-A967FADAB0CA',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-09-30T00:00:00',
#   'Berkshire',
#   'MA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '4',
#   '5',
#   '20.0'],
#  ['row-iehr-zymp-nqc3',
#   '00000000-0000-0000-00CF-67B3C3C6D267',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2018-10-31T00:00:00',
#   'Thurston',
#   'WA',
#   'Passenger',
#   '663',
#   '551',
#   '1214',
#   '194970',
#   '196184',
#   '0.6188068344003588467968845574'],
#  ['row-s9ch~mdee-gqpw',
#   '00000000-0000-0000-825A-7AD6D14BD28E',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-02-29T00:00:00',
#   'Klickitat',
#   'WA',
#   'Passenger',
#   '49',
#   '41',
#   '90',
#   '15681',
#   '15771',
#   '0.5706676811869887768689366559'],
#  ['row-dn37-j8ru.q9f2',
#   '00000000-0000-0000-F702-1C481BBC7E08',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2018-06-30T00:00:00',
#   'Charles',
#   'MD',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '84',
#   '85',
#   '1.176470588235294117647058824'],
#  ['row-9u2x.z88t-wiz5',
#   '00000000-0000-0000-A638-9D201D0494A4',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-01-31T00:00:00',
#   'Adams',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '5433',
#   '5433',
#   '0'],
#  ['row-tvq6.4jd9.dmtc',
#   '00000000-0000-0000-4A07-56983D98C3CC',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-11-30T00:00:00',
#   "St. Mary's",
#   'MD',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '183',
#   '184',
#   '0.5434782608695652173913043478'],
#  ['row-d4j3-wqc2-qhvn',
#   '00000000-0000-0000-9255-FA141AF06F7F',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-03-31T00:00:00',
#   'Charleston',
#   'SC',
#   'Passenger',
#   '2',
#   '2',
#   '4',
#   '59',
#   '63',
#   '6.349206349206349206349206349'],
#  ['row-ayn8_rp3f~ph3e',
#   '00000000-0000-0000-29A7-36A5973A38D1',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-01-31T00:00:00',
#   'Goochland',
#   'VA',
#   'Passenger',
#   '2',
#   '2',
#   '4',
#   '87',
#   '91',
#   '4.395604395604395604395604396'],
#  ['row-w5jz.34en~nu7h',
#   '00000000-0000-0000-0336-30FB3E0C9B19',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-08-31T00:00:00',
#   'Saratoga',
#   'NY',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '42',
#   '43',
#   '2.325581395348837209302325581'],
#  ['row-b7ep~gnm7_cwkf',
#   '00000000-0000-0000-8F9E-D9E4B9000333',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-04-30T00:00:00',
#   'Whatcom',
#   'WA',
#   'Truck',
#   '2',
#   '0',
#   '2',
#   '42768',
#   '42770',
#   '0.004676174888940846387654898293'],
#  ['row-au34_vrdh-fcbt',
#   '00000000-0000-0000-FBB1-CDF9D2137A87',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-01-31T00:00:00',
#   'Washoe',
#   'NV',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '115',
#   '116',
#   '0.8620689655172413793103448276'],
#  ['row-dn2k~364m.expb',
#   '00000000-0000-0000-2CC3-9055F15E5650',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-05-31T00:00:00',
#   'Fairfax',
#   'VA',
#   'Passenger',
#   '5',
#   '4',
#   '9',
#   '719',
#   '728',
#   '1.236263736263736263736263736'],
#  ['row-7tr7.eh46~inju',
#   '00000000-0000-0000-E0C0-74E274AEB787',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-03-31T00:00:00',
#   'Montgomery',
#   'MD',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '276',
#   '277',
#   '0.3610108303249097472924187726'],
#  ['row-s6ng_u99n~w4m8',
#   '00000000-0000-0000-33BA-F714DC94740C',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2018-09-30T00:00:00',
#   'Richland',
#   'SC',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '169',
#   '170',
#   '0.5882352941176470588235294118'],
#  ['row-9qiv~a8pu_pnzu',
#   '00000000-0000-0000-B1E5-9D45E4EBB0BD',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-03-31T00:00:00',
#   'Fulton',
#   'GA',
#   'Passenger',
#   '1',
#   '3',
#   '4',
#   '115',
#   '119',
#   '3.361344537815126050420168067'],
#  ['row-nncw_byrw-nhch',
#   '00000000-0000-0000-9138-19C2A8C70F0A',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-08-31T00:00:00',
#   'Montgomery',
#   'MD',
#   'Passenger',
#   '3',
#   '1',
#   '4',
#   '213',
#   '217',
#   '1.843317972350230414746543779'],
#  ['row-tgsm_qjn2.q4xe',
#   '00000000-0000-0000-9A2D-F8E67EB8F506',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2018-02-28T00:00:00',
#   'Dale',
#   'AL',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '62',
#   '63',
#   '1.587301587301587301587301587'],
#  ['row-vcky-h8h8.ceqr',
#   '00000000-0000-0000-2068-9A31EB94E879',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-01-31T00:00:00',
#   'Saratoga',
#   'NY',
#   'Passenger',
#   '1',
#   '1',
#   '2',
#   '40',
#   '42',
#   '4.761904761904761904761904762'],
#  ['row-sunv-6nyu.c8dm',
#   '00000000-0000-0000-EB00-C3E891BA7BF2',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-07-31T00:00:00',
#   'New Haven',
#   'CT',
#   'Passenger',
#   '0',
#   '2',
#   '2',
#   '46',
#   '48',
#   '4.166666666666666666666666667'],
#  ['row-5w8p_ct87~e8ui',
#   '00000000-0000-0000-BB22-BBF71CAA4C4D',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-10-31T00:00:00',
#   'San Diego',
#   'CA',
#   'Passenger',
#   '5',
#   '1',
#   '6',
#   '2618',
#   '2624',
#   '0.2286585365853658536585365854'],
#  ['row-tudg.46kb~kw9g',
#   '00000000-0000-0000-E992-408F879AA95B',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-05-31T00:00:00',
#   'Lewis',
#   'WA',
#   'Truck',
#   '7',
#   '0',
#   '7',
#   '26029',
#   '26036',
#   '0.02688585036103856199108926102'],
#  ['row-k865.e8hw~5tb2',
#   '00000000-0000-0000-598A-F912984BE3DA',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-07-31T00:00:00',
#   'Columbia',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '1554',
#   '1554',
#   '0'],
#  ['row-pxed~ak33_h483',
#   '00000000-0000-0000-DCA5-857FF7FC273A',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-07-31T00:00:00',
#   'Asotin',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '6631',
#   '6631',
#   '0'],
#  ['row-8puu_kyjz~qtv4',
#   '00000000-0000-0000-6629-655E140FCC25',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-03-31T00:00:00',
#   'Clallam',
#   'WA',
#   'Truck',
#   '1',
#   '0',
#   '1',
#   '22039',
#   '22040',
#   '0.004537205081669691470054446461'],
#  ['row-h6pz_husr.7vin',
#   '00000000-0000-0000-6629-8A4FEA9C3460',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-01-31T00:00:00',
#   'Riverside',
#   'CA',
#   'Passenger',
#   '7',
#   '0',
#   '7',
#   '437',
#   '444',
#   '1.576576576576576576576576577'],
#  ['row-szg7~9mep_3n2f',
#   '00000000-0000-0000-DFF7-EA1CB9F20CB5',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-12-31T00:00:00',
#   'Middlesex',
#   'MA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '109',
#   '110',
#   '0.9090909090909090909090909091'],
#  ['row-b3kt_uqz3-ijk8',
#   '00000000-0000-0000-8B81-7CEBD60A5A9A',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-04-30T00:00:00',
#   'Burlington',
#   'NJ',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '132',
#   '133',
#   '0.7518796992481203007518796992'],
#  ['row-tsax-zd2t.c82a',
#   '00000000-0000-0000-03CC-310761566726',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-11-30T00:00:00',
#   'Orange',
#   'CA',
#   'Truck',
#   '1',
#   '0',
#   '1',
#   '62',
#   '63',
#   '1.587301587301587301587301587'],
#  ['row-65kp-au3g-kqee',
#   '00000000-0000-0000-E285-DC30366E7B9A',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-08-31T00:00:00',
#   'Palm Beach',
#   'FL',
#   'Passenger',
#   '0',
#   '2',
#   '2',
#   '80',
#   '82',
#   '2.439024390243902439024390244'],
#  ['row-ck2j~nb5f-qxkb',
#   '00000000-0000-0000-EA43-94C1F68D205B',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-12-31T00:00:00',
#   'Williamson',
#   'TX',
#   'Passenger',
#   '0',
#   '2',
#   '2',
#   '151',
#   '153',
#   '1.307189542483660130718954248'],
#  ['row-ks5p-m9g2.vbbj',
#   '00000000-0000-0000-C0AA-2E9B3E030F2D',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-08-31T00:00:00',
#   'El Paso',
#   'TX',
#   'Passenger',
#   '3',
#   '0',
#   '3',
#   '280',
#   '283',
#   '1.060070671378091872791519435'],
#  ['row-vz4g.6b5b~x265',
#   '00000000-0000-0000-6491-91A314C12022',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-10-31T00:00:00',
#   'Jefferson',
#   'NY',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '215',
#   '216',
#   '0.4629629629629629629629629630'],
#  ['row-krmu.wx3n.za74',
#   '00000000-0000-0000-9DC9-3472368143F3',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-08-31T00:00:00',
#   'Fredericksburg',
#   'VA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '5',
#   '6',
#   '16.66666666666666666666666667'],
#  ['row-n9qt.wtxt.5d4a',
#   '00000000-0000-0000-9BB5-34F44470DCD0',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-11-30T00:00:00',
#   'Carson City',
#   'NV',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '10',
#   '11',
#   '9.090909090909090909090909091'],
#  ['row-cfvc-bar7_ptmf',
#   '00000000-0000-0000-B841-5E7397EAA00D',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-02-28T00:00:00',
#   'Collin',
#   'TX',
#   'Passenger',
#   '1',
#   '1',
#   '2',
#   '153',
#   '155',
#   '1.290322580645161290322580645'],
#  ['row-qg7y-5p5i.ttii',
#   '00000000-0000-0000-A49A-97EE31532956',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-02-28T00:00:00',
#   'Wahkiakum',
#   'WA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '2843',
#   '2844',
#   '0.03516174402250351617440225035'],
#  ['row-5mpm.tp78~wdbp',
#   '00000000-0000-0000-D74E-3748193E9EEB',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-10-31T00:00:00',
#   'New Haven',
#   'CT',
#   'Passenger',
#   '0',
#   '2',
#   '2',
#   '47',
#   '49',
#   '4.081632653061224489795918367'],
#  ['row-kkyd~pqhq~ntvv',
#   '00000000-0000-0000-9AE1-6C6ACA58AC03',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-12-31T00:00:00',
#   'Marin',
#   'CA',
#   'Passenger',
#   '1',
#   '1',
#   '2',
#   '26',
#   '28',
#   '7.142857142857142857142857143'],
#  ['row-nk3r.4u32~xk2w',
#   '00000000-0000-0000-FC1F-0EA13E76839C',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2018-06-30T00:00:00',
#   'Monroe',
#   'IL',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '4',
#   '5',
#   '20.0'],
#  ['row-wtkm-wwd7-39h4',
#   '00000000-0000-0000-B897-56E12A0D2B13',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-10-31T00:00:00',
#   'Pinal',
#   'AZ',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '120',
#   '121',
#   '0.8264462809917355371900826446'],
#  ['row-wxv5_nq5d-qg22',
#   '00000000-0000-0000-2952-E9BBE184DEF8',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-08-31T00:00:00',
#   'Lake',
#   'FL',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '24',
#   '25',
#   '4.00'],
#  ['row-sfpu-dxzh-3eis',
#   '00000000-0000-0000-B445-5FEEE58E20C1',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-08-31T00:00:00',
#   'Arapahoe',
#   'CO',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '135',
#   '136',
#   '0.7352941176470588235294117647'],
#  ['row-6mhb-cs3p_wwy9',
#   '00000000-0000-0000-5FA8-E347E53CCD07',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-06-30T00:00:00',
#   'Klickitat',
#   'WA',
#   'Passenger',
#   '151',
#   '64',
#   '215',
#   '15132',
#   '15347',
#   '1.400925262266240959145109793'],
#  ['row-jis5.nndz_tdbz',
#   '00000000-0000-0000-81E3-1754B19C8DFB',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-07-31T00:00:00',
#   'El Paso',
#   'CO',
#   'Passenger',
#   '2',
#   '2',
#   '4',
#   '615',
#   '619',
#   '0.6462035541195476575121163166'],
#  ['row-zip3_xjzs~5ivn',
#   '00000000-0000-0000-C4AE-B5449C3EFFEA',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-06-30T00:00:00',
#   'Duval',
#   'FL',
#   'Passenger',
#   '1',
#   '2',
#   '3',
#   '379',
#   '382',
#   '0.7853403141361256544502617801'],
#  ['row-ct7e-3h7c.tee9',
#   '00000000-0000-0000-2D4B-013FAC0AAFEE',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-08-31T00:00:00',
#   'Washtenaw',
#   'MI',
#   'Passenger',
#   '1',
#   '1',
#   '2',
#   '36',
#   '38',
#   '5.263157894736842105263157895'],
#  ['row-nqnz-gzpr_xw6c',
#   '00000000-0000-0000-13A2-54DBA6758705',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-02-29T00:00:00',
#   'Hawaii',
#   'HI',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '64',
#   '65',
#   '1.538461538461538461538461538'],
#  ['row-kfxv_8vg9.szhm',
#   '00000000-0000-0000-FEB9-735DF3CF0F2E',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-11-30T00:00:00',
#   'Portsmouth',
#   'VA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '65',
#   '66',
#   '1.515151515151515151515151515'],
#  ['row-xnn6.46eq-bxz4',
#   '00000000-0000-0000-0E8C-1B7C41D6B23F',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-04-30T00:00:00',
#   'Morris',
#   'NJ',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '15',
#   '16',
#   '6.2500'],
#  ['row-7yif~uia3_6247',
#   '00000000-0000-0000-030C-96C90D9DBAFE',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-12-31T00:00:00',
#   'Whatcom',
#   'WA',
#   'Passenger',
#   '988',
#   '477',
#   '1465',
#   '151649',
#   '153114',
#   '0.9568034275115273587000535549'],
#  ['row-mka5_v3kn.b5ag',
#   '00000000-0000-0000-9CB5-ABE9BE061145',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-01-31T00:00:00',
#   'Prince William',
#   'VA',
#   'Passenger',
#   '0',
#   '5',
#   '5',
#   '257',
#   '262',
#   '1.908396946564885496183206107'],
#  ['row-ma4y_viam_c7ip',
#   '00000000-0000-0000-7129-5F985A08D457',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2024-01-31T00:00:00',
#   'Pitt',
#   'NC',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '4',
#   '5',
#   '20.0'],
#  ['row-98iw_hj5z~55iz',
#   '00000000-0000-0000-A8C0-7ADD2E737EF2',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-04-30T00:00:00',
#   'Pierce',
#   'WA',
#   'Truck',
#   '140',
#   '0',
#   '140',
#   '137672',
#   '137812',
#   '0.1015876701593475169070908194'],
#  ['row-qmkk-29rd_6qvc',
#   '00000000-0000-0000-05E4-58EBFDF1A921',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-08-31T00:00:00',
#   'San Juan',
#   'WA',
#   'Passenger',
#   '644',
#   '175',
#   '819',
#   '13756',
#   '14575',
#   '5.619210977701543739279588336'],
#  ['row-mm3r_nemz~btwb',
#   '00000000-0000-0000-DFBD-BBA3E2E23DEE',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-12-31T00:00:00',
#   'Newport News',
#   'VA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '104',
#   '105',
#   '0.9523809523809523809523809524'],
#  ['row-f3vt-2mdj-zcxf',
#   '00000000-0000-0000-0266-A896D8DEBF76',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-12-31T00:00:00',
#   'Shasta',
#   'CA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '39',
#   '40',
#   '2.500'],
#  ['row-kera_n6z8~9trx',
#   '00000000-0000-0000-5A8F-7AF4846E1A09',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-09-30T00:00:00',
#   'Bucks',
#   'PA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '22',
#   '23',
#   '4.347826086956521739130434783'],
#  ['row-snr4_c8ra~4aep',
#   '00000000-0000-0000-768B-1AFCB3B149A9',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-11-30T00:00:00',
#   'Columbia',
#   'WA',
#   'Passenger',
#   '4',
#   '3',
#   '7',
#   '2438',
#   '2445',
#   '0.2862985685071574642126789366'],
#  ['row-ywrq.tnrw_d49u',
#   '00000000-0000-0000-FFCA-39096EBC8134',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-05-31T00:00:00',
#   'San Joaquin',
#   'CA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '133',
#   '134',
#   '0.7462686567164179104477611940'],
#  ['row-h35m.e5m7~v2g5',
#   '00000000-0000-0000-8F5E-0DCF653A2A15',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-11-30T00:00:00',
#   'Moore',
#   'NC',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '125',
#   '126',
#   '0.7936507936507936507936507937'],
#  ['row-9adv-bw7k~kre7',
#   '00000000-0000-0000-9A77-92D4E9EE0B1C',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-02-28T00:00:00',
#   'Polk',
#   'FL',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '69',
#   '70',
#   '1.428571428571428571428571429'],
#  ['row-giy8~7d4k-pqrk',
#   '00000000-0000-0000-3140-BF6537735270',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-07-31T00:00:00',
#   'Portsmouth',
#   'VA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '64',
#   '65',
#   '1.538461538461538461538461538'],
#  ['row-d5pe_ggwc~kpwh',
#   '00000000-0000-0000-8D64-85D78DA1ED00',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-08-31T00:00:00',
#   'Manassas',
#   'VA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '7',
#   '8',
#   '12.500'],
#  ['row-j34t~8wbd-dz3r',
#   '00000000-0000-0000-CF04-5FDCF15E3F32',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-05-31T00:00:00',
#   'Whatcom',
#   'WA',
#   'Passenger',
#   '1800',
#   '729',
#   '2529',
#   '148772',
#   '151301',
#   '1.671502501635812056761026034'],
#  ['row-ku6d~2r62_rgi8',
#   '00000000-0000-0000-A695-F945BFF0D440',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-12-31T00:00:00',
#   'Flathead',
#   'MT',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '58',
#   '59',
#   '1.694915254237288135593220339'],
#  ['row-seds_pjjp-mj2b',
#   '00000000-0000-0000-F2D9-62C89EFF414E',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-12-31T00:00:00',
#   'Pima',
#   'AZ',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '162',
#   '163',
#   '0.6134969325153374233128834356'],
#  ['row-73dn-s9ce~3n3m',
#   '00000000-0000-0000-8B67-0700FD8A0410',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-06-30T00:00:00',
#   'Goochland',
#   'VA',
#   'Passenger',
#   '4',
#   '2',
#   '6',
#   '240',
#   '246',
#   '2.439024390243902439024390244'],
#  ['row-ihs7-63br_ugzt',
#   '00000000-0000-0000-A1AB-EEB9083C54A1',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-09-30T00:00:00',
#   'Kootenai',
#   'ID',
#   'Passenger',
#   '1',
#   '1',
#   '2',
#   '221',
#   '223',
#   '0.8968609865470852017937219731'],
#  ['row-wce7-4kej.k4s6',
#   '00000000-0000-0000-13C5-D266642473B2',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-04-30T00:00:00',
#   'Mason',
#   'WA',
#   'Passenger',
#   '117',
#   '116',
#   '233',
#   '46856',
#   '47089',
#   '0.4948077045594512518847289176'],
#  ['row-uwdc_f53x.g7tb',
#   '00000000-0000-0000-903B-B0833360DAB3',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-02-28T00:00:00',
#   'Asotin',
#   'WA',
#   'Passenger',
#   '22',
#   '18',
#   '40',
#   '12625',
#   '12665',
#   '0.3158310303987366758784050533'],
#  ['row-cwvw~n56z~mh9m',
#   '00000000-0000-0000-6940-FFEF18F1E58E',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-01-31T00:00:00',
#   'Riverside',
#   'CA',
#   'Passenger',
#   '5',
#   '1',
#   '6',
#   '521',
#   '527',
#   '1.138519924098671726755218216'],
#  ['row-48wf-354r-8ghm',
#   '00000000-0000-0000-2F2C-CAFEE61CC866',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2024-02-29T00:00:00',
#   'Asotin',
#   'WA',
#   'Truck',
#   '2',
#   '0',
#   '2',
#   '6552',
#   '6554',
#   '0.03051571559353066829417149832'],
#  ['row-6m6t.sgh6.5t7z',
#   '00000000-0000-0000-BCEA-48448D2FB977',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-12-31T00:00:00',
#   'Jefferson',
#   'WA',
#   'Truck',
#   '18',
#   '0',
#   '18',
#   '9216',
#   '9234',
#   '0.1949317738791423001949317739'],
#  ['row-e96w~q2ys.rxb7',
#   '00000000-0000-0000-7B9F-AB393BD0C443',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-09-30T00:00:00',
#   'Tulsa',
#   'OK',
#   'Passenger',
#   '1',
#   '1',
#   '2',
#   '56',
#   '58',
#   '3.448275862068965517241379310'],
#  ['row-t8t7~ydkt~3f57',
#   '00000000-0000-0000-4E76-719395BCBB7F',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-07-31T00:00:00',
#   'New Haven',
#   'CT',
#   'Passenger',
#   '0',
#   '2',
#   '2',
#   '33',
#   '35',
#   '5.714285714285714285714285714'],
#  ['row-e8s3.hwkp_jfrd',
#   '00000000-0000-0000-C0FB-C44AEA062082',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-07-31T00:00:00',
#   'Kitsap',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '54128',
#   '54128',
#   '0'],
#  ['row-7zzx~jeka.z8gi',
#   '00000000-0000-0000-1F87-7031F6928170',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2018-10-31T00:00:00',
#   'Walla Walla',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '13509',
#   '13509',
#   '0'],
#  ['row-w5vz_jx9y-vag6',
#   '00000000-0000-0000-1A7E-FC1046213243',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-06-30T00:00:00',
#   'Jackson',
#   'MO',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '62',
#   '63',
#   '1.587301587301587301587301587'],
#  ['row-dnig_rhbf.pt9e',
#   '00000000-0000-0000-7A00-6998CF04DCD6',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-10-31T00:00:00',
#   'Fredericksburg',
#   'VA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '5',
#   '6',
#   '16.66666666666666666666666667'],
#  ['row-5mwc-zxdz-9swv',
#   '00000000-0000-0000-B9C3-4F33ACBCFCF4',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-07-31T00:00:00',
#   'Kitsap',
#   'WA',
#   'Passenger',
#   '1091',
#   '625',
#   '1716',
#   '181189',
#   '182905',
#   '0.9381919575736037833848172549'],
#  ['row-c6ah-sgwp_5cix',
#   '00000000-0000-0000-8A59-B43D535BD011',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-04-30T00:00:00',
#   'Pacific',
#   'WA',
#   'Passenger',
#   '60',
#   '68',
#   '128',
#   '15922',
#   '16050',
#   '0.7975077881619937694704049844'],
#  ['row-24qb-bhb5-zuyy',
#   '00000000-0000-0000-3CD6-CF69E0FCBAD1',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-12-31T00:00:00',
#   'Chelan',
#   'WA',
#   'Truck',
#   '13',
#   '0',
#   '13',
#   '23074',
#   '23087',
#   '0.05630874518127084506432191276'],
#  ['row-k7bj-zdgf_3sq4',
#   '00000000-0000-0000-5B9E-61808432109B',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-05-31T00:00:00',
#   'Douglas',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '12181',
#   '12181',
#   '0'],
#  ['row-rr76.ukum~gb7h',
#   '00000000-0000-0000-026D-7E6778C832B2',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-08-31T00:00:00',
#   'Chesapeake',
#   'VA',
#   'Passenger',
#   '2',
#   '2',
#   '4',
#   '294',
#   '298',
#   '1.342281879194630872483221477'],
#  ['row-gttc~nnyj-gnnj',
#   '00000000-0000-0000-D073-E9FA5277A5F4',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-03-31T00:00:00',
#   'Broward',
#   'FL',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '114',
#   '115',
#   '0.8695652173913043478260869565'],
#  ['row-zfjt_56d5-bahs',
#   '00000000-0000-0000-96D0-DC728EFD8163',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-01-31T00:00:00',
#   'King',
#   'WA',
#   'Passenger',
#   '8802',
#   '3620',
#   '12422',
#   '1387096',
#   '1399518',
#   '0.8875912992901841919860980709'],
#  ['row-97fe~3r5c_x3su',
#   '00000000-0000-0000-AE77-09C275D310D8',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-08-31T00:00:00',
#   'Maricopa',
#   'AZ',
#   'Passenger',
#   '5',
#   '10',
#   '15',
#   '1481',
#   '1496',
#   '1.002673796791443850267379679'],
#  ['row-vubk.ekhw.eu9e',
#   '00000000-0000-0000-F724-14C6A997A152',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-04-30T00:00:00',
#   'Maricopa',
#   'AZ',
#   'Passenger',
#   '11',
#   '5',
#   '16',
#   '774',
#   '790',
#   '2.025316455696202531645569620'],
#  ['row-3yyc.gp38.s92p',
#   '00000000-0000-0000-21B4-77AA897DB8F9',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-01-31T00:00:00',
#   'Kern',
#   'CA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '219',
#   '220',
#   '0.4545454545454545454545454545'],
#  ['row-y86z_6c37_k48g',
#   '00000000-0000-0000-30A6-93361B74E1D1',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-05-31T00:00:00',
#   'Shasta',
#   'CA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '27',
#   '28',
#   '3.571428571428571428571428571'],
#  ['row-nppf~2vck-m4ha',
#   '00000000-0000-0000-9285-E24B5129E253',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-03-31T00:00:00',
#   'Clackamas',
#   'OR',
#   'Passenger',
#   '2',
#   '0',
#   '2',
#   '163',
#   '165',
#   '1.212121212121212121212121212'],
#  ['row-gk3e-i43d-tfms',
#   '00000000-0000-0000-4E79-2E8905DC8ADE',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-12-31T00:00:00',
#   'Larimer',
#   'CO',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '54',
#   '55',
#   '1.818181818181818181818181818'],
#  ['row-fs7f.n3fr.edfu',
#   '00000000-0000-0000-C1D8-FE47759B1B79',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-10-31T00:00:00',
#   'Kauai',
#   'HI',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '18',
#   '19',
#   '5.263157894736842105263157895'],
#  ['row-q7x9-mrt2_c4ab',
#   '00000000-0000-0000-2B3C-C5293F9E9F27',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-09-30T00:00:00',
#   'Klickitat',
#   'WA',
#   'Passenger',
#   '83',
#   '51',
#   '134',
#   '15378',
#   '15512',
#   '0.8638473439917483238782877772'],
#  ['row-8biy~bxie-vask',
#   '00000000-0000-0000-3EC1-4BCA0CDEF4E1',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-08-31T00:00:00',
#   'Clallam',
#   'WA',
#   'Passenger',
#   '436',
#   '247',
#   '683',
#   '49512',
#   '50195',
#   '1.360693296145034365972706445'],
#  ['row-zrqu_shi3~5ti4',
#   '00000000-0000-0000-E2B9-5BD8B57CFEFE',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-11-30T00:00:00',
#   'Multnomah',
#   'OR',
#   'Passenger',
#   '3',
#   '6',
#   '9',
#   '717',
#   '726',
#   '1.239669421487603305785123967'],
#  ['row-ygri~u9ib_ue8j',
#   '00000000-0000-0000-F38C-CD839C9A175E',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-09-30T00:00:00',
#   'Orange',
#   'CA',
#   'Passenger',
#   '3',
#   '1',
#   '4',
#   '619',
#   '623',
#   '0.6420545746388443017656500803'],
#  ['row-h35r_bij8_8pgm',
#   '00000000-0000-0000-1515-9DA8CB6560CC',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2018-06-30T00:00:00',
#   'Williamson',
#   'TX',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '166',
#   '167',
# ...
#  ['row-8cpb-vwm6-kfsv',
#   '00000000-0000-0000-0FC1-21FA66C67E01',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-10-31T00:00:00',
#   'Newport News',
#   'VA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '92',
#   '93',
#   '1.075268817204301075268817204'],
#  ['row-ivk3.rp2n-mxpn',
#   '00000000-0000-0000-4294-0FCDC7BD4B7C',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-12-31T00:00:00',
#   'Pacific',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '7543',
#   '7543',
#   '0'],
#  ['row-khm9-wgwp~9h6w',
#   '00000000-0000-0000-8830-7EF1ABF33DFC',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-05-31T00:00:00',
#   'Yavapai',
#   'AZ',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '19',
#   '20',
#   '5.00'],
#  ['row-74kr~vqq7_y4s4',
#   '00000000-0000-0000-9D45-802896FD3CDE',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-07-31T00:00:00',
#   'Washtenaw',
#   'MI',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '29',
#   '30',
#   '3.333333333333333333333333333'],
#  ['row-5u6f-bbbc~8uqu',
#   '00000000-0000-0000-36CC-D53FE97ED343',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2024-01-31T00:00:00',
#   'Yakima',
#   'WA',
#   'Passenger',
#   '662',
#   '305',
#   '967',
#   '166127',
#   '167094',
#   '0.5787161717356697427795133278'],
#  ['row-yved_zd3w.zt9n',
#   '00000000-0000-0000-EA7D-DAD62EBD3E1D',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-05-31T00:00:00',
#   'Klickitat',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '8255',
#   '8255',
#   '0'],
#  ['row-wdus~af9y~3qbv',
#   '00000000-0000-0000-5636-E50C3FFDB80E',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-07-31T00:00:00',
#   'Stevens',
#   'WA',
#   'Passenger',
#   '118',
#   '69',
#   '187',
#   '29625',
#   '29812',
#   '0.6272641889172145444787333959'],
#  ['row-cxsh-tz6c~uqhd',
#   '00000000-0000-0000-7270-63F2B96024CE',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2018-07-31T00:00:00',
#   'Kittitas',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '14057',
#   '14057',
#   '0'],
#  ['row-6zyx-4b84_9xdr',
#   '00000000-0000-0000-D1A4-3C97FCAA0838',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-03-31T00:00:00',
#   'Jefferson',
#   'WA',
#   'Truck',
#   '9',
#   '0',
#   '9',
#   '9322',
#   '9331',
#   '0.09645268459972135891115636052'],
#  ['row-y8em_t8kt.6shp',
#   '00000000-0000-0000-8369-D43DAAD93D03',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-04-30T00:00:00',
#   'Skagit',
#   'WA',
#   'Passenger',
#   '397',
#   '215',
#   '612',
#   '91456',
#   '92068',
#   '0.6647260720337142112351740018'],
#  ['row-czku-im27~qdy6',
#   '00000000-0000-0000-5246-DF3F473C495E',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-08-31T00:00:00',
#   'Pend Oreille',
#   'WA',
#   'Passenger',
#   '16',
#   '7',
#   '23',
#   '9236',
#   '9259',
#   '0.2484069553947510530294848256'],
#  ['row-kduf-nh6n_9pgm',
#   '00000000-0000-0000-0DFF-49FDE2130FD0',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-11-30T00:00:00',
#   'Okanogan',
#   'WA',
#   'Truck',
#   '2',
#   '0',
#   '2',
#   '16451',
#   '16453',
#   '0.01215583784112319941651978363'],
#  ['row-d5ni-ncu9.bq5v',
#   '00000000-0000-0000-0260-EF3FAB5A4670',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-07-31T00:00:00',
#   'Prince William',
#   'VA',
#   'Passenger',
#   '1',
#   '4',
#   '5',
#   '249',
#   '254',
#   '1.968503937007874015748031496'],
#  ['row-6tpx-b74h_yew7',
#   '00000000-0000-0000-8EF4-B5D293B1A5B8',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-11-30T00:00:00',
#   'Chesterfield',
#   'VA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '38',
#   '39',
#   '2.564102564102564102564102564'],
#  ['row-pq9j-7y7j~6r9f',
#   '00000000-0000-0000-E5F6-2DF21BCBDB25',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2018-04-30T00:00:00',
#   'Caddo',
#   'LA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '23',
#   '24',
#   '4.166666666666666666666666667'],
#  ['row-rtys~9mkj_7qsc',
#   '00000000-0000-0000-AED5-721AAF936DBD',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-09-30T00:00:00',
#   'Alameda',
#   'CA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '357',
#   '358',
#   '0.2793296089385474860335195531'],
#  ['row-if65.mmfd~w73t',
#   '00000000-0000-0000-166B-DEDA59F7DD24',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-06-30T00:00:00',
#   'Clallam',
#   'WA',
#   'Passenger',
#   '228',
#   '168',
#   '396',
#   '50086',
#   '50482',
#   '0.7844380175111921080781268571'],
#  ['row-e55n~zjtv-yamt',
#   '00000000-0000-0000-903C-9FFE83E5A229',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-12-31T00:00:00',
#   'Stevens',
#   'WA',
#   'Truck',
#   '3',
#   '0',
#   '3',
#   '18612',
#   '18615',
#   '0.01611603545527800161160354553'],
#  ['row-pk2j~whcm_4khs',
#   '00000000-0000-0000-99EA-B972072E97A4',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2024-03-31T00:00:00',
#   'Benton',
#   'WA',
#   'Passenger',
#   '1478',
#   '671',
#   '2149',
#   '134141',
#   '136290',
#   '1.576784797123780174627632255'],
#  ['row-vtvt.8gjb_5bsz',
#   '00000000-0000-0000-DE03-CD747919E331',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2018-06-30T00:00:00',
#   'Franklin',
#   'WA',
#   'Passenger',
#   '39',
#   '66',
#   '105',
#   '57847',
#   '57952',
#   '0.1811844284925455549420209829'],
#  ['row-8nmw_6s4z~i73w',
#   '00000000-0000-0000-F4D6-696BEA50437E',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2024-03-31T00:00:00',
#   None,
#   None,
#   'Passenger',
#   '3',
#   '0',
#   '3',
#   '224',
#   '227',
#   '1.321585903083700440528634361'],
#  ['row-93sd.f54v_mjhr',
#   '00000000-0000-0000-186D-211E8E3CA421',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-02-28T00:00:00',
#   'Franklin',
#   'WA',
#   'Truck',
#   '4',
#   '0',
#   '4',
#   '20955',
#   '20959',
#   '0.01908488000381697600076339520'],
#  ['row-gq5m.rpik~pdxw',
#   '00000000-0000-0000-C9A2-95D5042F7F2C',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-04-30T00:00:00',
#   'Portsmouth',
#   'VA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '66',
#   '67',
#   '1.492537313432835820895522388'],
#  ['row-brza~zhxv-vxmm',
#   '00000000-0000-0000-33AD-E19AA6451640',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-01-31T00:00:00',
#   "Prince George's",
#   'MD',
#   'Passenger',
#   '1',
#   '1',
#   '2',
#   '187',
#   '189',
#   '1.058201058201058201058201058'],
#  ['row-f8pi-7ncy.yei6',
#   '00000000-0000-0000-6E6A-C57E4AEBDC58',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-09-30T00:00:00',
#   'Travis',
#   'TX',
#   'Passenger',
#   '1',
#   '1',
#   '2',
#   '196',
#   '198',
#   '1.010101010101010101010101010'],
#  ['row-ve4q-vk9w_kajj',
#   '00000000-0000-0000-945D-D9C94F46DF33',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2024-02-29T00:00:00',
#   'St. Louis',
#   'MO',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '48',
#   '49',
#   '2.040816326530612244897959184'],
#  ['row-gnxb-5jec~ppv4',
#   '00000000-0000-0000-B51D-D790DC1BB2E9',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2018-02-28T00:00:00',
#   'Garfield',
#   'WA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '1323',
#   '1324',
#   '0.07552870090634441087613293051'],
#  ['row-qgqp-aikm.xaju',
#   '00000000-0000-0000-8CFE-B24A4F980CE9',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-04-30T00:00:00',
#   'Rockingham',
#   'NH',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '26',
#   '27',
#   '3.703703703703703703703703704'],
#  ['row-uvyy~f7ik.ktcn',
#   '00000000-0000-0000-3B16-0CEA67353806',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-04-30T00:00:00',
#   "Prince George's",
#   'MD',
#   'Passenger',
#   '1',
#   '1',
#   '2',
#   '169',
#   '171',
#   '1.169590643274853801169590643'],
#  ['row-3wkw_f6ww-e286',
#   '00000000-0000-0000-15D0-C548BA0373F6',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-03-31T00:00:00',
#   'Pennington',
#   'SD',
#   'Passenger',
#   '2',
#   '0',
#   '2',
#   '32',
#   '34',
#   '5.882352941176470588235294118'],
#  ['row-mp29.p7sb-8ba4',
#   '00000000-0000-0000-2AD4-068BF5ECA974',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-12-31T00:00:00',
#   'Sarpy',
#   'NE',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '60',
#   '61',
#   '1.639344262295081967213114754'],
#  ['row-gtn4~ynuc_y8ng',
#   '00000000-0000-0000-6026-D2350A5811A8',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-05-31T00:00:00',
#   'Snohomish',
#   'WA',
#   'Passenger',
#   '1740',
#   '866',
#   '2606',
#   '512561',
#   '515167',
#   '0.5058553828176106000578453201'],
#  ['row-cpm3.ut9t.5ii4',
#   '00000000-0000-0000-1077-E3ACF056BD98',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-08-31T00:00:00',
#   'Lewis',
#   'WA',
#   'Passenger',
#   '181',
#   '153',
#   '334',
#   '59617',
#   '59951',
#   '0.5571216493469666894630615002'],
#  ['row-eyzi-wu49_x75c',
#   '00000000-0000-0000-2B9A-C13A59AF0E23',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-07-31T00:00:00',
#   'Skagit',
#   'WA',
#   'Truck',
#   '5',
#   '0',
#   '5',
#   '32270',
#   '32275',
#   '0.01549186676994577846630518978'],
#  ['row-kva3_ndg3_fgnj',
#   '00000000-0000-0000-5B92-1B3256AA1E43',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-09-30T00:00:00',
#   'Loudoun',
#   'VA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '69',
#   '70',
#   '1.428571428571428571428571429'],
#  ['row-yqbv~xr5u.iufz',
#   '00000000-0000-0000-6787-DFCA2954AFCF',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-08-31T00:00:00',
#   'Lewis',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '26311',
#   '26311',
#   '0'],
#  ['row-gzgd-4hqy-m7tz',
#   '00000000-0000-0000-E62C-893A171182E7',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-02-29T00:00:00',
#   'Broward',
#   'FL',
#   'Passenger',
#   '2',
#   '1',
#   '3',
#   '123',
#   '126',
#   '2.380952380952380952380952381'],
#  ['row-gqcj.qccp~zaxe',
#   '00000000-0000-0000-94A8-B2B2DCA78F69',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-08-31T00:00:00',
#   'Sonoma',
#   'CA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '93',
#   '94',
#   '1.063829787234042553191489362'],
#  ['row-9bzn_q53e~pbjv',
#   '00000000-0000-0000-CE85-B1B45981E213',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-07-31T00:00:00',
#   'Pulaski',
#   'AR',
#   'Passenger',
#   '2',
#   '0',
#   '2',
#   '18',
#   '20',
#   '10.0'],
#  ['row-zx5s_376u.r6vd',
#   '00000000-0000-0000-1651-5442EE6563E0',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-02-28T00:00:00',
#   'El Paso',
#   'TX',
#   'Passenger',
#   '3',
#   '0',
#   '3',
#   '316',
#   '319',
#   '0.9404388714733542319749216301'],
#  ['row-ygcq~58si.4giz',
#   '00000000-0000-0000-9306-C71D2BBCCCBD',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-03-31T00:00:00',
#   'El Paso',
#   'TX',
#   'Passenger',
#   '2',
#   '0',
#   '2',
#   '492',
#   '494',
#   '0.4048582995951417004048582996'],
#  ['row-sdht.bhdh~tk4q',
#   '00000000-0000-0000-1BF9-8DDADFA63CA8',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-11-30T00:00:00',
#   'Pima',
#   'AZ',
#   'Passenger',
#   '2',
#   '1',
#   '3',
#   '397',
#   '400',
#   '0.7500'],
#  ['row-ty5p~ahmx.u3gm',
#   '00000000-0000-0000-C1F2-630AC1C09261',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-05-31T00:00:00',
#   'Kern',
#   'CA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '229',
#   '230',
#   '0.4347826086956521739130434783'],
#  ['row-vcjc~5vaw.3wgt',
#   '00000000-0000-0000-99CC-762335C29150',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-01-31T00:00:00',
#   'Columbia',
#   'OR',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '23',
#   '24',
#   '4.166666666666666666666666667'],
#  ['row-ezyv_cng2-r8ic',
#   '00000000-0000-0000-9E62-A5C7E5F9EC8A',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2023-03-31T00:00:00',
#   'Stevens',
#   'WA',
#   'Truck',
#   '2',
#   '0',
#   '2',
#   '18737',
#   '18739',
#   '0.01067292811782912642083355569'],
#  ['row-ns8y~39hy-diyc',
#   '00000000-0000-0000-02F9-41BFA084DBC7',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-06-30T00:00:00',
#   'Maui',
#   'HI',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '27',
#   '28',
#   '3.571428571428571428571428571'],
#  ['row-zkbb-km8p-dnn6',
#   '00000000-0000-0000-0F11-21F26BB98C63',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-12-31T00:00:00',
#   'Bartow',
#   'GA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '5',
#   '6',
#   '16.66666666666666666666666667'],
#  ['row-azg6_34jx_cmnv',
#   '00000000-0000-0000-8701-544B4692EC02',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2018-08-31T00:00:00',
#   'Alameda',
#   'CA',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '347',
#   '348',
#   '0.2873563218390804597701149425'],
#  ['row-n7i6~v3uu.2hhn',
#   '00000000-0000-0000-F282-D472E6D2470C',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-12-31T00:00:00',
#   'Whitman',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '8452',
#   '8452',
#   '0'],
#  ['row-4qfg_ikpb.dmif',
#   '00000000-0000-0000-B527-9CE78BBF129E',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-12-31T00:00:00',
#   'District of Columbia',
#   'DC',
#   'Passenger',
#   '4',
#   '0',
#   '4',
#   '190',
#   '194',
#   '2.061855670103092783505154639'],
#  ['row-kiur.ebwk~4wq4',
#   '00000000-0000-0000-CA9B-81CB831C31B8',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2018-08-31T00:00:00',
#   'Lincoln',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '4571',
#   '4571',
#   '0'],
#  ['row-za8c.25cn-nnjh',
#   '00000000-0000-0000-C3E7-8150185196C7',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-01-31T00:00:00',
#   'Garfield',
#   'WA',
#   'Truck',
#   '0',
#   '0',
#   '0',
#   '961',
#   '961',
#   '0'],
#  ['row-4mgi-7rrm~ugjf',
#   '00000000-0000-0000-C76C-BA075219C21E',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2024-03-31T00:00:00',
#   'Asotin',
#   'WA',
#   'Truck',
#   '2',
#   '0',
#   '2',
#   '6504',
#   '6506',
#   '0.03074085459575776206578542883'],
#  ['row-pvin~vz5d.b5vv',
#   '00000000-0000-0000-F373-625FAB5DEAE2',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-06-30T00:00:00',
#   'Onslow',
#   'NC',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '167',
#   '168',
#   '0.5952380952380952380952380952'],
#  ['row-6att_ih4r~qjrj',
#   '00000000-0000-0000-2D6E-DD7F07F27970',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2021-07-31T00:00:00',
#   'Anne Arundel',
#   'MD',
#   'Passenger',
#   '3',
#   '1',
#   '4',
#   '386',
#   '390',
#   '1.025641025641025641025641026'],
#  ['row-fw2x.j32x~jb9q',
#   '00000000-0000-0000-15DE-0521B8B15813',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-02-28T00:00:00',
#   'Harris',
#   'TX',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '278',
#   '279',
#   '0.3584229390681003584229390681'],
#  ['row-guqi.p8we-ej2b',
#   '00000000-0000-0000-0F0D-A917BEA6748B',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-01-31T00:00:00',
#   'Okanogan',
#   'WA',
#   'Passenger',
#   '32',
#   '30',
#   '62',
#   '26209',
#   '26271',
#   '0.2360016748505957139050664231'],
#  ['row-k9n2~7t49-qvp2',
#   '00000000-0000-0000-C16E-7238E5396B8B',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2020-06-30T00:00:00',
#   'Island',
#   'WA',
#   'Truck',
#   '1',
#   '0',
#   '1',
#   '21195',
#   '21196',
#   '0.004717871296471032270239667862'],
#  ['row-7nex.qw4e-pb2f',
#   '00000000-0000-0000-A652-E06B7900633D',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2017-05-31T00:00:00',
#   'Sumter',
#   'FL',
#   'Passenger',
#   '0',
#   '1',
#   '1',
#   '10',
#   '11',
#   '9.090909090909090909090909091'],
#  ['row-y9k2_9b6m~etbr',
#   '00000000-0000-0000-6E13-34492859598A',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-07-31T00:00:00',
#   'Asotin',
#   'WA',
#   'Passenger',
#   '24',
#   '19',
#   '43',
#   '12616',
#   '12659',
#   '0.3396792795639465992574452958'],
#  ['row-avm6.vmtn.ax4u',
#   '00000000-0000-0000-D0E6-B69D166C0AAF',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2019-08-31T00:00:00',
#   'Solano',
#   'CA',
#   'Passenger',
#   '1',
#   '0',
#   '1',
#   '211',
#   '212',
#   '0.4716981132075471698113207547'],
#  ['row-bvjv~62iv.zaeq',
#   '00000000-0000-0000-78B5-476752D8B5BC',
#   0,
#   1716314809,
#   None,
#   1716314809,
#   None,
#   '{ }',
#   '2022-02-28T00:00:00',
#   'Boulder',
#   'CO',
#   'Passenger',
#   '2',
#   '0',
#   '2',
#   '46',
#   '48',
#   '4.166666666666666666666666667'],
#  ...]

# %%
print(len([x['name'] for x in newdata['meta']['view']['columns']]))
[x['name'] for x in newdata['meta']['view']['columns']]
# Out:
# 18
# ['sid',
#  'id',
#  'position',
#  'created_at',
#  'created_meta',
#  'updated_at',
#  'updated_meta',
#  'meta',
#  'Date',
#  'County',
#  'State',
#  'Vehicle Primary Use',
#  'Battery Electric Vehicles (BEVs)',
#  'Plug-In Hybrid Electric Vehicles (PHEVs)',
#  'Electric Vehicle (EV) Total',
#  'Non-Electric Vehicle Total',
#  'Total Vehicles',
#  'Percent Electric Vehicles']

# %%
info = newdata['data']
df = pd.DataFrame(info, columns=[x['name'] for x in newdata['meta']['view']['columns']])
df
# Out:
#                       sid                                    id  position  \
# 0      row-uc79~tpp3-5zxb  00000000-0000-0000-19FC-D5232A6F8D55         0
# 1      row-xc2i-z4xj_qa66  00000000-0000-0000-B75D-F6056FF7869D         0
# 2      row-pmup~x6gc~tm94  00000000-0000-0000-B010-7D96241E7BE6         0
# 3      row-ucnf-kkrn_ax53  00000000-0000-0000-BF41-9DE0FFE2B78B         0
# 4      row-ikva~vuqm_4e8c  00000000-0000-0000-FBC7-67DDDA10A339         0
# ...                   ...                                   ...       ...
# 21577  row-in5m~yusd-9wac  00000000-0000-0000-594A-B8B812E68A31         0
# 21578  row-7ce4~vfv2~ctnn  00000000-0000-0000-E957-C9CB3834A3B6         0
# 21579  row-g3rr.39kz.bi88  00000000-0000-0000-9CB9-C03853E0D106         0
# 21580  row-bcd2~mups~vbyz  00000000-0000-0000-1497-07A2C4E8CFD1         0
# 21581  row-egtj~9zxf_66br  00000000-0000-0000-8ED9-4CC235B12163         0
#
#        created_at created_meta  updated_at updated_meta meta  \
# 0      1716314809         None  1716314809         None  { }
# 1      1716314809         None  1716314809         None  { }
# 2      1716314809         None  1716314809         None  { }
# 3      1716314809         None  1716314809         None  { }
# 4      1716314809         None  1716314809         None  { }
# ...           ...          ...         ...          ...  ...
# 21577  1716314809         None  1716314809         None  { }
# 21578  1716314809         None  1716314809         None  { }
# 21579  1716314809         None  1716314809         None  { }
# 21580  1716314809         None  1716314809         None  { }
# 21581  1716314809         None  1716314809         None  { }
#
#                       Date     County State Vehicle Primary Use  \
# 0      2017-10-31T00:00:00   Saratoga    NY           Passenger
# 1      2017-02-28T00:00:00    Clallam    WA           Passenger
# 2      2020-08-31T00:00:00   Kittitas    WA           Passenger
# 3      2023-07-31T00:00:00     Asotin    WA           Passenger
# 4      2019-06-30T00:00:00  Riverside    CA           Passenger
# ...                    ...        ...   ...                 ...
# 21577  2022-05-31T00:00:00    Calvert    MD           Passenger
# 21578  2018-09-30T00:00:00   San Juan    WA           Passenger
# 21579  2021-11-30T00:00:00    Pacific    WA           Passenger
# 21580  2024-01-31T00:00:00    Cochise    AZ           Passenger
# 21581  2023-07-31T00:00:00   Hamilton    OH           Passenger
#
#       Battery Electric Vehicles (BEVs)  \
# 0                                    1
# 1                                   75
# 2                                  110
# 3                                   37
# 4                                    2
# ...                                ...
# 21577                                0
# 21578                              161
# 21579                               51
# 21580                                1
# 21581                                1
#
#       Plug-In Hybrid Electric Vehicles (PHEVs) Electric Vehicle (EV) Total  \
# 0                                            1                           2
# 1                                           64                         139
# 2                                           47                         157
# 3                                           23                          60
# 4                                            2                           4
# ...                                        ...                         ...
# 21577                                        2                           2
# 21578                                       68                         229
# 21579                                       64                         115
# 21580                                        0                           1
# 21581                                        0                           1
#
#       Non-Electric Vehicle Total Total Vehicles  \
# 0                             72             74
# 1                          47978          48117
# 2                          29763          29920
# 3                          12371          12431
# 4                            664            668
# ...                          ...            ...
# 21577                         81             83
# 21578                      14174          14403
# 21579                      16060          16175
# 21580                         51             52
# 21581                         32             33
#
#             Percent Electric Vehicles
# 0       2.702702702702702702702702703
# 1      0.2888791903069601180455971902
# 2      0.5247326203208556149732620321
# 3      0.4826643069744992357815139570
# 4      0.5988023952095808383233532934
# ...                               ...
# 21577   2.409638554216867469879518072
# 21578   1.589946538915503714503922794
# 21579  0.7109737248840803709428129830
# 21580   1.923076923076923076923076923
# 21581   3.030303030303030303030303030
#
# [21582 rows x 18 columns]

# %%
df1 = df.drop(df.columns[0:8], axis=1)
df1
# Out:
#                       Date     County State Vehicle Primary Use  \
# 0      2017-10-31T00:00:00   Saratoga    NY           Passenger
# 1      2017-02-28T00:00:00    Clallam    WA           Passenger
# 2      2020-08-31T00:00:00   Kittitas    WA           Passenger
# 3      2023-07-31T00:00:00     Asotin    WA           Passenger
# 4      2019-06-30T00:00:00  Riverside    CA           Passenger
# ...                    ...        ...   ...                 ...
# 21577  2022-05-31T00:00:00    Calvert    MD           Passenger
# 21578  2018-09-30T00:00:00   San Juan    WA           Passenger
# 21579  2021-11-30T00:00:00    Pacific    WA           Passenger
# 21580  2024-01-31T00:00:00    Cochise    AZ           Passenger
# 21581  2023-07-31T00:00:00   Hamilton    OH           Passenger
#
#       Battery Electric Vehicles (BEVs)  \
# 0                                    1
# 1                                   75
# 2                                  110
# 3                                   37
# 4                                    2
# ...                                ...
# 21577                                0
# 21578                              161
# 21579                               51
# 21580                                1
# 21581                                1
#
#       Plug-In Hybrid Electric Vehicles (PHEVs) Electric Vehicle (EV) Total  \
# 0                                            1                           2
# 1                                           64                         139
# 2                                           47                         157
# 3                                           23                          60
# 4                                            2                           4
# ...                                        ...                         ...
# 21577                                        2                           2
# 21578                                       68                         229
# 21579                                       64                         115
# 21580                                        0                           1
# 21581                                        0                           1
#
#       Non-Electric Vehicle Total Total Vehicles  \
# 0                             72             74
# 1                          47978          48117
# 2                          29763          29920
# 3                          12371          12431
# 4                            664            668
# ...                          ...            ...
# 21577                         81             83
# 21578                      14174          14403
# 21579                      16060          16175
# 21580                         51             52
# 21581                         32             33
#
#             Percent Electric Vehicles
# 0       2.702702702702702702702702703
# 1      0.2888791903069601180455971902
# 2      0.5247326203208556149732620321
# 3      0.4826643069744992357815139570
# 4      0.5988023952095808383233532934
# ...                               ...
# 21577   2.409638554216867469879518072
# 21578   1.589946538915503714503922794
# 21579  0.7109737248840803709428129830
# 21580   1.923076923076923076923076923
# 21581   3.030303030303030303030303030
#
# [21582 rows x 10 columns]

# %%
# df1 = df1.set_axis(['Date','County','State','Vehicle Primary Use','Battery Electric Vehicles (BEVs)','Plug-In Hybrid Electric Vehicles (PHEVs)','Electric Vehicle (EV) Total','Non-Electric Vehicle Total','Total Vehicles','Percent Electric Vehicles'], axis=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21582 entries, 0 to 21581
# Data columns (total 10 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Date                                      21582 non-null  object
#  1   County                                    21494 non-null  object
#  2   State                                     21494 non-null  object
#  3   Vehicle Primary Use                       21582 non-null  object
#  4   Battery Electric Vehicles (BEVs)          21582 non-null  object
#  5   Plug-In Hybrid Electric Vehicles (PHEVs)  21582 non-null  object
#  6   Electric Vehicle (EV) Total               21582 non-null  object
#  7   Non-Electric Vehicle Total                21582 non-null  object
#  8   Total Vehicles                            21582 non-null  object
#  9   Percent Electric Vehicles                 21582 non-null  object
# dtypes: object(10)
# memory usage: 1.6+ MB

# %%
df1.describe()
# Out:
#                        Date   County  State Vehicle Primary Use  \
# count                 21582    21494  21494               21582
# unique                   88      315     50                   2
# top     2022-11-30T00:00:00  Douglas     WA           Passenger
# freq                    289      295   6864               18052
#
#        Battery Electric Vehicles (BEVs)  \
# count                             21582
# unique                             1238
# top                                   1
# freq                               7203
#
#        Plug-In Hybrid Electric Vehicles (PHEVs) Electric Vehicle (EV) Total  \
# count                                     21582                       21582
# unique                                      950                        1432
# top                                           0                           1
# freq                                      10234                        9661
#
#        Non-Electric Vehicle Total Total Vehicles Percent Electric Vehicles
# count                       21582          21582                     21582
# unique                       7213           7230                      6400
# top                             1              2                         0
# freq                          301            301                      2273
